# %%
"""
Musical Instrument Emojis - Jupyter Notebook Compatible
Copy this code to your Jupyter notebook to display and use musical instrument emojis
"""

# Dictionary of musical instrument emojis organized by category
musical_instruments = {
    "String Instruments": {
        "guitar": "🎸",
        "violin": "🎻",
        "banjo": "🪕",
        "harp": "🎶",  # Using music note as harp isn't always available
    },
    
    "Keyboard Instruments": {
        "piano": "🎹",
        "accordion": "🪗",
    },
    
    "Wind Instruments": {
        "trumpet": "🎺",
        "saxophone": "🎷",
        "flute": "🪈",
    },
    
    "Percussion Instruments": {
        "drum": "🥁",
        "maracas": "🪇",
    },
    
    "General Music": {
        "microphone": "🎤",
        "headphones": "🎧",
        "musical_note": "🎵",
        "musical_notes": "🎶",
        "musical_score": "🎼",
        "studio_microphone": "🎙️",
        "level_slider": "🎚️",
        "control_knobs": "🎛️",
    }
}

# Display all emojis
def display_instruments():
    print("🎵 MUSICAL INSTRUMENT EMOJIS 🎵\n")
    print("=" * 50)
    
    for category, instruments in musical_instruments.items():
        print(f"\n📂 {category}:")
        print("-" * 50)
        for name, emoji in instruments.items():
            print(f"  {emoji}  {name:20s} | Copy: '{emoji}'")
    
    print("\n" + "=" * 50)

# Create a simple string of all instrument emojis
def get_all_emojis():
    all_emojis = []
    for category in musical_instruments.values():
        all_emojis.extend(category.values())
    return " ".join(all_emojis)

# Run the display
if __name__ == "__main__":
    display_instruments()
    
    print("\n\n🎼 ALL INSTRUMENTS IN ONE LINE:")
    print(get_all_emojis())
    
    print("\n\n💡 USAGE IN JUPYTER:")
    print("# Simply copy any emoji from above and paste it in your code!")
    print("# Example:")
    print("print('I love playing the', '🎸', 'and', '🥁')")

# Quick access list
GUITAR = "🎸"
VIOLIN = "🎻"
BANJO = "🪕"
PIANO = "🎹"
ACCORDION = "🪗"
TRUMPET = "🎺"
SAXOPHONE = "🎷"
FLUTE = "🪈"
DRUM = "🥁"
MARACAS = "🪇"
MICROPHONE = "🎤"
HEADPHONES = "🎧"
MUSICAL_NOTE = "🎵"
MUSICAL_NOTES = "🎶"

print("\n\n✨ You can also import these constants:")
print("GUITAR, VIOLIN, BANJO, PIANO, ACCORDION, TRUMPET,")
print("SAXOPHONE, FLUTE, DRUM, MARACAS, MICROPHONE, HEADPHONES,")
print("MUSICAL_NOTE, MUSICAL_NOTES")

# %%
"""
Automotive & Car Tools Emojis - Jupyter Notebook Compatible
Copy this code to your Jupyter notebook to display and use car/tool emojis
"""

# Dictionary of automotive and tool emojis organized by category
automotive_tools = {
    "Basic Tools": {
        "hammer": "🔨",
        "wrench": "🔧",
        "screwdriver": "🪛",
        "nut_and_bolt": "🔩",
        "gear": "⚙️",
        "clamp": "🗜️",
        "pick": "⛏️",
        "axe": "🪓",
        "saw": "🪚",
        "toolbox": "🧰",
    },
    
    "Vehicles": {
        "car": "🚗",
        "racing_car": "🏎️",
        "truck": "🚚",
        "delivery_truck": "🚛",
        "bus": "🚌",
        "taxi": "🚕",
        "police_car": "🚓",
        "ambulance": "🚑",
        "fire_engine": "🚒",
        "tractor": "🚜",
    },
    
    "Car Parts & Service": {
        "tire": "🛞",
        "oil_drum": "🛢️",
        "fuel_pump": "⛽",
        "battery": "🔋",
        "electric_plug": "🔌",
        "fire": "🔥",
        "droplet": "💧",
    },
    
    "Measurement & Testing": {
        "magnet": "🧲",
        "flashlight": "🔦",
        "compass": "🧭",
        "hourglass": "⏳",
        "stopwatch": "⏱️",
        "thermometer": "🌡️",
    },
    
    "Workshop Items": {
        "chains": "⛓️",
        "link": "🔗",
        "lock": "🔒",
        "key": "🔑",
        "shield": "🛡️",
        "warning": "⚠️",
        "no_entry": "⛔",
        "construction": "🚧",
    },
}

# Display all emojis
def display_tools():
    print("🔧 AUTOMOTIVE & TOOL EMOJIS 🚗\n")
    print("=" * 50)
    
    for category, items in automotive_tools.items():
        print(f"\n📂 {category}:")
        print("-" * 50)
        for name, emoji in items.items():
            print(f"  {emoji}  {name:20s} | Copy: '{emoji}'")
    
    print("\n" + "=" * 50)

# Create a simple string of all emojis
def get_all_emojis():
    all_emojis = []
    for category in automotive_tools.values():
        all_emojis.extend(category.values())
    return " ".join(all_emojis)

# Run the display
if __name__ == "__main__":
    display_tools()
    
    print("\n\n🚗 ALL TOOLS & VEHICLES IN ONE LINE:")
    print(get_all_emojis())
    
    print("\n\n💡 USAGE IN JUPYTER:")
    print("# Simply copy any emoji from above and paste it in your code!")
    print("# Example:")
    print("print('I need a', '🔧', 'and', '🔨', 'to fix my', '🚗')")

# Quick access list - Tools
HAMMER = "🔨"
WRENCH = "🔧"
SCREWDRIVER = "🪛"
NUT_AND_BOLT = "🔩"
GEAR = "⚙️"
TOOLBOX = "🧰"

# Quick access list - Vehicles
CAR = "🚗"
RACING_CAR = "🏎️"
TRUCK = "🚚"
BUS = "🚌"
TAXI = "🚕"

# Quick access list - Car Parts
TIRE = "🛞"
OIL_DRUM = "🛢️"
FUEL_PUMP = "⛽"
BATTERY = "🔋"

# Quick access list - Other
WARNING = "⚠️"
CONSTRUCTION = "🚧"

print("\n\n✨ You can also import these constants:")
print("HAMMER, WRENCH, SCREWDRIVER, NUT_AND_BOLT, GEAR, TOOLBOX,")
print("CAR, RACING_CAR, TRUCK, BUS, TAXI,")
print("TIRE, OIL_DRUM, FUEL_PUMP, BATTERY, WARNING, CONSTRUCTION")
