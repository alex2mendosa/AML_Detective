# %%
# By chat model we mean LLM model which operates with chats 
import os 
import json

import threading

from langchain_openai import ChatOpenAI 
from dotenv import load_dotenv
from langchain_core.prompts import PromptTemplate

from pydantic import BaseModel, Field
from typing import Literal , Optional

## check performance in agent workflow 
from typing import TypedDict, Annotated, List, Dict, Optional
from langchain_core.messages import BaseMessage, AnyMessage, ToolMessage,HumanMessage, AIMessage, SystemMessage
from langgraph.graph import add_messages , START, END , StateGraph
from IPython.display import Image, display 
from langgraph.checkpoint.memory import MemorySaver

from googleapiclient.discovery import build
from urllib.parse import urlparse

# prepare model for embeddings  
from langchain_openai import OpenAIEmbeddings 
from langchain_core.tools import tool, StructuredTool


from sklearn.metrics.pairwise import cosine_similarity
import numpy as np 
import numpy.typing as npt

from tavily import TavilyClient 

import subprocess
from IPython.display import Image, display


## OpenAI configuration
api_key_var = os.environ.get("OPENAI_API_KEY")
#print("OpenAI API: " , api_key_var)


# keys for tavily 
tavily_api = os.environ.get("TAVILY_API_KEY")
#print("Tavily API: " , tavily_api)

# api for goole
api_google = os.environ.get('GOOGLE_API_KEY')
#print("Google API: " , api_google)

# define search engine
SEARCH_ENGINE_ID = '26dda816634bd4044'


## word count 
def count_words_whitespace(s: str) -> int:
    return len(s.split())

class WordCounter:
    def __init__(self, word_in: int = 0, word_out: int = 0):
        self.word_input = word_in
        self.word_output = word_out

    def add_word_in(self, text: str) -> None:
        self.word_input += count_words_whitespace(text)

    def add_word_out(self, text: str) -> None:
        self.word_output += count_words_whitespace(text)


counter = WordCounter()
# Out:
# d:\MICB_Projects\8_aml_detective\.venv\lib\site-packages\google\api_core\_python_version_support.py:266: FutureWarning: You are using a Python version (3.10.11) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)

# %%
# Prepare embedding model
embedding_main = OpenAIEmbeddings(api_key=api_key_var, model="text-embedding-3-small")
embedding_cross_lang = OpenAIEmbeddings(api_key=api_key_var, model="text-embedding-3-large")

# For HyDE comparison we will employ large embedding model for richer semantic representation
# Larger model should be able to capture same concepts in different languages 
# Similar concepts should be positioned closer in the vector space

# Test with similar concepts + unrelated text
test_sentences = [
    "Искусственный интеллект меняет мир",        # AI is changing the world (Russian)
    "Artificial intelligence is changing the world",  # AI is changing the world (English) - fixed typo "word" -> "world"
    "Я люблю есть пиццу по вечерам"              # I love eating pizza in the evenings (unrelated)
]

# Get embeddings
#embeddings = [np.array(embedding_cross_lang.embed_query(x)).reshape(1, -1) for x in test_sentences]

# Calculate similarities
#print("Similarity between Russian and English (should be HIGH):")
#print(f"  {cosine_similarity(embeddings[0], embeddings[1])[0][0]:.4f}")

#print("\nSimilarity between Russian AI and Pizza (should be LOW):")
#print(f"  {cosine_similarity(embeddings[0], embeddings[2])[0][0]:.4f}")

#print("\nSimilarity between English AI and Pizza (should be LOW):")
#print(f"  {cosine_similarity(embeddings[1], embeddings[2])[0][0]:.4f}")

#del embeddings

# large vs small:
# better at capturing same meaning in different languages

# %%
# !jupyter nbconvert --to python 4_5_2_research_assistant.ipynb
# Out:
# [NbConvertApp] Converting notebook 4_5_2_research_assistant.ipynb to python
# [NbConvertApp] Writing 89814 bytes to 4_5_2_research_assistant.py

# %% [markdown]
# #### LLM models api definition

# %%
# Model to create payload 
llm_payload = ChatOpenAI(
    model="gpt-4.1-mini",  
    temperature=0.2,     
    max_tokens=500,      
    top_p=0.95,          
    timeout=15,         
)


# Translation and key terms extraction from short input
llm_translation_or_terms = ChatOpenAI(
    model="gpt-4.1-mini",  # BEST: Cheapest model that excels at translation tasks
                          # Translation is pattern-matching, doesn't need reasoning power
                          # GPT-4o-mini handles languages perfectly at 10x lower cost
    
    temperature=0.1,      # BEST: Near-deterministic output for consistent translations
                          # Translation should be consistent, not creative
                          # 0.1 allows tiny variation while preventing hallucinations
    
    max_tokens=500,       # BEST: Perfect for short translations and key terms
                          # Prevents model from over-explaining or adding fluff
                          # Saves money by limiting output length
    
    timeout=5,           # BEST: Translation should be fast, 5s is generous
                          # If it takes longer, something's wrong with the request
                          # Prevents hanging requests from eating budget
    
    max_retries=2         # BEST: Translation usually works first try
                          # 2 retries handles temporary network issues
                          # More retries waste time and money on bad requests
)

# Summary of content extracted from URL with tavily, applieed per each link
llm_url_content_summary = ChatOpenAI(
    model="gpt-4.1",  # BETTER CHOICE: Your original "gpt-4o" was budget-killer
                          # URL content analysis is mostly extraction/summarization
                          # GPT-4o-mini handles this 90% as well for 10% of the cost
                          # Save premium models for truly complex reasoning
    
    temperature=0.2,      # BEST: Factual analysis needs consistency, not creativity
                          # Prevents model from "making up" facts about content
                          # Ensures similar content gets similar analysis
    
    max_tokens=1500,      # GOOD: Enough for detailed analysis without waste
                          # Your original 1500 was excessive for most URL content
                          # Can capture key points without paying for verbosity
    
    top_p=0.95,          # GOOD: Slight randomness reduction for factual tasks
                          # Works with low temperature to ensure accuracy
                          # 0.95 allows some vocabulary variation while staying factual
    
    timeout=15,          # BETTER: Reduced from implicit 60s default
                          # Content analysis shouldn't take forever
                          # Faster feedback loop for debugging
)


# # generate persona
llm_class_generation = ChatOpenAI(
    model="gpt-4.1-mini",     # BETTER: Cheaper, perfectly capable for structured output
                             # Class generation is simple task, save budget
    
    temperature=0.2,         # BEST: Near-deterministic for consistent structure
                             # You want predictable field values
    
    max_tokens=1000,          # CORRECT: 3 fields with descriptions = ~50-80 tokens
                             # Prevents rambling, forces concise responses
    
    timeout=60,             # SUFFICIENT: Simple generation shouldn't take long
    
    max_retries=2           # ADEQUATE: Structured output usually works first try
)
# LengthFinishReasonError: Could not parse response content as the length limit was reached - CompletionUsage(completion_tokens=200, prompt_tokens=426, total_
# APITimeoutError: Request timed out.
# 4.0 mini replaced with 4.1 as it offers larger context allowing to simulate more experts


llm_hyde_generation = ChatOpenAI(
    model="gpt-4.1-mini",     # OPTIMAL: Cost-effective for creative writing
                             # Hyde articles don't need complex reasoning
                             # Good at generating diverse writing styles
    
    temperature=0.5,         # BEST: Creative variation for different journalist styles
                             # Each journalist should write distinctively
                             # Higher temp = more stylistic diversity
    
    max_tokens=500,          # CORRECT: 200-300 word articles need ~350-400 tokens
                             # Allows for complete thoughts and proper structure
                             # Prevents truncation mid-sentence
    
    timeout=60,             # ADEQUATE: Article generation needs more time than classes
                             # Creative writing takes longer than structured output
    
    max_retries=2           # SUFFICIENT: Article generation usually succeeds first try
)




# Applied for extract_evidence_claims, consolidates results from Multiple summaries
llm_agg_summaries = ChatOpenAI(
    model="gpt-4.1",       # CORRECT: You need the reasoning power here!
                          # Multi-document synthesis requires intelligence
                          # Finding connections across articles needs advanced reasoning
                          # 128K context window handles multiple long articles
                          # This is where you should spend your budget
    
    temperature=0.1,      # BEST: Even complex analysis should be consistent
                          # You want reliable insights, not creative interpretations
    
    max_tokens=3000,      # CORRECT: Complex multi-article analysis needs space
                          # Executive summaries of multiple sources require detail
                          # You need room for nuanced insights and connections
    
    top_p=0.95,          # GOOD: Allows sophisticated language while staying accurate
    
    timeout=45,          # INCREASED: Complex reasoning takes time
                          # Multi-document analysis can't be rushed
                          # 45s allows for thoughtful processing
    
    max_retries=3        # CORRECT: Complex tasks may need retries
                          # Network issues more likely with longer processing
)


# Model uses multiple summaries to make conclusion about possible risk 
llm_evaluation = ChatOpenAI( # compare to 4.o should have better instrusction following
    model="gpt-4.1",       
    temperature=0.2,                   
    max_tokens=3000,     
    #top_p=0.95,         
    timeout=1000,          
    max_retries=3        
)
# BadRequestError: Error code: 400 - {'error': {'message': "Unsupported parameter: 'top_p' is not supported with this model.", 
# 'type': 'invalid_request_error', 'param': 'top_p', 'code': 'unsupported_parameter'}}

## test gpt 5, takes signifficnt time, requires larger timeout
# result = llm_evaluation.invoke("Generate recommendations on how to prepare banana bread")



## we also need to generate names variations in different languages
llm_names_variation = ChatOpenAI(
    model="gpt-4.1-mini",   # note the hyphen
    temperature=0.0,        # pure extraction/translation
    timeout=30,
    max_retries=3,
    max_tokens=50          # we only need one short line
)

# %% [markdown]
# #### Variations of company names

# %%
## now genetate variation names 
import re
def generate_name_regex(company_name: str, llm) -> tuple[str, list[str], re.Pattern]:
    """
    Returns:
        pipe_line: "Original | Russian"
        parts: [Original, Russian]
        name_re: compiled regex matching either variant (case-insensitive)
    """
    prompt = f"""
    You are an expert at generating a single-line string of company name variants separated by '|'.

    OUTPUT FORMAT (choose exactly one based on spaces in the Original name):
    - If the Original name CONTAINS whitespace:
    <ORIGINAL_NAME>|<RUSSIAN_NAME>|<ORIGINAL_NO_SPACES>|<RUSSIAN_NO_SPACES>
    - If the Original name DOES NOT CONTAIN whitespace:
    <ORIGINAL_NAME>|<RUSSIAN_NAME>

    Rules:
    - ORIGINAL_NAME = the input company name verbatim (do not modify punctuation, casing, or suffixes).
    - RUSSIAN_NAME = a **transliteration/phonetic rewrite** of ORIGINAL_NAME into Cyrillic. **Do NOT translate any words** (brand words, common nouns, legal suffixes, country names, etc.). Only rewrite letters to approximate English pronunciation. If the input is already Cyrillic/Russian, repeat it verbatim. If unsure, copy the original as is.
    - ORIGINAL_NO_SPACES = ORIGINAL_NAME with ALL whitespace removed (preserve punctuation/casing). Include ONLY if the Original name contains whitespace.
    - RUSSIAN_NO_SPACES = RUSSIAN_NAME with ALL whitespace removed (preserve punctuation/casing). Include ONLY if the Original name contains whitespace.
    - Preserve hyphens, punctuation, and casing exactly where they appear in ORIGINAL_NAME.
    - Output MUST be exactly one line, no leading/trailing spaces, no extra spaces around '|', no quotes, no notes, no extra variants, no newlines.

    Original name: {company_name}
    """.strip()


    resp = llm.invoke(prompt)
    pipe_line = (getattr(resp, "content", "") or "").strip()

    # Parse "Original | Russian", fallback to original if needed
    parts = [p.strip() for p in pipe_line.split("|")]

    # Compile strict, case-insensitive pattern
    pattern_str = r"(?:%s)" % "|".join(map(re.escape, parts))
    name_re = re.compile(pattern_str, re.IGNORECASE)

    return parts, name_re


## test 
parts, name_re = generate_name_regex("Danube Logistics", llm_names_variation)
print("Variants:", parts)

tests = [
    "Our vendor is Danube Logistics for Q4.",
    "Our vendor is DANUBE LOGISTICS for Q4.",
    "our vendor is danube logistics for q4.",
    "Payment processed for DanubeLogistics yesterday.",
    "PAYMENT PROCESSED FOR DANUBELOGISTICS YESTERDAY.",
    "payment processed for danubelogistics yesterday.",
    "He said \"Danube Logistics\" will handle shipping.",
    "Contract signed with DanubeLogistics, terms apply.",
    "Partners — Danube Logistics — confirmed attendance.",
    "Client=DanubeLogistics; status=active.",
]

for i, s in enumerate(tests, 1):
    print(f"{i:02d}. {'MATCH' if name_re.search(s) else 'NO MATCH'} — {s}")
# Out:
# Variants: ['Danube Logistics', 'Данюб Лоджистикс', 'DanubeLogistics', 'ДанюбЛоджистикс']
# 01. MATCH — Our vendor is Danube Logistics for Q4.
# 02. MATCH — Our vendor is DANUBE LOGISTICS for Q4.
# 03. MATCH — our vendor is danube logistics for q4.
# 04. MATCH — Payment processed for DanubeLogistics yesterday.
# 05. MATCH — PAYMENT PROCESSED FOR DANUBELOGISTICS YESTERDAY.
# 06. MATCH — payment processed for danubelogistics yesterday.
# 07. MATCH — He said "Danube Logistics" will handle shipping.
# 08. MATCH — Contract signed with DanubeLogistics, terms apply.
# 09. MATCH — Partners — Danube Logistics — confirmed attendance.
# 10. MATCH — Client=DanubeLogistics; status=active.

# %% [markdown]
# #### Main classes for workflow

# %%
## Support for journalists and HyDe articles 

class Journalist(BaseModel):
    expertise: str = Field(
        description="Primary area of expertise and writing focus."
    )
    perspective: str = Field(
        description="Writing perspective and approach to the topic."
    )
    style: str = Field(
        description="Writing style, tone, and target audience."
    )

class HydePerspectives(BaseModel):
      journalists: List[ Journalist ] = Field( "Comprehensive list of analysts with their roles and affiliations." )

## test generation of personalitis 
journalist_instructions = """

You are creating exactly {max_journalists} AI journalist personas to analyze 
the SAME financial-crime topic from DIFFERENT, NON-OVERLAPPING angles for banking risk assessment.

Topic under investigation: {crime_topic}
Goal: Create persona of journalist which has solid experience in writing articles which occuses company over involement in  {crime_topic}.

OUTPUT FORMAT (MANDATORY)
- Return ONLY a valid HydePerspectives object with exactly {max_journalists} journalists.
- Each journalist has exactly these fields:
  - expertise (short phrase)
  - perspective (2-3 sentences)
  - style (6-10 adjectives/descriptors, comma-separated)
- No extra commentary, headings, or prose.

For each journalist:
- expertise: Their specific risk assessment specialization
- perspective: From what perspective they asses the impact of crime over diffenret economical or social aspects
- style: Their analytical approach to uncovering risks relevant to banking partnerships

UNIQUENESS REQUIREMENTS (MANDATORY)
- Pairwise distinct expertise (not just synonyms; avoid generic labels like “risk analyst”).
- Pairwise distinct perspectives (each must emphasize different indicators/decision criteria).
- style must contain 3–6 tokens; at least TWO tokens must be unique to that persona (not used by any other persona).
- Before returning, self-check all pairs. If any two personas substantially overlap in expertise keywords OR share >50% of style tokens OR rephrase the same perspective, REVISE and re-check.

COVERAGE & DIVERSITY (GUIDANCE, THEN ENFORCE UNIQUENESS)
- Distribute personas across different risk axes. Draw from (but are not limited to):
  • Regulatory/Enforcement (sanctions, consent orders, investigations)
  • Financial/Forensic flows (counterparties, anomalies, cash-intensity)
  • Operational/Governance/TPRM (controls, third parties, processes)
  • Reputational/Media/Stakeholders (controversy persistence, sentiment)
  • KYC/AML/BO/PEP/Sanctions screening (beneficial ownership transparency)
  • Correspondent banking & cross-border exposure
  • Data privacy/consumer protection
  
- If {max_journalists} ≥ 5, ensure at least one persona implicitly covers each of these example 
  archetypes (use them as inspiration; do NOT output role names, reflect them via fields only):
  1) Regulatory Compliance Analyst — statutory/enforcement exposure
  2) Financial Due Diligence Investigator — flows/counterparties/anomalies
  3) Operational Risk Assessor — governance/controls/third-party risk
  4) Reputational Risk Evaluator — media patterns/controversy persistence
  5) KYC/AML Specialist — KYC gaps/BO transparency/PEP & sanctions
- If {max_journalists} < 5, prioritize coverage in this order: KYC/AML → Regulatory → Financial.

FIELD WRITING RULES
- expertise: one crisp, specific phrase tied to the angle (no generic titles).
- perspective: 1–2 sentences listing the key indicators/thresholds/heuristics used to decide on partnership risk (e.g., “weights unresolved consent orders more than remedial plans”).
- style: 3–6 concise descriptors shaping tone/approach (e.g., “forensic, evidence-driven, regulation-centric, conservative”). Ensure ≥2 tokens unique to this persona.

Return ONLY the HydePerspectives object with exactly {max_journalists} journalists."""


#system_message = journalist_instructions.format( crime_topic = "money laundering" , max_journalists= 1)
#structured_llm = llm_class_generation.with_structured_output( HydePerspectives )

# populate values  
#journalists = structured_llm.invoke([SystemMessage(content=system_message)]+[HumanMessage(content="Generate the set of journalists according to instructions")])

# hasattr(journalists,"journalists")
#journalists.model_dump()

# %%
# Evidence Lineage tracking 
AllowedClaimType = Literal["allegation","investigation","charge","conviction","plea","fine","settlement","clearance","sanction_listing","other"]

class EvidenceClaim(BaseModel):
    """Track claims extracted from summaries - focused on consolidation"""
    claim_text: str = Field(description="Specific claim made (e.g., 'FinCEN fined company €50M in 2023')")
    claim_type: AllowedClaimType = Field(description="Each article must fit specific only 1 claim type") # should be generated during classification
    supporting_urls: List[str] = Field(description="ALL URLs that mention this claim")
    date_publish: str = Field(description=" Publication date or event date ")


class ClaimsFromSummaries( BaseModel ): 
    evidence_claims: List[EvidenceClaim] = Field(
    description="All extractable claims from the summaries"
      )

# Accountability: Every claim is traced to specific source
# Credibility: Check if the claim is supported by evidence
# Gap identification: We know what information is missing from the data
# Iteration: Check how many times we researched missing evidences

# %%
# Data and Meta for extracted content, per single link
class LinkCollection(BaseModel):
       displayLink: str = Field(description="The display URL shown in search results (usually domain name)")
       link: str = Field(description="The full URL of the search result")
       raw_content: str = Field(default="", description="Content extracted from URL")
       summary: str = Field(default="", description="Summary of content extracted from URL")
       claim_type: str = Field(default="other", description="Each article must fit specific only 1 claim type")
       date_published: Optional[str] = Field( default=None, description="Publication date extracted from content (format: YYYY-MM-DD, or 'Unknown' if not found)" )
       
       hyde_score: Optional[float] = Field(
        default=None,
        description="Max value of similarity between content of web page and HyDe articles"
    )
       
#ContentSummary (claim_type: AllowedClaimType) 
#    ↓ [extract/convert]
#LinkCollection (claim_type: str)       
       
# during article summarizations we generate both summary and assign specific claim  type    

class ContentSummary(BaseModel):
    claim_type: AllowedClaimType = Field(
        description="Primary financial crime classification from content"
    )

    date_published: Optional[str] = Field( default=None,
    description="Publication date extracted from content (format: YYYY-MM-DD, or 'Unknown' if not found)" )

    summary: str = Field(
        description="Detailed summary of financial crime/compliance information present in the content, or statement that no relevant information exists"
    )
    

## test structured output

url_summary_instructions = '''
You are analyzing RAW CONTENT extracted by Tavily to determine if it contains financial crime/compliance information.
Target entity: "{entity_name}"

TASK 1 - EXTRACT DATE (date_published field):
Find the publication date or event date in the content:
- Look for: publication date, article date, press release date, or event date
- Format as: YYYY-MM-DD (e.g., "2023-05-15")
- If multiple dates exist, prefer the publication date over event dates
- If no clear date is found, use: "Unknown"
- Common date locations: header, byline, footer, or first paragraph

TASK 2 - CLASSIFY (claim_type field):
Determine the PRIMARY claim type from the content:
- allegation: Unproven accusations or allegations of wrongdoing
- investigation: Active investigations, probes, or inquiries  
- charge: Formal criminal or civil charges filed
- conviction: Guilty verdicts, convictions, or findings of liability
- plea: Plea agreements, admissions, or guilty pleas
- fine: Monetary penalties, fines, or financial sanctions imposed
- settlement: Settlements, resolved cases, or negotiated agreements
- clearance: Exonerations, dismissals, or cases dropped/closed without findings
- sanction_listing: Sanctions designations, blacklisting, or regulatory listings
- other: Content has no financial crime information OR doesn't fit categories above

TASK 3 - SUMMARIZE (summary field):
Write a detailed factual summary of financial crime/compliance information found in the content.

SCOPE - Include ONLY if explicitly mentioned:
- AML/KYC/transaction monitoring deficiencies or failures
- Money laundering allegations, investigations, charges, or convictions
- Sanctions violations or sanctions-related issues
- Fraud, corruption, bribery, or embezzlement
- Tax evasion or tax-related crimes
- Securities violations or market manipulation
- Regulatory fines, penalties, or enforcement actions
- Court proceedings, settlements, or legal outcomes
- Compliance program failures or remediation efforts

RULES:
- Use ONLY information explicitly stated in RAW CONTENT - no inference or external knowledge
- Always mention "{entity_name}" in the summary if the entity appears in the content
- Include specific details: amounts, timeframes, jurisdictions, allegations, outcomes, remedial actions
- If content has NO financial crime/compliance information, write: "No financial crime or compliance information is present in the content."
- Summary can be multiple sentences if needed to capture important details
- Do NOT include the publication date in the summary - it goes in the date_published field
- RAW CONTENT may include boilerplate (menus/footers/headers), duplicated blocks, and unrelated 
    text—ignore such noise and extract/classify only substantive financial-crime content.


EXAMPLES:

Example 1 (detailed fine/settlement):
date_published: "2023-05-15"
claim_type: "fine"
summary: "FinCEN fined Danube Logistics €50M for AML violations during 2018-2020 related to inadequate transaction monitoring at Estonian branch operations. The settlement included Danube Logistics admitting to deficiencies in their compliance program. As part of the resolution, Danube Logistics agreed to retain an independent compliance monitor for two years and implement enhanced KYC procedures and high-risk counterparty screening."

Example 2 (investigation cleared):
date_published: "2024-01-10"
claim_type: "clearance"
summary: "DOJ closed an 18-month investigation into Danube Logistics regarding alleged sanctions violations related to transactions with embargoed entities. No charges were filed and Danube Logistics was cleared of all allegations. The investigation examined trade financing activities from 2020-2022."

Example 3 (no date found):
date_published: "Unknown"
claim_type: "investigation"
summary: "Prosecutors are conducting a money-laundering probe into Danube Logistics related to suspicious transactions processed between 2021-2022. The investigation involves alleged failures to file suspicious activity reports and inadequate customer due diligence. No formal charges have been filed yet."

Example 4 (irrelevant content):
date_published: "Unknown"
claim_type: "other"
summary: "No financial crime or compliance information is present in the content."

Remember: Extract ALL three fields. Focus on factual content from the text only.
'''

raw_content_1 = ''' Danube Logistics settles AML case with regulator
Publisher: Financial Times
Byline: FT Staff
Date: 2023-05-15

The National Financial Authority (NFA) announced that Danube Logistics agreed to pay a
€50,000,000 penalty to settle alleged anti-money laundering program deficiencies 
occurring between 2018 and 2020. According to the NFA’s statement, the settlement resolves 
findings related to inadequate transaction monitoring and delayed suspicious activity reporting. 
As part of the settlement, Danube Logistics will retain an independent 
compliance monitor for two years and complete a remedial program by Q4 2024. 
The company stated it has overhauled its KYC procedures since 2022 and enhanced screening of high-risk counterparties. 

No criminal charges were filed, and the NFA described the administrative 
matter as “resolved via settlement.” Danube Logistics did not admit or deny the findings.

'''

raw_content_2 = """Company town hall transcript

Welcome everyone to our Q2 product roadmap review. We’ll focus on UI improvements,
faster onboarding, and expanding to two new markets. The session covers customer
feedback and hiring plans for engineering and support. No mention of investigations,
fines, sanctions, legal cases, or compliance topics."""


system_message = url_summary_instructions.format( entity_name = "Danube Logistics")

structured_llm = llm_url_content_summary.with_structured_output( ContentSummary )

# populate values  
output = structured_llm.invoke([SystemMessage(content=system_message)]+
                               [HumanMessage(content=raw_content_2)])

# hasattr(journalists,"journalists")
print( output.model_dump() )
print(output.claim_type, output.summary , output.date_published)
# Out:
# {'claim_type': 'other', 'date_published': 'Unknown', 'summary': 'No financial crime or compliance information is present in the content.'}
# other No financial crime or compliance information is present in the content. Unknown

# %%
# Support of google search arguments 
class candidate_names(BaseModel):
       comp_names_variation: List[str] = Field(description="Different possible variations of company name")

class search_terms_extraction(BaseModel):
       or_terms: List[str] = Field(description="List of alternative terms and variations for OR search in the specified language")

# %%
# main state
class UnifiedResearchState(TypedDict):
    # From UnifiedResearchState
    messages: Annotated[List[AnyMessage], add_messages]
    search_results: List[LinkCollection]
    filtered_results: List[LinkCollection]
    entity_name: str
    expanded_query:str
    
    # From GenerateAnalystsState
    max_journalists: int
    journalists: List[Journalist]
    hyde_list: List[str]    

    # from evidence collection 
    evidence_claims: List[EvidenceClaim]

# %% [markdown]
# #### Supportive tools definition

# %%
## Function to generate different names of the company
llm_dummy = ChatOpenAI(
    model="gpt-4o-mini",  
    temperature=0.1,     
    max_tokens=100,       
    timeout=5,           
    max_retries=2   )      

entity_name = "Lukoil"

def extract_name_variations(prompt: str, llm, ln: str = "en") -> str:
    """Generate different variations of how a company name might appear in news articles"""
    
    language_mapping = {
        'en': 'English',
        'ru': 'Russian',
        'fr': 'French', 
        'ro': 'Romanian',
        'de': 'German'
    }
    
    full_language_name = language_mapping.get(ln.lower(), 'English')
    
    template = PromptTemplate(
        input_variables=["prompt", "language"],
        template='''
You are a text analysis expert. Extract the company name from this prompt: "{prompt}"
This name will be used as keywords used for google API, to make it focus only on 
sources which contain company name.

Generate 6-7 possible ways this company name could appear in news articles in {language}.


Consider:
1. Full official name with legal entity type (PJSC, LLC, Inc., etc.)
2. Shortened version without legal entity type
3. Common abbreviations or acronyms
4. Alternative spellings or transliterations
5. How it appears in headlines
6. Brand name vs legal name
7. Regional variations

Return ONLY a JSON array of name variations in {language}.
'''
    )
    
    structured_llm = llm.with_structured_output(candidate_names)
    chain = template | structured_llm
    response = chain.invoke({"prompt": prompt, "language": full_language_name})
    
    variations_list = response.comp_names_variation
    variations_list.append(prompt)
    
    return " ".join(variations_list)

# Usage:
result = extract_name_variations("Lukoil money laundering accusations", llm_dummy, ln="en")
print(result)
# Out:
# Lukoil PJSC Lukoil LUKOIL Lukoil Oil Company Lukoil Inc. Lukoil Group Lukoil Holdings Lukoil money laundering accusations

# %%
# define argument for google search 

def extract_orterms_from_query(search_query: str, llm, ln: str) -> str:
    """Extract relevant terms from search query for Google orTerms parameter in the specified language
    
    Args:
        search_query (str): The original search query
        llm: Language model instance
        ln (str): Language code ('en', 'ru', 'fr', 'ro', 'de')
        
    Returns:
        str: Space-separated string of OR terms in the specified language
    """
    
    # Language code to full name mapping
    language_mapping = {
        'en': 'English',
        'ru': 'Russian',
        'fr': 'French', 
        'ro': 'Romanian',
        'de': 'German'
    }
    
    # Get full language name or default to English
    full_language_name = language_mapping.get(ln.lower(), 'English')
    
    prompt = PromptTemplate(
        input_variables=["search_query", "language"],
        template='''
You are a search optimization expert. Analyze this search query and extract alternative terms that should be used in Google's orTerms parameter.

IMPORTANT: Generate ALL terms in {language} language. The response must be entirely in the specified language.

Original Query: "{search_query}"

Extract 6-10 alternative terms covering:
1. Company name variations (abbreviations, alternative spellings, transliterations), both in english and  {language}
2. Topic/subject variations (synonyms, related terms, technical terms)
3. Activity variations (different ways to describe the same concept)

For money laundering searches, consider terms like:
- Financial crimes, compliance violations, sanctions evasion
- AML violations, illicit finance, financial misconduct
- Regulatory violations, corruption, fraud

For company names, consider:
- Official names with/without legal entity types
- Common abbreviations, brand names
- Alternative spellings or transliterations

IMPORTANT: Keep each term SHORT - single words or very short phrases work best for OR logic.
CRITICAL: All terms must be in {language} language.

Example for English:
Query: "Search for news about Apple Inc related to tax evasion"
orTerms: ["Apple", "AAPL", "Apple-Inc", "tax-evasion", "tax-avoidance", "taxation", "fiscal", "treasury", "IRS", "revenue"]

Example for Romanian:
Query: "Căutați știri despre Apple Inc legate de evaziunea fiscală"
orTerms: ["Apple", "AAPL", "Apple-Inc", "evaziune-fiscală", "fraudă-fiscală", "taxare", "fiscal", "trezorerie", "venituri", "impozite"]

Example for Russian:
Query: "Поиск новостей об Apple Inc связанных с уклонением от налогов"
orTerms: ["Apple", "AAPL", "Apple-Inc", "уклонение-налогов", "налоговое-мошенничество", "налогообложение", "фискальный", "казначейство", "доходы", "налоги"]

Example for French:
Query: "Rechercher des nouvelles sur Apple Inc liées à l'évasion fiscale"
orTerms: ["Apple", "AAPL", "Apple-Inc", "évasion-fiscale", "fraude-fiscale", "taxation", "fiscal", "trésorerie", "revenus", "impôts"]

Example for German:
Query: "Suchen Sie nach Nachrichten über Apple Inc bezüglich Steuerhinterziehung"
orTerms: ["Apple", "AAPL", "Apple-Inc", "Steuerhinterziehung", "Steuerumgehung", "Steuervermeidung", "Steuerdelikte", "Steuerrecht", "Finanzbehörden", "Steuerprüfung", "Umsätze", "Gewinne", "Steuern"]

Query: "{search_query}"
Language: {language}

Generate ONLY a list of SHORT alternative terms as a JSON array of strings in {language} language.
        '''
    )
    
    structured_llm = llm.with_structured_output(search_terms_extraction)
    chain = prompt | structured_llm
    
    response = chain.invoke({
        "search_query": search_query, 
        "language": full_language_name
    })
    
    # Join the terms with spaces for orTerms parameter
    orterms_string = " ".join(response.or_terms)
    
    return orterms_string

# Usage examples:
# English
search_query = "Search for news and information about TESLA Company company related to money laundering."
orterms_for_search = extract_orterms_from_query(search_query, llm_translation_or_terms, "en")

print(f"Original query: {search_query}")
print(f"Generated orTerms: {orterms_for_search}")

# Romanian
#search_query = "Căutați știri și informații despre compania PJSC Lukoil Oil Company legate de spălarea banilor."
#orterms_for_search = extract_orterms_from_query(search_query, llm_translation_or_terms, "ro")

#print(f"Original query: {search_query}")
#print(f"Generated orTerms: {orterms_for_search}")

# Russian
#search_query = "Поиск новостей и информации о компании PJSC Lukoil Oil Company связанных с отмыванием денег."
#orterms_for_search = extract_orterms_from_query(search_query, llm_translation_or_terms, "ru")

#print(f"Original query: {search_query}")
#print(f"Generated orTerms: {orterms_for_search}")

# French
#search_query = "Rechercher des nouvelles et informations sur la société PJSC Lukoil Oil Company liées au blanchiment d'argent."
#orterms_for_search = extract_orterms_from_query(search_query, llm_translation_or_terms, "fr")

#print(f"Original query: {search_query}")
#print(f"Generated orTerms: {orterms_for_search}")

# German
#search_query = "Suchen Sie nach Nachrichten und Informationen über die Gesellschaft PJSC Lukoil Oil Company im Zusammenhang mit Geldwäsche."
#orterms_for_search = extract_orterms_from_query(search_query, llm_translation_or_terms, "fr")

#print(f"Original query: {search_query}")
#print(f"Generated orTerms: {orterms_for_search}")
# Out:
# Original query: Search for news and information about TESLA Company company related to money laundering.
# Generated orTerms: Tesla Tesla Inc Tesla Motors TSLA money laundering financial crimes AML violations illicit finance financial misconduct fraud corruption regulatory violations sanctions evasion

# %%
## Function to translate query 
## payload will be adjusted to the language but we also need to aligh language of request 

def translate_query_for_search(query: str, target_lang: str, llm_instance) -> str:
    """
    Translate search query to target language
    
    Args:
        query: Original search query
        target_lang: Target language code (en, ru, fr, ro, de)
        llm_instance: LLM instance for translation
        
    Returns:
        Translated query string
    """
    language_names = {
        "en": "English","ru": "Russian", "fr": "French","ro": "Romanian","de":"German"
    }

    target_language = language_names[target_lang]

    translation_prompt = f"""Translate this search query to {target_language}. 
                            Keep it concise and search-engine friendly.
                            Keep company names in their original form (do not translate company names)
                            Use semantically correct terms for fraud, corruption, and reputation-related concepts
                            Only return the translated query, nothing else:

    Query: {query}

    Translation:"""
        
    try:
        response = llm_instance.invoke(translation_prompt)
        translated = response.content.strip() if hasattr(response, 'content') else str(response).strip()
        print(f"Translated '{query}' -> '{translated}' ({target_language})")

        return translated
    
    except Exception as e:
        print(f"Translation error: {e}. Using original query.")
        return query
    

result = translate_query_for_search(" Information on Money laundering by Lukoil company " , "de" , llm_translation_or_terms)
result
# Out:
# Translated ' Information on Money laundering by Lukoil company ' -> 'Informationen zur Geldwäsche durch Lukoil Unternehmen' (German)
# 'Informationen zur Geldwäsche durch Lukoil Unternehmen'

# %% [markdown]
# ####  Google tool definition

# %%
### test google api to simulate bad request error 
# https://developers.google.com/custom-search/v1/reference/rest/v1/cse/list

api_key = api_google
cse_id = SEARCH_ENGINE_ID

service = build("customsearch", "v1", developerKey=api_key)

result = service.cse().list(
            q="Lukoil Money Laundering",
            cx=cse_id, # search engine name defined in the console 
            dateRestrict='y2',  # Agent customizable
            start=1,
            filter='1', # turn on duplicated filter content 
            hl='en', # Agent customizable - user interface language
            lr='en',  # Agent customizable - language of content             
            num=2, # 10 i smax value
            safe='off',
            orTerms='Lukoil', # if incorrectly specified returned dsearch object may not contain classes
            
            siteSearch='en.wikipedia.org',  # Agent customizable - Wikipedia language version
            siteSearchFilter="e"  # Exclude Wikipedia
        ).execute()

result
# Out:
# {'kind': 'customsearch#search',
#  'url': {'type': 'application/json',
#   'template': 'https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json'},
#  'queries': {'request': [{'title': 'Google Custom Search - Lukoil Money Laundering',
#     'totalResults': '19700',
#     'searchTerms': 'Lukoil Money Laundering',
#     'count': 2,
#     'startIndex': 1,
#     'language': 'en',
#     'inputEncoding': 'utf8',
#     'outputEncoding': 'utf8',
#     'safe': 'off',
#     'cx': '26dda816634bd4044',
#     'filter': '1',
#     'hl': 'en',
#     'siteSearch': 'en.wikipedia.org',
#     'siteSearchFilter': 'e',
#     'orTerms': 'Lukoil',
#     'dateRestrict': 'y2'}],
#   'nextPage': [{'title': 'Google Custom Search - Lukoil Money Laundering',
#     'totalResults': '19700',
#     'searchTerms': 'Lukoil Money Laundering',
#     'count': 2,
#     'startIndex': 3,
#     'language': 'en',
#     'inputEncoding': 'utf8',
#     'outputEncoding': 'utf8',
#     'safe': 'off',
#     'cx': '26dda816634bd4044',
#     'filter': '1',
#     'hl': 'en',
#     'siteSearch': 'en.wikipedia.org',
#     'siteSearchFilter': 'e',
#     'orTerms': 'Lukoil',
#     'dateRestrict': 'y2'}]},
#  'context': {'title': 'engine_google_test_1'},
#  'searchInformation': {'searchTime': 0.219596,
#   'formattedSearchTime': '0.22',
#   'totalResults': '19700',
#   'formattedTotalResults': '19,700'},
#  'items': [{'kind': 'customsearch#result',
#    'title': 'Treasury Sanctions Major Russian Oil Companies, Calls on Moscow ...',
#    'htmlTitle': 'Treasury Sanctions Major Russian Oil Companies, Calls on Moscow ...',
#    'link': 'https://home.treasury.gov/news/press-releases/sb0290',
#    'displayLink': 'home.treasury.gov',
#    'snippet': 'Oct 22, 2025 ... Money Laundering · Financial Action Task Force · Protecting Charitable ... Lukoil (Lukoil), which are now designated. Rosneft is a vertically integrated\xa0...',
#    'htmlSnippet': 'Oct 22, 2025 <b>...</b> <b>Money Laundering</b> &middot; Financial Action Task Force &middot; Protecting Charitable ... <b>Lukoil</b> (<b>Lukoil</b>), which are now designated. Rosneft is a vertically integrated&nbsp;...',
#    'formattedUrl': 'https://home.treasury.gov/news/press-releases/sb0290',
#    'htmlFormattedUrl': 'https://home.treasury.gov/news/press-releases/sb0290',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ-91IfwYYNnVbB_SsWhMb954aObHlbTxojgkmXpbpy7fdA3rsWflH3E6el&s',
#       'width': '318',
#       'height': '159'}],
#     'metatags': [{'og:image': 'https://home.treasury.gov/system/files/291/treasury-preview-1900x950.jpg',
#       'og:type': 'article',
#       'og:image:width': '1900px',
#       'og:image:alt': 'U.S. Department of the Treasury',
#       'twitter:card': 'summary_large_image',
#       'twitter:title': 'Treasury Sanctions Major Russian Oil Companies, Calls on Moscow to Immediately Agree to Ceasefire',
#       'og:site_name': 'U.S. Department of the Treasury',
#       'handheldfriendly': 'true',
#       'og:title': 'Treasury Sanctions Major Russian Oil Companies, Calls on Moscow to Immediately Agree to Ceasefire',
#       'og:image:height': '950px',
#       'twitter:image:height': '1080',
#       'og:image:type': 'image/jpeg',
#       'og:updated_time': '2025-10-24',
#       'og:description': 'WASHINGTON — Today, the U.S. Department of the Treasury’s Office of Foreign Assets Control (OFAC) is imposing further sanctions as a result of Russia’s lack of serious commitment to a peace process to end the war in Ukraine.\xa0 Today’s actions increase pressure on Russia’s energy sector and degrade the Kremlin’s ability to raise revenue for its war machine and support its weakened economy.\xa0The United States will continue to advocate for a peaceful resolution to the war, and a permanent peace depends entirely on Russia’s willingness to negotiate in good faith. Treasury will continue to use its authorities in support of a peace process.“Now is the time to stop the killing and for an immediate ceasefire,” said Secretary of the Treasury Scott Bessent.\xa0 “Given President Putin’s refusal to end this senseless war, Treasury is sanctioning Russia’s two largest oil companies that fund the Kremlin’s war machine. Treasury is prepared to take further action if necessary to support President Trum',
#       'twitter:image': 'https://home.treasury.gov/system/files/291/treasury-preview-1080x1080.jpg',
#       'twitter:image:alt': 'U.S. Department of the Treasury',
#       'twitter:site': '@USTreasury',
#       'twitter:image:width': '1080',
#       'viewport': 'width=device-width, initial-scale=1.0',
#       'mobileoptimized': 'width',
#       'og:url': 'https://home.treasury.gov/news/press-releases/sb0290'}],
#     'cse_image': [{'src': 'https://home.treasury.gov/system/files/291/treasury-preview-1900x950.jpg'}]}},
#   {'kind': 'customsearch#result',
#    'title': 'UK Sanctions - Rosneft, Lukoil and others | Trade Compliance ...',
#    'htmlTitle': 'UK Sanctions - Rosneft, <b>Lukoil</b> and others | Trade Compliance ...',
#    'link': 'https://www.tradecomplianceresourcehub.com/2025/10/15/uk-sanctions-rosneft-lukoil-and-others/',
#    'displayLink': 'www.tradecomplianceresourcehub.com',
#    'snippet': "Oct 15, 2025 ... PJSC Lukoil. In some regards, these designations mirror the intent of ... Emerging money laundering risks in the UK's clothing and retail sectors. July\xa0...",
#    'htmlSnippet': 'Oct 15, 2025 <b>...</b> PJSC <b>Lukoil</b>. In some regards, these designations mirror the intent of ... Emerging <b>money laundering</b> risks in the UK&#39;s clothing and retail sectors. July&nbsp;...',
#    'formattedUrl': 'https://www.tradecomplianceresourcehub.com/.../uk-sanctions-rosneft-lukoi...',
#    'htmlFormattedUrl': 'https://www.tradecomplianceresourcehub.com/.../uk-sanctions-rosneft-<b>lukoi</b>...',
#    'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQqv_RHwoTmLS6qcZiGrD-pJ56PzMeTRa7LKJLzDWk54As-JRt0vpLhOOQ6&s',
#       'width': '310',
#       'height': '163'}],
#     'metatags': [{'og:image': 'https://www.tradecomplianceresourcehub.com/wp-content/uploads/sites/63/2023/04/opengraph.jpg',
#       'og:type': 'article',
#       'article:published_time': '2025-10-15T13:52:50+00:00',
#       'og:image:width': '1200',
#       'twitter:card': 'summary_large_image',
#       'og:site_name': 'Trade Compliance Resource Hub',
#       'author': 'Leigh T. Hansson, Alexander Brandt, James Willn, Ray-Shio Ho, William Young, Stephan Johansen, Tan Albayrak, Finlay Donaldson, Dimitris Athanasopoulos, Banu Hilalqizi',
#       'og:title': 'UK Sanctions - Rosneft, Lukoil and others\xa0',
#       'og:image:height': '630',
#       'og:image:type': 'image/jpeg',
#       'msapplication-tileimage': 'https://www.tradecomplianceresourcehub.com/wp-content/uploads/sites/63/2023/02/cropped-RSTwitterAvatar_512x512-270x270.jpg',
#       'og:description': 'In continuation of the UK’s sanctions restrictions against Russia, on 15 October 2025, the UK imposed further sanctions on various entities and vessels.',
#       'article:modified_time': '2025-10-15T13:53:38+00:00',
#       'viewport': 'width=device-width, initial-scale=1',
#       'og:locale': 'en_US',
#       'og:url': 'https://www.tradecomplianceresourcehub.com/2025/10/15/uk-sanctions-rosneft-lukoil-and-others/'}],
#     'cse_image': [{'src': 'https://www.tradecomplianceresourcehub.com/wp-content/uploads/sites/63/2023/04/opengraph.jpg'}]}}]}

# %%
# search result is stored in items key
# it does not contain the publication date of the article/news. 
if 'items' in result:
    for elem in result["items"]:
        print(elem.get('displayLink') )
# Out:
# home.treasury.gov
# www.tradecomplianceresourcehub.com

# %%
# Message for llm to create payload 
system_message_google_search = SystemMessage(content="""
                                             
You are a multi-language search assistant. When asked to search for information, 
call the google_search tool ONCE for EACH of these 5 languages:

1. **Romanian** (ro):
   - hl="ro" (Romanian interface)
   - lr="lang_ro" (Romanian content)
   - wikipedia_lang="ro" (exclude Romanian Wikipedia)

2. **English** (en):
   - hl="en" (English interface)  
   - lr="lang_en" (English content)
   - wikipedia_lang="en" (exclude English Wikipedia)

3. **Russian** (ru):
   - hl="ru" (Russian interface)
   - lr="lang_ru" (Russian content) 
   - wikipedia_lang="ru" (exclude Russian Wikipedia)

4. **French** (fr):
   - hl="fr" (French interface)
   - lr="lang_fr" (French content)
   - wikipedia_lang="fr" (exclude French Wikipedia)
                            
5. **German** (de):
   - hl="de" (German interface)
   - lr="lang_de" (German content)
   - wikipedia_lang="de" (exclude German Wikipedia)

IMPORTANT: Make exactly 10 tool calls (one per language). 
For each call, use num_results = 10 to retrieve 10 search results per language.
Use dateRestrict="y2" (last year) for recent information.

"""
)

# %%
# common error BadRequestError: Max 20 URLs are allowed.
# https://developers.google.com/custom-search/v1/reference/rest/v1/cse/list#try-it 

## define function for tool schema
def google_search(query,  num_results = 5, hl="en", lr="lang_en", dateRestrict="y2", wikipedia_lang="en"):

    """
    Search Google using Custom Search API with configurable parameters.
    
    This function performs Google searches and returns structured results including titles, URLs, and snippets.
    The agent can customize language settings, time restrictions, and Wikipedia language exclusions to optimize search results for specific needs.
    
    Parameters:
    -----------
    query : str
        The search query string to execute
    api_key : str  
        Google Custom Search API key
    cse_id : str
        Google Custom Search Engine ID
        
    Agent Customizable Parameters:
    -----------------------------

    num_results : int, always included and defined by user
    Number of results to return (default: 5, max: 10 per API call), Value must not exceed 10, NOT customisable

    hl : str, always included (default: "en")
        Interface language - controls UI language and affects search quality
        Examples: "en", "ru", "de", "fr","ro"
        
    lr : str, always included (default: "lang_en") 
        Content language restriction - filters results by document language
        Examples: "lang_en", "lang_ru", "lang_de", "lang_fr","lang_ro"
        
    dateRestrict : str, always included (default: "d365")
        Time-based filtering for results freshness
        Examples: "d1" (past day), "w1" (past week), "m1" (past month), 
                 "m3" (past 3 months), "m6" (past 6 months), "y1" (past year)
    
    wikipedia_lang : str, always included (default: "en")
        Wikipedia language version to exclude from results
        Possible values: "en" (English), "ru" (Russian), "fr" (French), "ro" (Romanian), "de" (German)
        Maps to domains: en.wikipedia.org, ru.wikipedia.org, fr.wikipedia.org, ro.wikipedia.org, de.wikipedia.org
    
    Returns:
    --------
    list
        List of dictionaries containing search results with keys:
        - 'title': Result title
        - 'link': Result URL  
        - 'snippet': Result description/excerpt
        - Additional metadata from Google API
        
    Example Agent Usage:
    -------------------
    # For Russian content excluding Russian Wikipedia
    results = google_search(query, api_key, cse_id, hl="ru", lr="lang_ru", dateRestrict="y3", wikipedia_lang="ru")
    
    # For French content excluding French Wikipedia
    results = google_search(query, api_key, cse_id, hl="fr", lr="lang_fr", dateRestrict="y3", wikipedia_lang="fr")
    
    # For Romanian content excluding Romanian Wikipedia
    results = google_search(query, api_key, cse_id, hl="ro", lr="lang_ro", dateRestrict="y3", wikipedia_lang="ro")

    # For German content excluding German Wikipedia
    results = google_search(query, api_key, cse_id, hl="de", lr="lang_de", dateRestrict="y3", wikipedia_lang="de")

     # For English content excluding English Wikipedia
    results = google_search(query, api_key, cse_id, hl="en", lr="lang_en", dateRestrict="y3", wikipedia_lang="en")

    """

    print("Executing google_search_payload ...")

    api_key = api_google
    cse_id = SEARCH_ENGINE_ID

    service = build("customsearch", "v1", developerKey=api_key)
    
    # Map language codes to Wikipedia domains
    wikipedia_domains = {
        "en": "en.wikipedia.org",
        "ru": "ru.wikipedia.org", 
        "fr": "fr.wikipedia.org",
        "ro": "ro.wikipedia.org",
        "de": "de.wikipedia.org"
    }
    
    wikipedia_site = wikipedia_domains.get(wikipedia_lang, "en.wikipedia.org")
    
    ## store search results 
    all_results = []
   
    ## query language must be aligned with search parameters
    translated_query = translate_query_for_search(query , hl , llm_translation_or_terms)

    ## orterms
    #orterms_for_search = extract_orterms_from_query(translated_query, orterms_for_search, hl )
    orterms_for_search = extract_name_variations(translated_query, llm_translation_or_terms, hl)
    print("Additional search terms: " , orterms_for_search)
    

    try:
        result1 = service.cse().list(
            q=translated_query,
            cx=cse_id, # search engine name defined in the console 
            dateRestrict=dateRestrict,  # Agent customizable
            start=1,
            filter='1', # turn on duplicated filter content 
            hl=hl, # Agent customizable - user interface language
            lr=lr,  # Agent customizable - language of content             
            num=num_results, 
            orTerms=orterms_for_search, # each document must contain at least one of the additional terms 
            safe='off',
            siteSearch=wikipedia_site,  # Agent customizable - Wikipedia language version
            siteSearchFilter="e"  # Exclude Wikipedia
        ).execute()
        
        if 'items' in result1:
                # Extract only relevant information from each result
                filtered_items = []
                for item in result1['items']:
                    essential_data = {
                        'query':translated_query,
                        'title': item.get('title', ''),
                        'link': item.get('link', ''),
                        'snippet': item.get('snippet', ''),
                        'displayLink': item.get('displayLink', '')
                    }
                    filtered_items.append(essential_data)

                all_results.extend(filtered_items)
    
    except Exception as e:
        print(f"Error getting results: {e}")

    print("Executing google_search_payload DONE ")    

    return all_results

# %%
## Test function 
tool_google_search = StructuredTool.from_function( google_search, name = "google_search" )

entity_name = "Lukoil"
query = f"{entity_name} money laundering compliance violations investigations"

# join instructions and entity name
messages = [ system_message_google_search ,  HumanMessage(content=query) ]

## create list of tools, which be called externally with  tool_call['args']
tools = [ tool_google_search  ]
tools_by_name = {tool.name:tool for tool in tools}

# bind first tool to 4o mnodel
llm_with_tools = llm_payload.bind_tools(tools)

# test tool call without payload 
#payload = llm_with_tools.invoke( messages )

# %%
## check payload values
#for tool_call in payload.tool_calls:
#    print(f"Tool: {tool_call['name']}")
#    print(f"ID: {tool_call['id']}")
#    print(f"Args: {tool_call['args']}")
#    print("---")

# %%
# run the function  using single payload
#tool_call = payload.tool_calls[0]
#tool_google_search.invoke( tool_call['args'] )
#print("##-----------------##")

## Now run through app payloads  
#for tool_call in payload.tool_calls: # AI message with payload , last ai message with too l calls
#        tool = tools_by_name[tool_call["name"]]
#        observations = tool.invoke(tool_call["args"])
#        print(observations)

# %%
## Dummy unified state

dummy_state = UnifiedResearchState(
    {
        "messages": [HumanMessage(content = "Lukoil" ) ]   
    }   
)

# %%
## Node to create payload for the tool
def llm_node(state: UnifiedResearchState):
    """LLM node that generates tool calls"""
    print("Executing llm_node...")
    
    # Get the last message from state
    entity_name  = state["messages"][-1] # human message
    query = f"{entity_name.content} money laundering criminal activity"
    
    ## modified content 
    human_message_updated = HumanMessage(content=query, id=entity_name.id)
    print("Updated human message: " , human_message_updated.content)

    ## Replace content of the original human imput 
    system_message = system_message_google_search

    messages = [ system_message ,  human_message_updated ]
    
    # Call LLM with tools to generate ai message
    response = llm_with_tools.invoke( messages )
    #print(f"LLM response: {response}")
    #print("State fields " , state)
    
    # return all up to last message, replace last human input , company name(for prompts), expanded query for debugging in English
    return {"messages": state["messages"][:-1] + [human_message_updated, response], "entity_name": entity_name.content , "expanded_query":query }

#print("Test Results: ")
#dummy_state = llm_node(dummy_state) 
#print( dummy_state )

#for msg in dummy_state.get('messages'):
#    if isinstance(msg, AIMessage):
#        for msg_tool  in msg.tool_calls:
#            print(msg_tool.get("args"))

# after payload is populated to AI messages we need to pass args to funcntion
# below implemented sequentially

# %%
## google search tool execution and allocation of seatch results
def tool_node_chunk_selection_exec(state: UnifiedResearchState):
    """Performs the tool call"""
    print("Executing tool_node_chunk_selection_exec...")
    
    result = []
    link_collections = []

    for tool_call in state["messages"][-1].tool_calls: # AI message with payload , last ai message with too l calls
        tool = tools_by_name[tool_call["name"]] # select tool
        observation = tool.invoke(tool_call["args"]) # paste arguments to the tool 
           
        result.append(ToolMessage( # messages are returned by google api not all generated
                       content = observation, 
                       tool_call_id=tool_call["id"] , 
                       name = tool_call['name']))    
        
        # Extract LinkCollection data from observation
        for item in observation:
            if isinstance(item, dict):
                # Check if required keys exist
                if 'displayLink' in item and 'link' in item:
                    link_collection = LinkCollection(
                        displayLink=item['displayLink'],
                        link=item['link']
                    )
                    link_collections.append(link_collection)
                else:
                    # This will only print for items that are missing keys
                    available_keys = list(item.keys())
                    print(f"Item missing required keys. Available keys: {available_keys}")
                    print(f"Item content: {item}")
            else:
                print(f"Item is not a dict, it's: {type(item)}")
        
    # we need to populate LinkCollection class and store in  search_results 

    print("Executing tool_node_chunk_selection_exec END")
    return {"messages": result , "search_results":link_collections }   

print("Test case: ")
#tool_node_chunk_selection_exec(dummy_state)
#output = tool_node_chunk_selection_exec(dummy_state)
# Out:
# Test case:

# %%
## check classes to store initial link data 
#for attr in output.get("search_results")[0]:
#    print(attr)

# %%
## function to display flow using cli

def render_mermaid_graph(mermaid_code, output_filename='graph.png', width=700, height=700, cleanup=True):
    """
    Render Mermaid diagram using CLI and display in Jupyter
    """
    # Create temporary mermaid file
    temp_mmd = output_filename.replace('.png', '.mmd').replace('.svg', '.mmd').replace('.pdf', '.mmd')
    
    try:
        # Write mermaid code to file
        with open(temp_mmd, 'w', encoding='utf-8') as f:
            f.write(mermaid_code)
        
        # Build command based on output format
        # Use the Windows .cmd version
        cmd = [
            'C:\\Users\\Admin\\AppData\\Roaming\\npm\\mmdc.cmd',  # Full path to Windows version
            '-i', temp_mmd,
            '-o', output_filename,
            '-w', str(width),
            '-H', str(height)
        ]
        
        # Add size parameters only for PNG/PDF
        if output_filename.endswith(('.png', '.pdf')):
            cmd.extend(['-w', str(width), '-H', str(height), '--scale', '2'])
        
        result = subprocess.run(cmd, capture_output=True, text=True) # we simulate running command like
        
        if result.returncode == 0:
            print(f"Graph rendered successfully: {output_filename}")
            try:
                display(Image(output_filename))
            except:
                print(f"Image saved to {output_filename} but could not display inline")
            return True
        else:
            print(f"Mermaid CLI error: {result.stderr}")
            return False
            
    except FileNotFoundError:
        print("Mermaid CLI not found. Install with: npm install -g @mermaid-js/mermaid-cli")
        return False
    except Exception as e:
        print(f"Error rendering graph: {e}")
        return False
    finally:
        if cleanup and os.path.exists(temp_mmd):
            os.remove(temp_mmd)

# %% [markdown]
# #### Prepare Tavily for content extraction

# %%
## Generate summary of extracted content

#current approach uses multiple parallel function calls
# function process 1 link 
def generate_url_summary(raw_content: str, llm, entity_name: str, thread_outcomes: dict, url: str):
    
    """
    Generate a focused summary of raw content with emphasis on company reputation 
    and criminal activity using dedicated LLM.
    
    Args:
        raw_content: Text content to analyze
        llm: Language model instance for processing
        entity_name: Company name for context
        thread_outcomes: used to aggregate outputs of paralles processes
        url: used as a key 
        
    Returns:
        threadding is applied , no result returned
        
    """
    
    print(f"Thread for {url} starting...")

    
     # Input validation
    if not raw_content or not raw_content.strip():
        thread_outcomes[url] = "Error: No content provided for analysis"
        print(f"No content found for {url} ")
        return
    
    # Truncate content if too long (prevent token limit issues)
       # skipped, tavily uses  def first_n_words(text: str, n: int) -> str:
    # url_summary_instructions is defined in Main Classes section 
    # now we need  to populate class with date, summary and intent classification  
    #  
    try:
        system_message = url_summary_instructions.format( entity_name = entity_name )
        structured_llm = llm.with_structured_output( ContentSummary )

        # populate values  
        response = structured_llm.invoke([SystemMessage(content=system_message)]+
                                         [HumanMessage(content=raw_content)])
        # contains 3 attributes claim_type, summary , date_published
        # ex. ContentSummary(claim_type='other', date_published='Unknown', summary='No financial crime or compliance information is present in the content.')
        print(response)

         # Validate response
        if not response or not hasattr(response, 'summary'):
            thread_outcomes[url] = "Error: Invalid response from language model"
            return
        
        thread_outcomes[url] = response
        
    except Exception as e:
        # More specific error handling
        error_msg = f"Error generating reputation summary: {str(e)}"
        print(error_msg)  # For debugging
        thread_outcomes[url] = "Error: Could not generate reputation summary due to processing issues"
        return 


# Fixed test call
url_to_raw_content = {
    # allegation
    "https://news.example.com/article/allegation": """Publisher: Market Watch Europe
Date: 2025-01-12
Reporters alleged that Danube Logistics facilitated questionable cash-intensive shipments through third-party brokers in 2023. The article cites unnamed sources and notes no official filings or agency statements. Legal status not confirmed; allegations only.""",

    # investigation
    "https://regulator.example.gov/notices/inquiry-2025-02": """Publisher: National Financial Authority
Date: 2025-02-05
The NFA announced it has opened an investigation into Danube Logistics regarding potential AML/KYC monitoring deficiencies in 2022–2024 cross-border transfers. No fines or charges are imposed at this stage; the probe is ongoing.""",

    # charge
    "https://court.example.org/dockets/indictment-24-771": """Publisher: District Court Bulletin
Date: 2024-11-18
Prosecutors filed criminal charges against a Danube Logistics regional manager for alleged structuring and false statements. The indictment specifies three counts; the company itself is not charged. Arraignment is scheduled next month.""",

    # conviction
    "https://court.example.org/verdicts/2025-03-14": """Publisher: District Court Bulletin
Date: 2025-03-14
A jury convicted a former Danube Logistics contractor on two counts of money laundering tied to 2021 transactions. The order notes no finding against Danube Logistics as a corporate entity. Sentencing set for May.""",

    # plea
    "https://justice.example.gov/releases/plea-agreement-2024-10-02": """Publisher: Ministry of Justice
Date: 2024-10-02
A former operations lead at Danube Logistics entered a guilty plea to one count of failing to file required reports. The plea agreement includes cooperation and a recommended fine; the filing does not charge the company.""",

    # fine
    "https://nfa.example.gov/enforcement/actions/2025-04-20": """Publisher: National Financial Authority
Date: 2025-04-20
The NFA fined Danube Logistics €12,500,000 for AML program deficiencies related to delayed suspicious activity reporting in 2022. The civil penalty order cites inadequate alert tuning and training gaps.""",

    # settlement
    "https://newswire.example.com/releases/settlement-announce": """Publisher: Financial Times
Date: 2023-05-15
Danube Logistics reached a settlement resolving an administrative AML matter with the NFA, agreeing to pay €50,000,000 and retain an independent monitor for two years. The company did not admit or deny the findings; no criminal charges were filed.""",

    # clearance
    "https://regulator.example.gov/notices/closure-2025-06": """Publisher: National Financial Authority
Date: 2025-06-09
Following review, the NFA closed its investigation into Danube Logistics with no enforcement action. The notice states that evidence was insufficient to support alleged violations and the matter is dismissed.""",

    # sanction_listing
    "https://sanctions.example.gov/updates/listing-2024-09-28": """Publisher: Ministry of Finance — Sanctions Directorate
Date: 2024-09-28
The Sanctions Directorate listed Danube Logistics Trading FZE on the national sanctions list for involvement in evasion schemes. The designation imposes asset freezes and prohibits transactions with listed parties.""",

    # other (irrelevant/neutral ops update)
    "https://blog.example.org/posts/ops-expansion": """Publisher: Logistics Today
Date: 2025-03-02
Danube Logistics announced a 40,000 m² distribution center with automated sortation and cold-chain capacity, plus 120 new jobs. The post discusses sustainability features and scheduling software. No legal or compliance topics are mentioned.""",

    "https://blog.example.org/DUMMY" : 'weather in scotland'
}


thread_outcomes = {}

# now trreading
threads = []
entity_name = "Danube Logistics" 

for url, raw_content in url_to_raw_content.items():
    t = threading.Thread( 
        target = generate_url_summary ,
        args = ( raw_content, llm_url_content_summary, entity_name, thread_outcomes, url )
     )
    threads.append(t)

for thread in threads:
    thread.start() 

for thread in threads:
    t.join()
# Out:
# Thread for https://news.example.com/article/allegation starting...
# Thread for https://regulator.example.gov/notices/inquiry-2025-02 starting...
# Thread for https://court.example.org/dockets/indictment-24-771 starting...
# Thread for https://court.example.org/verdicts/2025-03-14 starting...
# Thread for https://justice.example.gov/releases/plea-agreement-2024-10-02 starting...
# Thread for https://nfa.example.gov/enforcement/actions/2025-04-20 starting...
# Thread for https://newswire.example.com/releases/settlement-announce starting...
# Thread for https://regulator.example.gov/notices/closure-2025-06 starting...
# Thread for https://sanctions.example.gov/updates/listing-2024-09-28 starting...
# Thread for https://blog.example.org/posts/ops-expansion starting...
# Thread for https://blog.example.org/DUMMY starting...
# claim_type='other' date_published='Unknown' summary='No financial crime or compliance information is present in the content.'

# %%
#thread_outcomes
#thread_outcomes['https://regulator.example.gov/notices/closure-2025-06'].claim_type

# %%
# test extraction 
tavily_client = TavilyClient(api_key=tavily_api)
url = 'https://www.ebrd.com/home/news-and-events/news/2023/ebrd-will-appeal-imposed-external-administration-of-assets-of-moldovas-danube-logistics-srl.html'
output = tavily_client.extract(urls=url, extract_depth='advanced', format = 'markdown')
# Out:
# claim_type='other' date_published='2025-03-02' summary='No financial crime or compliance information is present in the content.'
# claim_type='plea' date_published='2024-10-02' summary='A former operations lead at Danube Logistics entered a guilty plea to one count of failing to file required reports. The plea agreement includes cooperation and a recommended fine. The filing does not charge Danube Logistics as a company.'
# claim_type='investigation' date_published='2025-02-05' summary='The National Financial Authority has opened an investigation into Danube Logistics concerning potential AML/KYC monitoring deficiencies related to cross-border transfers conducted between 2022 and 2024. No fines or charges have been imposed at this stage, and the probe is ongoing.'
# claim_type='charge' date_published='2024-11-18' summary='Prosecutors filed criminal charges against a Danube Logistics regional manager for alleged structuring and false statements. The indictment includes three counts. Danube Logistics as a company is not charged in this case. Arraignment for the individual is scheduled for next month.'
# claim_type='settlement' date_published='2023-05-15' summary='Danube Logistics reached a settlement with the NFA regarding an administrative anti-money laundering (AML) matter. As part of the settlement, Danube Logistics agreed to pay €50,000,000 and retain an independent monitor for two years. The company did not admit or deny the findings, and no criminal charges were filed.'
# claim_type='allegation' date_published='2025-01-12' summary='Reporters alleged that Danube Logistics facilitated questionable cash-intensive shipments through third-party brokers in 2023. The article is based on unnamed sources and notes that there are no official filings or agency statements. The legal status of the matter is not confirmed and these are allegations only.'
# claim_type='clearance' date_published='2025-06-09' summary='The National Financial Authority closed its investigation into Danube Logistics with no enforcement action. The notice states that evidence was insufficient to support alleged violations and the matter is dismissed.'
# claim_type='fine' date_published='2025-04-20' summary='The National Financial Authority fined Danube Logistics €12,500,000 for anti-money laundering (AML) program deficiencies, specifically related to delayed suspicious activity reporting in 2022. The civil penalty order highlights issues such as inadequate alert tuning and gaps in staff training.'
# claim_type='sanction_listing' date_published='2024-09-28' summary='The Sanctions Directorate of the Ministry of Finance listed Danube Logistics Trading FZE on the national sanctions list for involvement in evasion schemes. As a result of this designation, Danube Logistics Trading FZE is subject to asset freezes and prohibitions on transactions with listed parties.'

# %%
output
# single large string which includes the whole page, footers, cookies, article body, header, navigation
# data requires post cleaning , keep for later , add to summarisation promot that 
# content can contain irrelecant pieces
# Out:
# {'results': [{'url': 'https://www.ebrd.com/home/news-and-events/news/2023/ebrd-will-appeal-imposed-external-administration-of-assets-of-moldovas-danube-logistics-srl.html',
#    'title': 'EBRD will appeal imposed external administration of assets of Moldova’s Danube Logistics SRL',
#    'raw_content': 'EBRD will appeal imposed external administration of assets of Moldova’s Danube Logistics SRL\n\n===============\n\nBack\nWho we are\n\n[Overview: about the EBRD](https://www.ebrd.com/home/who-we-are.html "visit page about the EBRD\'s background, history and mandates")\n\nWho we are\n\n[Overview: about the EBRD](https://www.ebrd.com/home/who-we-are.html "visit page about the EBRD\'s background, history and mandates")\n\n* * *\n\n[![Image 1: Man walking in desert next to electricity pylons](https://www.ebrd.com/content/dam/ebrd_dxp/assets/images/countries/southern-and-eastern-mediterranean/egypt/aswan-solar-farm/aswan-solar-farm-1282x682.jpg)](https://www.ebrd.com/home/who-we-are/ebrd-history.html "visit page about ebrd history")\n\n### [Our story](https://www.ebrd.com/home/who-we-are/ebrd-history.html "visit page about ebrd history")\n\nLearn about the EBRD\'s journey to investing more than €210 billion in over 7,500 projects.\n\n* * *\n\n*   Our background and history\n*   Our organisation\n*   Our values\n*   Strategies, governance and compliance\n*   Project accountability\n\nBack\n*   [Story of the EBRD](https://www.ebrd.com/home/who-we-are/ebrd-history.html "visit page about ebrd history")\n*   [Basic documents establishing the Bank](https://www.ebrd.com/home/news-and-events/publications/institutional-documents/basic-documents.html "visit page to view ebrd establishing documents")\n\nBack\n*   [Governance and leadership](https://www.ebrd.com/home/who-we-are/our-organisation/ebrd-governance-leadership.html "visit page about ebrd governance and leadership")\n*   [Shareholders](https://www.ebrd.com/home/who-we-are/our-organisation/shareholders.html "visit page about ebrd shareholders")\n*   [Staff](https://www.ebrd.com/home/who-we-are/our-organisation/ebrd-people.html "visit page about ebrd staff")\n*   [Headquarters](https://www.ebrd.com/home/who-we-are/our-organisation/our-headquarters.html "visit page about ebrd headquarters")\n\nBack\n*   [Overview](https://www.ebrd.com/home/who-we-are/ebrd-values.html "Overview")\n*   [Transition](https://www.ebrd.com/home/who-we-are/ebrd-values/ebrd-transition.html "Transition")\n*   [Environmental and social sustainability](https://www.ebrd.com/home/who-we-are/ebrd-values/ebrd-environmental-social-sustainability.html "Environmental and social sustainability")\n*   [Additionality](https://www.ebrd.com/home/who-we-are/ebrd-values/ebrd-additionality.html "Additionality")\n*   [Multiparty democracy and pluralism](https://www.ebrd.com/home/who-we-are/ebrd-values/ebrd-multiparty-democracy-and-pluralism.html "Multiparty democracy and pluralism")\n*   [Transparency](https://www.ebrd.com/home/who-we-are/ebrd-values/transparency-and-accountability.html "Transparency")\n*   [Integrity and compliance](https://www.ebrd.com/home/who-we-are/strategies-governance-compliance/office-chief-compliance-officer.html "Integrity and compliance")\n\nBack\n*   [All strategies and policies](https://www.ebrd.com/home/who-we-are/strategies-governance-compliance/ebrd-strategies-policies.html "All strategies and policies")\n*   [Evaluation](https://www.ebrd.com/home/who-we-are/strategies-governance-compliance/evaluation.html "Evaluation")\n*   [Sanctions system](https://www.ebrd.com/home/who-we-are/strategies-governance-compliance/ebrd-sanctions-system.html "Sanctions system")\n*   [Office of the Chief Compliance Officer](https://www.ebrd.com/home/who-we-are/strategies-governance-compliance/office-chief-compliance-officer.html "Office of the Chief Compliance Officer")\n*   [Client due diligence](https://www.ebrd.com/home/who-we-are/strategies-governance-compliance/ebrd-client-due-diligence.html "Client due diligence")\n*   [Risk Management](https://www.ebrd.com/home/who-we-are/strategies-governance-compliance/risk-management.html "Risk Management")\n\nBack\n*   [Independent Project Accountability Mechanism](https://www.ebrd.com/home/what-we-do/projects/independent-project-accountability-mechanism. ...
#    'images': []}],
#  'failed_results': [],
#  'response_time': 0.01,
#  'request_id': '0e5e86ad-7794-4f89-bce4-4f55797f37d6'}

# %%
# Initialize client once at module level
# https://docs.tavily.com/documentation/api-reference/endpoint/extract

#  avily API has a limit of 20 URLs per extraction request
# we can face error bad requiest max 20 is allowed

# function will run inside the node, tool is not generated 
# as application is strainghforward 

def tavily_content_extractor(
    dummy_state: List[LinkCollection], # will be populated with new data from ClassSummary   
    extract_depth: str = "advanced", # advanced  basic
    include_raw_content: bool = True,
    entity_name:str = ""

) -> List[LinkCollection]:
    
    print("Executing content extraction...")

    # store urls values
    urls = [link.link for link in dummy_state] # link_collection.link
    displayLinks = [link.displayLink for link in dummy_state]
    ## map url and displayLink based on link_collection.displayLink
    url_to_displayLink = {url: displayLink for url, displayLink in zip(urls, displayLinks)}
    

    ## extract all urls in batches, tavily limits to 20 requests
    BATCH_SIZE = 20 
    url_to_raw_content = {} # need to store "url" and "raw_content"

    def first_n_words(text: str, n: int) -> str:
        return " ".join(text.split()[:n])

    for i in range(0, len(urls), BATCH_SIZE ):
        batch_urls = urls[i: ( i + BATCH_SIZE ) ]
        print(f"Processing batch {i//BATCH_SIZE + 1}: {len(batch_urls)} URLs")

        try: 
            response = tavily_client.extract(urls=batch_urls, extract_depth=extract_depth, format = 'markdown')     

            # Map URLs to content from this batch
            for item in response.get('results', []):
                url = item.get("url", "")
                content = item.get("raw_content", "")
                url_to_raw_content[url] = first_n_words(content , 5000) 

        except Exception as e:
            print(f"Error extracting batch: {e}")
            # Continue with empty content for failed URLs
            for url in batch_urls:
                if url not in url_to_raw_content:
                    url_to_raw_content[url] = ""    

    ## We need to keep only non empty content which contains name of the company                    
    # url_to_raw_content to url_to_raw_content_filtered
    parts, name_re = generate_name_regex(entity_name, llm_names_variation)
    print(parts)  # Optional: see "Original | Russian"
    url_to_raw_content_filtered = {url:content for url,content in url_to_raw_content.items() if name_re.search(content)}
    

    # Create new LinkCollection objects with matched raw_content
    updated_collections = []
    thread_outcomes = {}
    threads = []
    
    print(f"Entity name: {entity_name} ")
    for url, raw_content in url_to_raw_content_filtered.items():
        t = threading.Thread( 
            target = generate_url_summary ,
            args = ( raw_content, llm_url_content_summary, entity_name, thread_outcomes, url )
        )
        threads.append(t)

    for thread in threads:
        thread.start() 

    for thread in threads:
        thread.join()
    # now thread_outcomes is populated with pairs url, summary  

    # debug 
    print(f"Total number of links by google search: {len(urls)}")
    print(f"URLs in url_to_raw_content: {len(url_to_raw_content)}")
    print(f"URLs in url_to_raw_content_filtered: {len(url_to_raw_content_filtered)}")
    print(f"URLs in thread_outcomes: {len(thread_outcomes)}")
    print(f"URLs in url_to_displayLink: {len(url_to_displayLink)}")  

    # now unpack the dictionary which contains 3 attributes which we need to add to Link Collection
    # claim_type='other' date_published='Unknown' summary='No financial crime or compliance information is present in the content.'
    for url in thread_outcomes:       
        updated_collection = LinkCollection(
            displayLink=url_to_displayLink[url],
            link=url,
            raw_content=url_to_raw_content[url],
            summary=thread_outcomes[url].summary, 
            claim_type=thread_outcomes[url].claim_type, 
            date_published=thread_outcomes[url].date_published
        )
        
        updated_collections.append(updated_collection)

    print("Executing content extraction Done")

    return updated_collections

# Test 
#dummy = tavily_content_extractor(dummy_state=results["search_results"],  entity_name= results["entity_name"] )

# %%
# the function above will not be implemented as tool 
# we will update search_results component for each LinkCollection

def extract_content(state: UnifiedResearchState) -> UnifiedResearchState :
    """Node function to extract content from URLs in search results"""
    
    print("Executing extract_content...")
    
    dummy_state = state["search_results"].copy()
    updated_search_result = tavily_content_extractor(dummy_state=dummy_state , entity_name = state["entity_name"])
    
    print("Extract_content completed Done")

    return {"search_results": updated_search_result} # replace the searchresult field

# %% [markdown]
# #### Unite Research and HyDe agent into 1

# %%
## input comes from expanded query formed after llm node
## now define nodes 

def create_journalists( state:UnifiedResearchState  ) :
     
     """ create journalist """ 

     print("Executing create_journalists ... ")

      # prompts arguments
     crime_topic=state['expanded_query']
     max_journalists=state['max_journalists']
     
     # llm to generate persona 
     structured_llm = llm_class_generation.with_structured_output( HydePerspectives )

     system_message = journalist_instructions.format( crime_topic = crime_topic , 
                                                      max_journalists= max_journalists
                                                     )
     print( "System Instructions: " , system_message[:100])
     
     # populate values  
     journalists = structured_llm.invoke([SystemMessage(content=system_message)]+[HumanMessage(content="Generate the set of journalists according to instructions")])

     print("Executing create_journalists Done ")

     return { "journalists": journalists.journalists }



## function to write article 
def generate_hyde_document(state:UnifiedResearchState): 

    """Generate Hyde articles using journalist personas"""

    print("Executing generate_hyde_document ... ")

    article_template = """You are a journalist with the profile below. Write a short, hypothetical article for retrieval (HyDE). :
            
            Company name (repeat it several times): {entity_name}
            Expertise: {expertise}
            Perspective: {perspective}
            Style: {style}
            Topic to cover: {crime_topic}

            Constraints:
            - 350 - 400 words, plain text (no markdown).
            - Include AML/KYC lexicon where natural: anti-money laundering (AML), know-your-customer (KYC), transaction monitoring,
              suspicious activity reports (SARs), correspondent banking, beneficial ownership, PEP, sanctions, consent order, settlement, probe.
            - Keep a neutral, reportorial tone; this is hypothetical for search, not a claim.
            - If topic lacks dates/amounts, use vague ranges. Do not fabricate concrete numbers.


            Structure to follow (inline, no headings):
            - Headline that includes "{entity_name}".
            - One-sentence dek summarizing the angle.
            - Lede paragraph naming {entity_name} and the jurisdiction/sector if implied by the topic.
            - One paragraph with AML/KYC process vocabulary and typical risk indicators.
            - One paragraph on regulatory/enforcement posture (investigation/settlement/fine allegations as applicable).
            - Closing sentence that restates {entity_name} and the core issue.

            Write the article now.

"""
            
    hyde_list = []

    print("Unpacking journalists classes")

    ## unpack values in journalists field
    journalists =  [ state["journalists"] ] 

    for elem in state['journalists']:
        prompt = article_template.format(
            expertise=elem.expertise,
            perspective=elem.perspective, 
            style=elem.style,
            crime_topic=state["expanded_query"],
            entity_name = state['entity_name']
        )

        print("Prompt to create Article: ", prompt[:400])
        article = llm_hyde_generation.invoke([HumanMessage(content=prompt)])
        hyde_list.append(article.content)

    print("Executing generate_hyde_document Done ")    

    return {"hyde_list": hyde_list}

# %% [markdown]
# #### Prepare module for cosine similarity

# %%
## ok test comparison algo , each article is compared against
## HeDe docs

from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# we compare 1 article agains max_journalist , the format is ( n_row , n_journalists ) 

text_samples = [
    "The financial institution faces significant regulatory compliance challenges and potential money laundering violations that could impact its banking partnerships.",
    
    "Recent investigations reveal operational risk factors including inadequate anti-money laundering controls and suspicious transaction monitoring failures.",
    
    "Market analysts express concerns about reputational damage from ongoing legal proceedings and regulatory scrutiny affecting stakeholder confidence."
]

url_content = text_samples[1]

## form embedding of original 

vector_url_content = np.array( embedding_cross_lang.embed_query(url_content) )
vector_url_content = vector_url_content.reshape(1,-1)
print(vector_url_content.shape)
# Out:
# (1, 3072)

# %%
# function will be iteravely applied over each content 

def check_content_similarity(
    search_results: List[LinkCollection], 
    hyde_list: npt.NDArray[np.float64]
) -> List[LinkCollection]:
    
    """
    Check if URL content has high similarity to any Hyde document
    
    Args:
        search_results: List of LinkCollection objects with raw_content
        hyde_list: numpy array of shape (n, 1536) containing Hyde embeddings
    
    Returns:
        float: Maximum cosine similarity score rounded to hundredth (2 decimal places)
    """
    
    # Store max similarity score for each URL
    updated_collections = []  # stroe new values for the collection, later replace, solution is redundant
    for link in search_results:

        url_content = link.raw_content
        
        # Embed URL content, cap is 300 000 tokens, 1 token is aproximately 4 characters, Embedding error: Error code: 400 - {'error': {'message': 'Requested 307281 tokens, max 300000 tokens per request', 't
        try:
           url_content_embed = np.array(
               embedding_cross_lang.embed_query(url_content[:800000])
           ).reshape(1, -1)
        except Exception as e:
           print(f"Embedding error: {str(e)[:100]}")
           url_content_embed = np.zeros((1, 3072))  # Default embedding for text-embedding-3-large
        
        # calculate similarity scores against all Hyde embeddings
        similarity_scores = cosine_similarity(url_content_embed, hyde_list)
        
        # Find and store max similarity for this URL
        max_score = round(float(np.max(similarity_scores)), 2)
        
       
        # update the state values , fix later 
        updated_collection = LinkCollection(
            displayLink=link.displayLink,
            link=link.link,
            raw_content=link.raw_content,
            summary=link.summary,
            claim_type=link.claim_type, 
            date_published=link.date_published,
            hyde_score=max_score
        )
        
        updated_collections.append(updated_collection)
    
    return updated_collections

# Usage:
#results["search_results"] = check_content_similarity(
#    results["search_results"], 
#    hyde_content_list_embed
#)

# Tools are for external API, actions which requires LLM to decide parameters , sityation whcih required dynamic parameters
# Here we process data which already in a state, no external api, state modification, sequential processing

# %%
## Node to update  state["search_results"] and keep only relevant material for summary 

def filter_relevant_content(state: UnifiedResearchState) -> UnifiedResearchState:
    """Filter and sort search results by HyDE relevance score"""
    
    print("Executing filter_relevant_content...")
    
    RELEVANCE_THRESHOLD = 0.0  # Configurable
    TOP_K = 30  # Maximum articles to keep
    
    # Filter items with scores
    scored_items = [
        link for link in state["search_results"]
        if link.hyde_score is not None
    ]
    
    # Sort by score (descending)
    sorted_items = sorted(
        scored_items, 
        key=lambda x: x.hyde_score, 
        reverse=True
    )

    ## now genetate variation names 
    parts, name_re = generate_name_regex(state['entity_name'], llm_names_variation)
    print(parts)  # Optional: see "Original | Russian"

    def in_summary(item) -> bool:
        s = getattr(item, "summary", "") or ""
        return bool(name_re.search(s))
    
   #  name filter first ---
    name_filtered = [item for item in sorted_items if in_summary(item)]
    print(f"Total articles: {len(state['search_results'])}")
    print(f"Articles with scores: {len(scored_items)}")
    print(f"Name-matched (summary contains company name): {len(name_filtered)}")
    
   # threshold filtering
    threshold_filtered = [it for it in name_filtered if it.hyde_score >= RELEVANCE_THRESHOLD]
    filtered = threshold_filtered[:TOP_K]
    print(f"Above threshold ({RELEVANCE_THRESHOLD}): {len(threshold_filtered)}")
    print(f"Returned (TOP_K={TOP_K}): {len(filtered)}")

    if filtered:
        scores = [item.hyde_score for item in filtered]
        print(f"Score range: {min(scores):.2f} - {max(scores):.2f}")
        print(f"Top 5 sources example: {[item.displayLink[:30] for item in filtered[:5]]}")
    else:
        print("WARNING: No articles passed relevance threshold!")
    
    print("Executing filter_relevant_content Done")
    
    return {"filtered_results": filtered}

# %%
## now prepare function to integrate into main flow 

# with cosine we should distingusin 
#company accused in money laundering, mentioned in article about laundering
# denying accusations, complying with anti money policy

def assign_score_vs_hyde(state: UnifiedResearchState) -> UnifiedResearchState :
    """Node function to estimate similarity score agains HyDe documents"""
    
    print("Executing assign_score_vs_hyde...")

    ## prepare HydeEmbeddings 
    hyde_content_list = state.get("hyde_list", None)
    # hyde_content_list_embed = np.vstack([  np.array( embedding_cross_lang.embed_query(article) ).reshape(1,-1) for article in hyde_content_list ])

    hyde_embeddings = embedding_cross_lang.embed_documents(hyde_content_list)
    hyde_content_list_embed = np.array(hyde_embeddings)
    
    ## prepare input for score estimation
    dummy_state = state["search_results"].copy()
    updated_search_result = check_content_similarity(search_results=dummy_state , hyde_list = hyde_content_list_embed )
    
    print(" Executing assign_score_vs_hyde  Done")

    return {"search_results": updated_search_result} # replace the searchresult field

# %% [markdown]
# #### Evidence Validation

# %%
# We need verifiation that final assessment clains are based on the evidence 
# collected as summaries 
# We need to emplly evidence therefore add modules to trace the process

# Eventually, evidences must be collected into reusable sharable format 
# It should help to avoid hallusination and back up arguments with evidences 

# we require consistent deduplication, inproved output structure with more discinplined extraction, lower hallucination
# LengthFinishReasonError: Could not parse response content as the length limit was reached - CompletionUsage(completion_tokens=4000, prompt_tokens=3174, total_tokens=7174,


## test the class 

def extract_evidence_claims(state:UnifiedResearchState) -> Dict: 
    
    """Extract claims from summaries and consolidate duplicate claims across sources"""
    
    print("Extracting and consolidating evidence claims...")

    # prepare summaries 
    summaries_data = [] # each element is dictionary wish summary data 

    for link in state["filtered_results"]: 
        if link.summary.strip(): 
            summaries_data.append(
                {
                "url": link.link,
                "source": link.displayLink,
                "summary": link.summary, # contains date
                "claim_type": link.claim_type,
                "date_published":link.date_published,
                "hyde_score": link.hyde_score
                }
            )

    print("Data from which to consolidate evidences: " , json.dumps(summaries_data, indent=2))

    extraction_prompt = f"""
Consolidate financial-crime/compliance claims about {state["entity_name"]} from the PRE-CLASSIFIED summaries below.

IMPORTANT
- Do NOT re-classify. Use each item's `claim_type` as ground truth.
- Do NOT invent facts or fields. Use only what is present in the summaries.
- Return ONLY the structured object matching `ClaimsFromSummaries` (no extra text).

INPUT (per item): url, source, summary, claim_type, date_published, hyde_score

SCOPE & FILTERS
- Include ONLY items about {state["entity_name"]}. If an item focuses on another company, skip it.
- If an affiliate/subsidiary is mentioned, include only if the summary explicitly ties it to {state["entity_name"]} (ownership/control/parent–subsidiary stated). Otherwise skip.
- Ignore items that explicitly say there is no information about {state["entity_name"]}.
- RAW CONTENT may include boilerplate or unrelated text—ignore noise and use only substantive financial-crime details.

DEFINITION — CLUSTER
- A **cluster** is a set of items that describe the **same underlying event** and share the same `claim_type`.
- “Underlying event” means a single discrete action/outcome (e.g., one fine order, one settlement agreement, one charge/indictment, one conviction/plea, one sanctions listing, one clearance/closure, one investigation opening) concerning {state["entity_name"]}.
- Press updates or multiple articles about the **same** order/filing/decision belong to the **same cluster**.
- If there is a **material difference** (e.g., different regulator/agency, different amount/currency, different case number or court, clearly different event dates), treat as **separate clusters** even if wording is similar.
- Each **cluster maps to exactly one `EvidenceClaim`** (one cluster ⇒ one claim).

CONSOLIDATION (NO RE-CLASSIFICATION)
1) Form clusters using semantic overlap in:
   - regulator/agency/court names
   - action (fine/settlement/charge/plea/conviction/investigation/allegation/clearance/sanction_listing)
   - amounts & currency (treat “€1.5B” ≈ “€1,500,000,000”)
   - timeframe or event date window
   - jurisdiction/country/court
   When uncertain, prefer merging items with higher `hyde_score`; if still unsure, keep separate claims.

2) For each cluster, output ONE `EvidenceClaim`:
   - `claim_text`: One precise sentence for {state["entity_name"]} capturing shared details (amounts, agency, timeframe, jurisdiction). If sources conflict on a detail, omit that detail rather than guessing.
   - `claim_type`: COPY from the clustered items (do not change).
   - `supporting_urls`: ALL unique URLs from the cluster. Deduplicate. Order by descending `hyde_score`; if scores tie or are missing, preserve first appearance.
   - `date_publish`: choose in this order:
       a) A clear event date in the summaries (YYYY-MM-DD).
       b) Else the most recent non-"Unknown" publication date among the clustered items.
       c) Else "Unknown".

3) If items refer to the same matter but have DIFFERENT `claim_type` (e.g., investigation → settlement → clearance), output SEPARATE claims (one per type).

FORMAT RULES
- `date_publish` must be "YYYY-MM-DD" or "Unknown".
- If no valid claims remain after filtering, return `evidence_claims: []`.
- Sort `evidence_claims` by `date_publish` ascending; place "Unknown" dates last.

Summaries to analyze:
{json.dumps(summaries_data, indent=2)}
"""


    # debug
    #print(json.dumps(summaries_data, indent=2))


    structured_llm = llm_agg_summaries.with_structured_output( ClaimsFromSummaries )

    response = structured_llm.invoke([
        SystemMessage(content= f"""
                You are a forensic Financial Crimes Analysts of company {state["entity_name"]}

                Follow these constraints:
                - Use only information contained in the user message; do not add outside knowledge.
                - Do not guess missing details (dates, amounts, agencies).
                - Produce consolidated, non-duplicative claims and include provenance (supporting URLs).
                - Choose exactly one claim_type per claim, using the schema provided by the user.
                - If nothing qualifies under these constraints, return an empty list.
                """ )
                ,      

        HumanMessage(content=extraction_prompt)
        
    ])

    print(f"Extracted {len(response.evidence_claims)} unique claims from {len(summaries_data)} summaries")
    # json dums return string which is applied to promot via f syntax

    print(response.evidence_claims)
    return {"evidence_claims" : response.evidence_claims}

#buff = extract_evidence_claims(results)  # tested

# %%
# adjust summarisation node 

def generate_risk_assessment(state: UnifiedResearchState):
    """Generate comprehensive AML risk assessment from evidence claims"""
    
    print("Executing generate_risk_assessment...")
    
    print("State keys" , state.keys())
    types = {c.claim_type for c in state["evidence_claims"]}
    claims_by_type = {t: [] for t in types}

    print("Claim types:", sorted(types)) # myst be fine investigation, allegation, clearance, settlement
    
    ## now prepare input for final summarisation prompt 
    print("Iterate through claim cases: ")
    for claim in state["evidence_claims"]:
        claims_by_type[claim.claim_type].append({
            "text": claim.claim_text,
            "sources": len(claim.supporting_urls),
            "date_publish":claim.date_publish
        })
    
    entity_name = state["entity_name"]
    
    system_message = SystemMessage(content=f"""
    You are a senior AML compliance officer conducting risk assessment for {entity_name}.
    
    Analyze the evidence to determine banking partnership viability.
    
    KEY ASSESSMENT CRITERIA:
    
    1. VIOLATION SEVERITY
    - Calculate total fines from the evidence (don't hardcode)
    - Identify the scale of violations (amounts involved vs fines paid)
    - Determine if violations were systemic or isolated
    
    2. CURRENT RISK STATUS
    - Count active investigations (ongoing = unresolved risk)
    - Identify investigating authorities 
    - Assess geographic spread (multiple jurisdictions = higher risk)
    - Evaluate timeline and provide quote with date in ISO 8601 format (recent violations = weak current controls)
    
    3. CONTROL ENVIRONMENT
    - Evaluate settlement efforts (genuine improvement vs PR)
    - Check for leadership accountability (executives resigned?)
    - Assess system improvements (new AML systems, training?)
    
    4. PATTERN RECOGNITION
    - Multiple fines for similar issues = poor compliance culture
    - Repeated violations across years = systemic failure
    - Mix of old violations + strong settlement = possible reform
    
    DECISION FRAMEWORK:
    
    AVOID PARTNERSHIP if:
    - Criminal investigations ongoing
    - Multiple violations without meaningful settlement
    - Pattern of violations continuing to present
    - Total fines exceed €1 billion with no improvement
    
    ENHANCED DUE DILIGENCE if:
    - Significant past violations but settled
    - Active settlement program with evidence
    - Civil investigations ongoing (not criminal)
    - Mix of violations and clearances
    
    
    REQUIRED OUTPUT:
    1. EXECUTIVE SUMMARY: Core issues and total financial impact (calculate from evidence)
    2. VIOLATION ANALYSIS: What they did wrong and when
    3. CURRENT STATUS: What's resolved vs ongoing
    4. TRAJECTORY: Getting better or worse? (compare dates)
    5. RISK RATING: HIGH/MEDIUM/LOW with specific justification
    6. PARTNERSHIP RECOMMENDATION: Your decision with conditions
    
    Be specific about amounts, dates, and authorities involved.

    Each Summary must end with structurem here is example, Keep same criteria but
    Content for Status/Details can vary

    **Summary Table**

| Criteria                | Status/Details                                           |
|-------------------------|---------------------------------------------------------|
| Total Fines Paid        | €0                                                      |
| Most Serious Issue      | Ongoing criminal investigation for money laundering     |
| Ongoing Risk?           | Yes (as of 2025-09-16)                                  |
| Investigating Authority | Moldovan law enforcement                                |
| Geographic Spread       | Moldova only                                            |
| Settlement Efforts      | None reported                                           |
| Risk Rating             | HIGH                                                    |
| Recommendation          | AVOID PARTNERSHIP                                       |

    """)
    
    # Prepare evidence for analysis
    # Build evidence_prompt dynamically (no hardcoded claim types)
    sections = []
    for t in sorted(claims_by_type.keys()):
        items = claims_by_type[t]
        if not items:
            continue
        title = t.replace("_", " ").upper()  # simple, generic prettifier
        sections.append(f"{title}:\n{json.dumps(items, indent=2, ensure_ascii=False)}")

    evidence_block = "\n\n".join(sections) if sections else "No evidence available."

    evidence_prompt = (
        f"Evidence for {entity_name}:\n\n"
        f"{evidence_block}\n\n"
        "Based on this evidence:\n"
        "1. Calculate the total fines paid\n"
        "2. Identify the most serious issue (hint: look for large transaction amounts)\n"
        "3. Determine if this is historical or ongoing risk\n"
        "4. Make your partnership recommendation with clear reasoning\n"
    )


    print("Request LLM Response ")
    print("Example of evidence_prompt: ", evidence_prompt)
    messages = [system_message, HumanMessage(content=evidence_prompt)]

    analysis_response = llm_evaluation.invoke(messages)
    
    print("Risk assessment completed")
    return {"messages": [analysis_response]}

# %%
## add node to the workflow 


# assemble agent
builder = StateGraph(UnifiedResearchState)

# content extraction
builder.add_node( "llm", llm_node)
builder.add_node( "tool_node_chunk_selection_exec", tool_node_chunk_selection_exec)
builder.add_node( "extract_content", extract_content)
builder.add_node( "generate_risk_assessment", generate_risk_assessment)
builder.add_node( "filter_relevant_content",filter_relevant_content)
  # the node DOES wait for all incoming edges to complete before

# hyde generation
builder.add_node( "create_journalists", create_journalists )
builder.add_node( "generate_hyde_document", generate_hyde_document )

# estimate score 
builder.add_node( "assign_score_vs_hyde" ,  assign_score_vs_hyde )

# evidence assessment 
builder.add_node( "extract_evidence_claims", extract_evidence_claims)

# logic 

# content extraction
builder.add_edge(START, "llm")
builder.add_edge( "llm", "tool_node_chunk_selection_exec")
builder.add_edge( "tool_node_chunk_selection_exec", "extract_content")
builder.add_edge( "extract_content", "assign_score_vs_hyde")  # Then end

# article writer
builder.add_edge( "llm" , "create_journalists")
builder.add_edge( "create_journalists" , "generate_hyde_document")
builder.add_edge( "generate_hyde_document" , "assign_score_vs_hyde" )
builder.add_edge( "assign_score_vs_hyde" , "filter_relevant_content" )
builder.add_edge( "filter_relevant_content" , "extract_evidence_claims" )
builder.add_edge( "extract_evidence_claims" , "generate_risk_assessment" )
builder.add_edge("generate_risk_assessment", END)  # Then end

# assemble agent
graph = builder.compile( )

mermaid_code = graph.get_graph(xray=True).draw_mermaid()
render_mermaid_graph(mermaid_code)
# Out:
# claim_type='conviction' date_published='2025-03-14' summary='A former Danube Logistics contractor was convicted by a jury on two counts of money laundering related to transactions in 2021. The court order specifies that there was no finding of wrongdoing against Danube Logistics as a corporate entity. Sentencing for the convicted individual is scheduled for May.'
# Graph rendered successfully: graph.png
# True

# %%
# test 
# Moldretail
# Lukoil  Wachovia Bank     HSBC    Dankse Bank Moldindconbank
# Finpar Invest
# trans oil
# danube logistics

# try different search algoriths
# LLM as local 
# juridical cases in pdf , justice md

initial_message = [ HumanMessage(content = "Danske Bank" )  ]
results = graph.invoke(   
               {
                    "messages" : initial_message,
                    "max_journalists": 1,
                    "journalists": [],  # Will be populated by create_journalists node
                    "hyde_list": []     # Will be populated by generate_hyde_document node
                    
                } )
# "max_journalists": 6, 10 links per language
# Out:
# Executing llm_node...
# Updated human message:  Danske Bank money laundering criminal activity
# Executing create_journalists ...
# System Instructions:
#
# You are creating exactly 10 AI journalist personas to analyze
# the SAME financial-crime topic from
# Executing tool_node_chunk_selection_exec...
# Executing google_search_payload ...
# Translated 'Danske Bank money laundering criminal activity' -> 'Danske Bank spălare de bani activitate infracțională' (Romanian)
# Additional search terms:  Danske Bank Danske Bank A/S Danske Bank România Danske Bank SA DanskeBank Banca Danske Danske Bank în România Danske Bank spălare de bani activitate infracțională
# Executing google_search_payload DONE
# Executing google_search_payload ...
# Translated 'Danske Bank money laundering criminal activity' -> 'Danske Bank money laundering criminal activity' (English)
# Additional search terms:  Danske Bank A/S Danske Bank Danske Danske Bank Plc Danske Bank Group Danske Bank Denmark Danske Bank Corporation Danske Bank money laundering criminal activity
# Executing google_search_payload DONE
# Executing google_search_payload ...
# Translated 'Danske Bank money laundering criminal activity' -> 'Danske Bank отмывание денег преступная деятельность' (Russian)
# Additional search terms:  Danske Bank Данске Банк Danske Bank A/S Данске Банк А/С Danske Данске Danske Bank Denmark Danske Bank отмывание денег преступная деятельность
# Executing google_search_payload DONE
# Executing google_search_payload ...
# Executing create_journalists Done
# Translated 'Danske Bank money laundering criminal activity' -> 'Danske Bank blanchiment d'argent activité criminelle' (French)
# Additional search terms:  Danske Bank A/S Danske Bank Danske Danske Bank Plc Danske Bank Denmark Danske Bank groupe Danske Bank société Danske Bank blanchiment d'argent activité criminelle
# Executing google_search_payload DONE
# Executing google_search_payload ...
# Translated 'Danske Bank money laundering criminal activity' -> 'Danske Bank Geldwäsche kriminelle Aktivitäten' (German)
# Additional search terms:  Danske Bank Danske Bank A/S Danske Bank AG DanskeBank Danske-Bank Danske Bank Deutschland Danske Bank Dänemark Danske Bank Geldwäsche kriminelle Aktivitäten
# Executing google_search_payload DONE
# Executing tool_node_chunk_selection_exec END
# Executing extract_content...
# Executing content extraction...
# Processing batch 1: 20 URLs
# Executing generate_hyde_document ...
# Unpacking journalists classes
# Prompt to create Article:  You are a journalist with the profile below. Write a short, hypothetical article for retrieval (HyDE). :
#
#             Company name (repeat it several times): Danske Bank
#             Expertise: Regulatory enforcement and sanctions compliance
#             Perspective: Focuses on the impact of unresolved regulatory sanctions and consent orders on Danske Bank’s risk profile, emphasizing the
# Prompt to create Article:  You are a journalist with the profile below. Write a short, hypothetical article for retrieval (HyDE). :
#
#             Company name (repeat it several times): Danske Bank
#             Expertise: Financial forensic transaction analysis
#             Perspective: Analyzes suspicious transaction patterns and anomalous cash flows linked to Danske Bank, prioritizing detection of layering techni
# Prompt to create Article:  You are a journalist with the profile below. Write a short, hypothetical article for retrieval (HyDE). :
#
#             Company name (repeat it several times): Danske Bank
#             Expertise: Operational risk and internal controls evaluation
#             Perspective: Assesses weaknesses in Danske Bank’s internal governance, control failures, and third-party oversight that enabled money
# Processing batch 2: 20 URLs
# Prompt to create Article:  You are a journalist with the profile below. Write a short, hypothetical article for retrieval (HyDE). :
#
#             Company name (repeat it several times): Danske Bank
#             Expertise: Reputational risk and media sentiment analysis
#             Perspective: Evaluates the persistence and intensity of negative media coverage and public sentiment around Danske Bank’s laundering sca
# Processing batch 3: 2 URLs
# Prompt to create Article:  You are a journalist with the profile below. Write a short, hypothetical article for retrieval (HyDE). :
#
#             Company name (repeat it several times): Danske Bank
#             Expertise: KYC and beneficial ownership transparency
#             Perspective: Examines shortcomings in Danske Bank’s customer due diligence, focusing on opaque beneficial ownership structures and inadequate
# Prompt to create Article:  You are a journalist with the profile below. Write a short, hypothetical article for retrieval (HyDE). :
#
#             Company name (repeat it several times): Danske Bank
#             Expertise: Correspondent banking and cross-border exposure
#             Perspective: Investigates Danske Bank’s correspondent banking relationships and international transaction flows to identify vulnerabili
# ['Danske Bank', 'Данске Банк', 'DanskeBank', 'ДанскеБанк']Prompt to create Article:  You are a journalist with the profile below. Write a short, hypothetical article for retrieval (HyDE). :
#
#             Company name (repeat it several times): Danske Bank
#             Expertise: Data privacy and consumer protection risks
#             Perspective: Assesses the implications of Danske Bank’s laundering activities on customer data privacy and the bank’s adherence to consumer
#
# Entity name: Danske Bank
# Thread for https://danskebank.com/about-us/corporate-governance/compliance/fighting-financial-crime starting...
# Thread for https://www.sanctionscanner.com/blog/danske-bank-case-money-laundering-scandal-1130 starting...
# Thread for https://danskebank.com/-/media/danske-bank-com/file-cloud/2021/5/financial-crime-policy.pdf?rev=ad7e611592334042afcda054aa43431f&hash=D137E7CD1A45AF978631626263F53D7A starting...
# Thread for https://www.tookitaki.com/blog/from-wachovia-to-danske-bank-biggest-money-laundering-cases-in-recent-times starting...
# Thread for https://www.moneylaundering.com/news/danske-bank-pays-e6-3-million-to-settle-money-laundering-charges-in-france/ starting...
# Thread for https://www.zuckermanlaw.com/uncategorized/money-laundering-sec-whistleblower-program/ starting...
# Thread for https://lucinity.com/blog/reshaping-anti-money-laundering-compliance-the-impact-of-ai-on-financial-integrity starting...
# Thread for https://pythagoras-solutions.com/en/insights/danske-bank-scandal-turning-point-aml-compliance-of-banking-sector starting...
# Thread for https://www.moneylaunderingnews.com/2024/09/nydfs-imposes-35-million-fine-on-nordea-bank-for-alleged-aml-failures-following-panama-papers-revelations/ starting...
# Thread for https://www.cbr.ru/Collection/Collection/File/55401/Jan_2025.pdf starting...
# Thread for https://www.occrp.org/ru/ficher/utecka-iz-swedbank-pokazala-cto-sotrudniki-banka-sutili-pro-sxemy-otmyvaniia-deneg starting...
# Thread for https://www.tadviser.ru/index.php/%D0%A1%D1%82%D0%B0%D1%82%D1%8C%D1%8F:%D0%9E%D1%82%D0%BC%D1%8B%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5_%D0%B4%D0%B5%D0%BD%D0%B5%D0%B3_(Money_Muling) starting...
# Thread for https://coredo.eu/ru/tri-jetapa-otmyvanija-deneg-i-ih-vlijanie-na-biznes/ starting...
# Thread for https://finance.ua/goodtoknow/skhemy-vidmyvannia-hroshei-nairezonansnishi-spravy-svitu starting...
# Thread for https://rus.postimees.ee/8338600/ssha-vydelili-estonii-milliony-na-borbu-s-otmyvaniem-deneg starting...
# Thread for https://dineka.ru/news/1374/ starting...
# Thread for https://financialcrimeacademy.org/fr/blanchiment-dargent-demasque-des-cas-et-des-exemples-notables-devoiles/ starting...
# Thread for https://blog.transworldcompliance.com/fr/des-amendes-qui-font-froid-dans-le-dos-les-sanctions-les-plus-effrayantes-en-cas-de-non-conformite-dans-le-secteur-financier starting...
# Thread for https://www.twobirds.com/fr/insights/2025/france/lcb-ft-retrospective-2024-partie-2 starting...
# Thread for https://pythagoras-solutions.com/insights/danske-bank-skandal-ein-wendepunkt-aml-compliance-im-banksektor starting...
# Thread for https://financialcrimeacademy.org/de/geldwasche-aufgedeckt-bemerkenswerte-falle-und-beispiele-enthullt/ starting...
# Thread for https://www.socialistsanddemocrats.eu/de/newsroom/die-sd-fraktion-begruesst-die-bahnbrechende-einigung-beim-eu-anti-geldwaesche-paket starting...
# Thread for https://exkulpa.de/geldwaeschepraevention/geldwaescheparadies-deutschland-ursachen-eu-vergleich-folgen/ starting...
# Thread for https://www.produktion.de/wirtschaft/die-10-groessten-wirtschaftsskandale-in-deutschland-383.html starting...
# Thread for https://theconversation.com/blanchiment-dargent-leurope-passe-enfin-a-laction-258091 starting...
# Thread for https://pideeco.be/fr/articles/comment-les-gatekeepers-sont-utilises-pour-le-blanchiment-dargent/ starting...
# Thread for https://tribuna.ee/tribuna/economy/usa-finansirujut-proekty-estonia-predotvrashenie-korriptsii/ starting...
# Thread for https://navacelle.law/fr/cjip-danske-bank/ starting...
# claim_type='other' date_published='Unknown' summary='No financial crime or compliance information is present in the content.'
# claim_type='other' date_published='Unknown' summary='No financial crime or compliance information is present in the content.'
# claim_type='other' date_published='2025-06-16' summary='No financial crime or compliance information is present in the content.'
# claim_type='other' date_published='2024-09-05' summary='No financial crime or compliance information is present in the content regarding Danske Bank. The content primarily discusses regulatory actions and AML deficiencies related to Nordea Bank, with only a brief mention of Danske Bank in the context of correspondent banking relationships and risk ratings assigned by Nordea. There are no allegations, investigations, fines, or other financial crime compliance actions described for Danske Bank in this content.'
# claim_type='fine' date_published='2025-10-28' summary="Danske Bank's Estonian branch was involved in a major money laundering scandal between 2007 and 2015, serving as a channel for an estimated $228 billion in laundered funds. Thousands of suspicious customers were implicated in the scheme, which brought public attention to significant compliance failures at Danske Bank. Danish authorities imposed fines totaling $2 million and attributed responsibility to several managers of the bank."
# claim_type='allegation' date_published='2025-07-15' summary="Danske Bank is cited as the epicenter of the largest money laundering scandal in Europe, with revelations that over €200 billion in suspicious transactions passed through its Estonian branch. The article discusses this as part of a broader analysis of anti-money laundering (AML) failures and scandals involving major EU banks. It highlights systemic deficiencies in AML controls and supervision within the European Union, referencing Danske Bank's involvement in large-scale illicit financial flows as a key example of such failures."
# claim_type='allegation' date_published='Unknown' summary='The content references scandals involving Danske Bank and Credit Suisse as part of the justification for new EU anti-money laundering legislation. It mentions that the reforms were necessary in light of these scandals, implying allegations of money laundering or compliance failures at Danske Bank. However, no specific details, outcomes, or new developments regarding Danske Bank are provided in the content.'
# claim_type='fine' date_published='2024-01-16' summary="Danske Bank was involved in one of the largest US money laundering scandals. Between 2008 and 2016, Danske Bank defrauded several US banks and was sentenced to a billion-dollar fine. The Deutsche Bank processed suspicious transactions worth more than $267 billion for Danske Bank. The case involved significant deficiencies in anti-money laundering measures and compliance failures related to Danske Bank's Estonian subsidiary."
# claim_type='fine' date_published='2025-08-29' summary="Danske Bank's Estonian branch was involved in a major money laundering scandal, acting as an intermediary for approximately $228 billion in laundered funds between 2007 and 2015. The case involved thousands of suspicious clients and significant compliance failures. Danish authorities imposed fines totaling $2 million and attributed responsibility to several bank officials. This case highlighted serious deficiencies in Danske Bank's AML compliance program and failures in transaction monitoring and customer due diligence."
# claim_type='fine' date_published='2024-07-30' summary='Danske Bank war in einen der größten Geldwäscheskandale Europas verwickelt. Über die estnische Niederlassung der Bank wurden zwischen 2007 und 2015 rund 200 Milliarden Euro verdächtiger Gelder, hauptsächlich aus Russland, Aserbaidschan und der Ukraine, gewaschen. Der Skandal führte zu einem massiven Vertrauensverlust und einer erheblichen Belastung des Rufs der Bank. Die dänischen und estnischen Behörden sowie internationale Regulierungsbehörden führten umfassende Untersuchungen durch, was zu hohen Geldstrafen und dem Rücktritt des CEO führte.'
# claim_type='allegation' date_published='2019-03-25' summary='Danske Bank, Denmark’s largest bank, was implicated in a major money laundering scandal involving its Estonian branch. The European Commission described it as the biggest scandal in Europe, with allegations that thousands of suspicious customers used the bank’s weak controls to carry out illicit transactions worth about US$228 billion during 2007-2015. The content highlights deficiencies in Danske Bank’s anti-money laundering controls that allegedly enabled these illicit activities.'
# claim_type='fine' date_published='Unknown' summary="Danske Bank was recently fined €470 million (US$495 million) due to its involvement in an international money laundering scandal. The content highlights that the fine was imposed as a consequence of Danske Bank's participation in money laundering activities, emphasizing the significant regulatory penalties that can result from such compliance failures."
# claim_type='fine' date_published='2024-06-07' summary="In 2018, Danske Bank was involved in one of the largest money laundering scandals in Europe. Approximately 200 billion euros in suspicious transactions were processed through the bank's Estonian branch. As a result, Danske Bank was fined hundreds of millions of dollars, its management faced serious criticism, and the bank suffered significant reputational losses. The investigation revealed that Danske Bank failed to properly check its clients and did not conduct adequate transaction monitoring."
# Prompt to create Article:  You are a journalist with the profile below. Write a short, hypothetical article for retrieval (HyDE). :
#
#             Company name (repeat it several times): Danske Bank
#             Expertise: Financial crime typologies and laundering methods
#             Perspective: Focuses on identifying specific money laundering typologies used within Danske Bank, such as trade-based laundering or s
# claim_type='fine' date_published='2024-11-18' summary='Danske Bank was involved in a major international money laundering scandal revealed in 2018, where approximately €200 billion in suspicious funds were laundered through its Estonian branch between 2007 and 2015. The scandal highlighted the role of professionals, including lawyers, in facilitating money laundering by creating shell companies and complex corporate structures to obscure the origin and ownership of funds. Danske Bank was fined €470 million for its involvement in this case, which exposed deficiencies in regulatory oversight and compliance controls in Estonia. The case is cited as a prominent example of how gatekeepers can be exploited for money laundering purposes.'
# claim_type='allegation' date_published='2024-04-10' summary="The content discusses the Danske Bank money laundering scandal, describing it as one of the most severe cases in the financial world. It alleges that over €200 billion in suspicious funds were laundered through Danske Bank's Estonian branch between 2007 and 2015. The scandal exposed significant failures in Danske Bank's internal AML (Anti-Money Laundering) control mechanisms, which were insufficient to detect and prevent illegal activities. The case led to investigations, regulatory scrutiny, and penalties, and highlighted the need for stricter AML regulations and improved compliance structures within Danske Bank and the broader European banking sector. The summary also notes the reputational and economic damage suffered by Danske Bank as a result of these compliance failures."
# claim_type='fine' date_published='2025-10-08' summary="Danske Bank was involved in a money laundering case that resulted in the United States allocating $50 million (48.8 million euros) to Estonia as part of a settlement for Estonia's contribution to resolving the so-called Danske Bank money laundering case. The funds, originating from fines paid in connection with the Danske Bank case, are being used in Estonia for the prevention, detection, and investigation of financial crimes, including money laundering, cybercrime, and terrorism financing. The projects funded aim to strengthen Estonia's capacity to combat financial crime, improve investigation practices, enhance technological support, and provide sustainable training for specialists. The allocation of these funds underscores the international cooperation between Estonia and the United States in fighting financial crime."
# claim_type='other' date_published='2025-11-09' summary='No financial crime or compliance information is present in the content regarding Danske Bank. The content discusses U.S. funding for Estonian projects aimed at preventing corruption and money laundering, referencing the "so-called money laundering case in Danske Bank" as the context for the funding, but does not provide any new allegations, investigations, charges, fines, settlements, or other compliance actions specifically involving Danske Bank.'
# claim_type='allegation' date_published='2024-04-10' summary="The content details the Danske Bank money laundering scandal, describing it as one of the most serious cases in the financial sector. It alleges that between 2007 and 2015, over 200 billion euros of suspicious funds were laundered through Danske Bank's Estonian branch. The scandal revealed significant deficiencies in Danske Bank's AML (Anti-Money Laundering) controls, with thousands of suspicious transactions going undetected due to inadequate internal compliance mechanisms. The case led to extensive investigations, reputational damage, and calls for stricter AML regulations and reforms across the European banking sector. The summary also notes that Danske Bank's compliance structure and corporate culture were found insufficient for managing money laundering risks."
# claim_type='settlement' date_published='Unknown' summary='Danske Bank agreed to pay $413 million to settle charges that it violated the antifraud provisions of the Securities Exchange Act of 1934 by misleading investors about its anti-money laundering (AML) compliance program in its Estonian branch and failing to disclose the risks posed by the program’s significant deficiencies. Danske Bank has agreed to pay more than $2 billion as part of an integrated, global resolution with the SEC, the Department of Justice, the United States Attorney’s Office for the Southern District of New York, and Denmark’s Special Crime Unit. The settlement addresses significant AML compliance failures and related investor disclosures.'
# claim_type='fine' date_published='Unknown' summary="Danske Bank was involved in a major money laundering scandal, where its Estonian branch allegedly laundered approximately $230 billion in suspicious transactions between 2007 and 2015, mainly from Russian clients. The scandal became public in 2018, and Danish regulators imposed a fine on Danske Bank for anti-money laundering (AML) failures. Investigations revealed that Danske Bank lacked adequate controls, allowing criminal networks to exploit its systems for illicit transactions. The bank faced regulatory penalties, legal proceedings, shareholder challenges, and significant reputational damage. Senior executives resigned, and the bank's reputation suffered due to these compliance failures."
# claim_type='conviction' date_published='2024-07-11' summary='Danske Bank was involved in a major money laundering scandal related to suspicious transactions totaling approximately €200 billion processed through its Estonian branch. The scandal came to light in 2018 after a whistleblower revealed that Danske Bank ignored signs of potentially criminal operations moving billions of dollars to the West from 2008 to 2017, including from Russian clients. Many clients were shell companies registered in the UK. An investigation by Danish law firm Bruun&Hjejle found that Danske Bank employees may have knowingly participated in illegal activities, and the bank failed to control money laundering, did not know the owners of many accounts, and lacked automated transaction monitoring. In 2022, Danske Bank admitted guilt to conspiracy to commit bank fraud, acknowledging that it provided banking services to suspicious clients through its Estonian branch despite being aware of money laundering risks.'
# claim_type='fine' date_published='2025-06-20' summary='Danske Bank was implicated in a major money laundering scandal involving over $230 billion in suspicious transactions processed through its Estonian branch between 2007 and 2015. The scandal exposed significant anti-money laundering (AML) and compliance failures, including poor Know Your Customer (KYC) procedures, inadequate suspicious activity reporting (SAR), and weak transaction monitoring systems. Investigations by Danish, Estonian, U.S., and U.K. authorities followed, leading to the resignation of key executives and the closure of the Estonian branch in 2019. Danske Bank faced multiple regulatory investigations, criminal charges in Denmark and other jurisdictions, and paid hundreds of millions in fines. In December 2022, Danske Bank agreed to forfeit $2 billion as part of a global settlement with the U.S. Department of Justice and the SEC for defrauding U.S. banks and violating AML laws. The case is considered a turning point for AML compliance in Europe, prompting regulatory reforms and stricter oversight.'
# claim_type='settlement' date_published='2025-01-07' summary="On January 7, 2025, the US Department of Justice issued a press release regarding a decision to transfer part of the assets confiscated in the money laundering case involving the Estonian branch of Danske Bank A.S. (Danske Bank Estonia) to Estonia. According to the agreement with the US Department of Justice, Estonia will receive $50 million for its assistance and significant contribution to the investigation of Danske Bank Estonia. The funds will be used to improve Estonia's national system for combating financial crimes, including money laundering, fraud, and cybercrime, as well as for specialist training programs, digital forensic expertise, and public awareness campaigns. The content also notes that Danske Bank admitted responsibility for misleading US banks and processing suspicious transactions for high-risk clients through the US financial system, amounting to billions of US dollars. In 2022, Danske Bank was fined over $2 billion by US authorities as a result of the investigation."
# claim_type='allegation' date_published='Unknown' summary="The content references allegations of large-scale money laundering through the Estonian branch of Danske Bank. According to the information, between 2007 and 2015, €201 billion of suspicious origin passed through Danske Bank's Estonian branch, with the transactions primarily involving non-resident clients who had ceased operations by that time. Ten former employees of Danske Bank, mainly client managers, were detained and accused of money laundering, with the total amount of suspicious transactions cited as approximately €300 million. The allegations include claims that bank staff, under the leadership of the branch head, created conditions for large-scale money laundering and concealed these activities. The Central Bank of Russia reportedly warned Danske Bank's Estonian branch about possible illegal transfers by Russian clients as early as 2013, but Danske Bank did not take the necessary measures. The scandal led to the resignation of Danske Bank's CEO, Thomas Borgen."
# claim_type='settlement' date_published='2024-09-18' summary="Danske Bank agreed to pay the French government €6.3 million to settle money laundering charges related to its now-closed Estonian branch. French authorities began investigating Danske Bank in February 2019 over suspicions that weak anti-money laundering controls at the Estonian affiliate allowed a French Russian businesswoman to evade millions of euros in tax and customs duties via offshore entities from 2007 to 2014. French prosecutors concluded that Danske Bank's Estonian branch permitted non-resident portfolio customers to open accounts and conduct transactions without adequate controls or due diligence. The settlement was reached through a deferred prosecution agreement with France’s National Financial Prosecutor. This follows previous enforcement actions, including Danske Bank's December 2022 guilty plea in the U.S. to conspiracy to defraud banks and agreement to pay over $2 billion in penalties and implement AML upgrades."
# claim_type='settlement' date_published='2024-09-20' summary="Danske Bank concluded a judicial public interest agreement (CJIP) with the French National Financial Prosecutor (PNF) regarding allegations of money laundering of tax fraud committed between 2007 and 2014. The case involved Danske Bank's Estonian branch, which maintained a portfolio of high-risk international clients who frequently used shell companies to evade tax regulations. The bank was investigated for facilitating money laundering activities linked to a French import-export company, whose manager was convicted in January 2024. The investigation revealed that Danske Bank's compliance controls were inadequate, allowing clients to open accounts and conduct transactions without proper due diligence. The CJIP, validated by the Paris Judicial Court on September 18, 2024, required Danske Bank to pay a public interest fine of €6,028,799 and an additional €300,000 in compensation to the French state. The settlement took into account aggravating factors such as repeated offenses and compliance program deficiencies, as well as mitigating factors like corrective measures and cooperation with authorities. Danske Bank also faced previous penalties in Denmark and the US for related AML failures and fraud. The bank has since committed to strengthening its compliance and internal controls."
# claim_type='investigation' date_published='2024-11-12' summary="The content reports that in 2019, journalists revealed that Swedbank and Danske Bank were used to move nearly six billion dollars through suspicious accounts in the Baltic countries. The OCCRP investigation found that Swedbank assisted a high-profile client, Russian oligarch and former minister Mikhail Abyzov, in transferring hundreds of millions of dollars to offshore accounts, with $53 million later determined by a Russian court to have been embezzled. Danske Bank is mentioned as being involved in the transfer of funds through suspicious accounts in the Baltics alongside Swedbank. Official investigations were launched into Swedbank's activities, focusing on money laundering and the concealment of beneficial ownership, but the Estonian case was closed in February 2024 due to lack of cooperation from Russian authorities. The content explicitly links Danske Bank to the movement of suspicious funds in the Baltics, but does not provide details of specific investigations, charges, or penalties against Danske Bank in this context."
# claim_type='settlement' date_published='2025-05-27' summary="Danske Bank A/S entered into a judicial public interest agreement (CJIP) with the French financial prosecutor on August 27, 2024, which was validated by the president of the Paris judicial court on September 18, 2024. The settlement followed a judicial investigation opened in April 2015 that uncovered financial flows constituting tax fraud committed by the manager of Decobat, with funds transiting through accounts in Estonia held at Danske Bank's Estonian branch, Sampo Bank. The manager of Decobat was convicted in January 2024 for tax fraud and laundering of tax fraud. Danske Bank A/S was indicted in February 2019 for laundering of organized tax fraud, accused of opening fictitious transit accounts to receive money from organized tax fraud and allowing these accounts to be debited through multiple unjustified transactions to conceal the destination of misappropriated funds and benefit foreign recipients. The public interest fine of €6,028,799 was validated, taking into account Danske Bank's active cooperation, corrective measures, and relevant internal investigations conducted in the context of proceedings by Danish and American regulators."
# Total number of links by google search: 42
# URLs in url_to_raw_content: 41
# URLs in url_to_raw_content_filtered: 28
# URLs in thread_outcomes: 28
# URLs in url_to_displayLink: 42
# Executing content extraction Done
# Extract_content completed Done
# Prompt to create Article:  You are a journalist with the profile below. Write a short, hypothetical article for retrieval (HyDE). :
#
#             Company name (repeat it several times): Danske Bank
#             Expertise: Third-party risk management in AML frameworks
#             Perspective: Analyzes the role of external vendors and service providers in Danske Bank’s AML failures, emphasizing gaps in third-party d
# Prompt to create Article:  You are a journalist with the profile below. Write a short, hypothetical article for retrieval (HyDE). :
#
#             Company name (repeat it several times): Danske Bank
#             Expertise: Economic impact on regional banking stability
#             Perspective: Evaluates how Danske Bank’s laundering scandal affects regional financial stability, credit availability, and investor confi
# Executing generate_hyde_document Done
# Executing assign_score_vs_hyde...
#  Executing assign_score_vs_hyde  Done
# Executing filter_relevant_content...
# ['Danske Bank', 'Данске Банк', 'DanskeBank', 'ДанскеБанк']
# Total articles: 28
# Articles with scores: 28
# Name-matched (summary contains company name): 25
# Above threshold (0.2): 25
# Returned (TOP_K=30): 25
# Score range: 0.33 - 0.70
# Top 5 sources example: ['www.moneylaundering.com', 'www.sanctionscanner.com', 'pythagoras-solutions.com', 'www.moneylaunderingnews.com', 'pythagoras-solutions.com']
# Executing filter_relevant_content Done
# Extracting and consolidating evidence claims...
# Data from which to consolidate evidences:  [
#   {
#     "url": "https://www.moneylaundering.com/news/danske-bank-pays-e6-3-million-to-settle-money-laundering-charges-in-france/",
#     "source": "www.moneylaundering.com",
#     "summary": "Danske Bank agreed to pay the French government \u20ac6.3 million to settle money laundering charges related to its now-closed Estonian branch. French authorities began investigating Danske Bank in February 2019 over suspicions that weak anti-money laundering controls at the Estonian affiliate allowed a French Russian businesswoman to evade millions of euros in tax and customs duties via offshore entities from 2007 to 2014. French prosecutors concluded that Danske Bank's Estonian branch permitted non-resident portfolio customers to open accounts and conduct transactions without adequate controls or due diligence. The settlement was reached through a deferred prosecution agreement with France\u2019s National Financial Prosecutor. This follows previous enforcement actions, including Danske Bank's December 2022 guilty plea in the U.S. to conspiracy to defraud banks and agreement to pay over $2 billion in penalties and implement AML upgrades.",
#     "claim_type": "settlement",
#     "date_published": "2024-09-18",
#     "hyde_score": 0.7
#   },
#   {
#     "url": "https://www.sanctionscanner.com/blog/danske-bank-case-money-laundering-scandal-1130",
#     "source": "www.sanctionscanner.com",
#     "summary": "Danske Bank was implicated in a major money laundering scandal involving over $230 billion in suspicious transactions processed through its Estonian branch between 2007 and 2015. The scandal exposed significant anti-money laundering (AML) and compliance failures, including poor Know Your Customer (KYC) procedures, inadequate suspicious activity reporting (SAR), and weak transaction monitoring systems. Investigations by Danish, Estonian, U.S., and U.K. authorities followed, leading to the resignation of key executives and the closure of the Estonian branch in 2019. Danske Bank faced multiple regulatory investigations, criminal charges in Denmark and other jurisdictions, and paid hundreds of millions in fines. In December 2022, Danske Bank agreed to forfeit $2 billion as part of a global settlement with the U.S. Department of Justice and the SEC for defrauding U.S. banks and violating AML laws. The case is considered a turning point for AML compliance in Europe, prompting regulatory reforms and stricter oversight.",
#     "claim_type": "fine",
#     "date_published": "2025-06-20",
#     "hyde_score": 0.64
#   },
#   {
#     "url": "https://pythagoras-solutions.com/en/insights/danske-bank-scandal-turning-point-aml-compliance-of-banking-sector",
#     "source": "pythagoras-solutions.com",
#     "summary": "The content discusses the Danske Bank money laundering scandal, describing it as one of the most severe cases in the financial world. It alleges that over \u20ac200 billion in suspicious funds were laundered through Danske Bank's Estonian branch between 2007 and 2015. The scandal exposed significant failures in Danske Bank's internal AML (Anti-Money Laundering) control mechanisms, which were insufficient to detect and prevent illegal activities. The case led to investigations, regulatory scrutiny, and penalties, and highlighted the need for stricter AML regulations and improved compliance structures within Danske Bank and the broader European banking sector. The summary also notes the reputational and economic damage suffered by Danske Bank as a result of these compliance failures.",
#     "claim_type": "allegation",
#     "date_published": "2024-04-10",
#     "hyde_score": 0.63
#   },
#   {
#     "url": "https://www.moneylaunderingnews.com/2024/09/nydfs-imposes-35-million-fine-on-nordea-bank-for-alleged-aml-failures-following-panama-papers-revelations/",
#     "source": "www.moneylaunderingnews.com",
#     "summary": "No financial crime or compliance information is present in the content regarding Danske Bank. The content primarily discusses regulatory actions and AML deficiencies related to Nordea Bank, with only a brief mention of Danske Bank in the context of correspondent banking relationships and risk ratings assigned by Nordea. There are no allegations, investigations, fines, or other financial crime compliance actions described for Danske Bank in this content.",
#     "claim_type": "other",
#     "date_published": "2024-09-05",
#     "hyde_score": 0.53
#   },
#   {
#     "url": "https://pythagoras-solutions.com/insights/danske-bank-skandal-ein-wendepunkt-aml-compliance-im-banksektor",
#     "source": "pythagoras-solutions.com",
#     "summary": "The content details the Danske Bank money laundering scandal, describing it as one of the most serious cases in the financial sector. It alleges that between 2007 and 2015, over 200 billion euros of suspicious funds were laundered through Danske Bank's Estonian branch. The scandal revealed significant deficiencies in Danske Bank's AML (Anti-Money Laundering) controls, with thousands of suspicious transactions going undetected due to inadequate internal compliance mechanisms. The case led to extensive investigations, reputational damage, and calls for stricter AML regulations and reforms across the European banking sector. The summary also notes that Danske Bank's compliance structure and corporate culture were found insufficient for managing money laundering risks.",
#     "claim_type": "allegation",
#     "date_published": "2024-04-10",
#     "hyde_score": 0.53
#   },
#   {
#     "url": "https://financialcrimeacademy.org/de/geldwasche-aufgedeckt-bemerkenswerte-falle-und-beispiele-enthullt/",
#     "source": "financialcrimeacademy.org",
#     "summary": "Danske Bank's Estonian branch was involved in a major money laundering scandal between 2007 and 2015, serving as a channel for an estimated $228 billion in laundered funds. Thousands of suspicious customers were implicated in the scheme, which brought public attention to significant compliance failures at Danske Bank. Danish authorities imposed fines totaling $2 million and attributed responsibility to several managers of the bank.",
#     "claim_type": "fine",
#     "date_published": "2025-10-28",
#     "hyde_score": 0.52
#   },
#   {
#     "url": "https://www.zuckermanlaw.com/uncategorized/money-laundering-sec-whistleblower-program/",
#     "source": "www.zuckermanlaw.com",
#     "summary": "Danske Bank agreed to pay $413 million to settle charges that it violated the antifraud provisions of the Securities Exchange Act of 1934 by misleading investors about its anti-money laundering (AML) compliance program in its Estonian branch and failing to disclose the risks posed by the program\u2019s significant deficiencies. Danske Bank has agreed to pay more than $2 billion as part of an integrated, global resolution with the SEC, the Department of Justice, the United States Attorney\u2019s Office for the Southern District of New York, and Denmark\u2019s Special Crime Unit. The settlement addresses significant AML compliance failures and related investor disclosures.",
#     "claim_type": "settlement",
#     "date_published": "Unknown",
#     "hyde_score": 0.52
#   },
#   {
#     "url": "https://financialcrimeacademy.org/fr/blanchiment-dargent-demasque-des-cas-et-des-exemples-notables-devoiles/",
#     "source": "financialcrimeacademy.org",
#     "summary": "Danske Bank's Estonian branch was involved in a major money laundering scandal, acting as an intermediary for approximately $228 billion in laundered funds between 2007 and 2015. The case involved thousands of suspicious clients and significant compliance failures. Danish authorities imposed fines totaling $2 million and attributed responsibility to several bank officials. This case highlighted serious deficiencies in Danske Bank's AML compliance program and failures in transaction monitoring and customer due diligence.",
#     "claim_type": "fine",
#     "date_published": "2025-08-29",
#     "hyde_score": 0.5
#   },
#   {
#     "url": "https://www.twobirds.com/fr/insights/2025/france/lcb-ft-retrospective-2024-partie-2",
#     "source": "www.twobirds.com",
#     "summary": "Danske Bank A/S entered into a judicial public interest agreement (CJIP) with the French financial prosecutor on August 27, 2024, which was validated by the president of the Paris judicial court on September 18, 2024. The settlement followed a judicial investigation opened in April 2015 that uncovered financial flows constituting tax fraud committed by the manager of Decobat, with funds transiting through accounts in Estonia held at Danske Bank's Estonian branch, Sampo Bank. The manager of Decobat was convicted in January 2024 for tax fraud and laundering of tax fraud. Danske Bank A/S was indicted in February 2019 for laundering of organized tax fraud, accused of opening fictitious transit accounts to receive money from organized tax fraud and allowing these accounts to be debited through multiple unjustified transactions to conceal the destination of misappropriated funds and benefit foreign recipients. The public interest fine of \u20ac6,028,799 was validated, taking into account Danske Bank's active cooperation, corrective measures, and relevant internal investigations conducted in the context of proceedings by Danish and American regulators.",
#     "claim_type": "settlement",
#     "date_published": "2025-05-27",
#     "hyde_score": 0.5
#   },
#   {
#     "url": "https://theconversation.com/blanchiment-dargent-leurope-passe-enfin-a-laction-258091",
#     "source": "theconversation.com",
#     "summary": "Danske Bank is cited as the epicenter of the largest money laundering scandal in Europe, with revelations that over \u20ac200 billion in suspicious transactions passed through its Estonian branch. The article discusses this as part of a broader analysis of anti-money laundering (AML) failures and scandals involving major EU banks. It highlights systemic deficiencies in AML controls and supervision within the European Union, referencing Danske Bank's involvement in large-scale illicit financial flows as a key example of such failures.",
#     "claim_type": "allegation",
#     "date_published": "2025-07-15",
#     "hyde_score": 0.48
#   },
#   {
#     "url": "https://www.tookitaki.com/blog/from-wachovia-to-danske-bank-biggest-money-laundering-cases-in-recent-times",
#     "source": "www.tookitaki.com",
#     "summary": "Danske Bank, Denmark\u2019s largest bank, was implicated in a major money laundering scandal involving its Estonian branch. The European Commission described it as the biggest scandal in Europe, with allegations that thousands of suspicious customers used the bank\u2019s weak controls to carry out illicit transactions worth about US$228 billion during 2007-2015. The content highlights deficiencies in Danske Bank\u2019s anti-money laundering controls that allegedly enabled these illicit activities.",
#     "claim_type": "allegation",
#     "date_published": "2019-03-25",
#     "hyde_score": 0.48
#   },
#   {
#     "url": "https://coredo.eu/ru/tri-jetapa-otmyvanija-deneg-i-ih-vlijanie-na-biznes/",
#     "source": "coredo.eu",
#     "summary": "Danske Bank was recently fined \u20ac470 million (US$495 million) due to its involvement in an international money laundering scandal. The content highlights that the fine was imposed as a consequence of Danske Bank's participation in money laundering activities, emphasizing the significant regulatory penalties that can result from such compliance failures.",
#     "claim_type": "fine",
#     "date_published": "Unknown",
#     "hyde_score": 0.48
#   },
#   {
#     "url": "https://dineka.ru/news/1374/",
#     "source": "dineka.ru",
#     "summary": "In 2018, Danske Bank was involved in one of the largest money laundering scandals in Europe. Approximately 200 billion euros in suspicious transactions were processed through the bank's Estonian branch. As a result, Danske Bank was fined hundreds of millions of dollars, its management faced serious criticism, and the bank suffered significant reputational losses. The investigation revealed that Danske Bank failed to properly check its clients and did not conduct adequate transaction monitoring.",
#     "claim_type": "fine",
#     "date_published": "2024-06-07",
#     "hyde_score": 0.48
#   },
#   {
#     "url": "https://pideeco.be/fr/articles/comment-les-gatekeepers-sont-utilises-pour-le-blanchiment-dargent/",
#     "source": "pideeco.be",
#     "summary": "Danske Bank was involved in a major international money laundering scandal revealed in 2018, where approximately \u20ac200 billion in suspicious funds were laundered through its Estonian branch between 2007 and 2015. The scandal highlighted the role of professionals, including lawyers, in facilitating money laundering by creating shell companies and complex corporate structures to obscure the origin and ownership of funds. Danske Bank was fined \u20ac470 million for its involvement in this case, which exposed deficiencies in regulatory oversight and compliance controls in Estonia. The case is cited as a prominent example of how gatekeepers can be exploited for money laundering purposes.",
#     "claim_type": "fine",
#     "date_published": "2024-11-18",
#     "hyde_score": 0.48
#   },
#   {
#     "url": "https://blog.transworldcompliance.com/fr/des-amendes-qui-font-froid-dans-le-dos-les-sanctions-les-plus-effrayantes-en-cas-de-non-conformite-dans-le-secteur-financier",
#     "source": "blog.transworldcompliance.com",
#     "summary": "Danske Bank was involved in a major money laundering scandal, where its Estonian branch allegedly laundered approximately $230 billion in suspicious transactions between 2007 and 2015, mainly from Russian clients. The scandal became public in 2018, and Danish regulators imposed a fine on Danske Bank for anti-money laundering (AML) failures. Investigations revealed that Danske Bank lacked adequate controls, allowing criminal networks to exploit its systems for illicit transactions. The bank faced regulatory penalties, legal proceedings, shareholder challenges, and significant reputational damage. Senior executives resigned, and the bank's reputation suffered due to these compliance failures.",
#     "claim_type": "fine",
#     "date_published": "Unknown",
#     "hyde_score": 0.48
#   },
#   {
#     "url": "https://www.tadviser.ru/index.php/%D0%A1%D1%82%D0%B0%D1%82%D1%8C%D1%8F:%D0%9E%D1%82%D0%BC%D1%8B%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5_%D0%B4%D0%B5%D0%BD%D0%B5%D0%B3_(Money_Muling)",
#     "source": "www.tadviser.ru",
#     "summary": "The content references allegations of large-scale money laundering through the Estonian branch of Danske Bank. According to the information, between 2007 and 2015, \u20ac201 billion of suspicious origin passed through Danske Bank's Estonian branch, with the transactions primarily involving non-resident clients who had ceased operations by that time. Ten former employees of Danske Bank, mainly client managers, were detained and accused of money laundering, with the total amount of suspicious transactions cited as approximately \u20ac300 million. The allegations include claims that bank staff, under the leadership of the branch head, created conditions for large-scale money laundering and concealed these activities. The Central Bank of Russia reportedly warned Danske Bank's Estonian branch about possible illegal transfers by Russian clients as early as 2013, but Danske Bank did not take the necessary measures. The scandal led to the resignation of Danske Bank's CEO, Thomas Borgen.",
#     "claim_type": "allegation",
#     "date_published": "Unknown",
#     "hyde_score": 0.46
#   },
#   {
#     "url": "https://exkulpa.de/geldwaeschepraevention/geldwaescheparadies-deutschland-ursachen-eu-vergleich-folgen/",
#     "source": "exkulpa.de",
#     "summary": "Danske Bank war in einen der gr\u00f6\u00dften Geldw\u00e4scheskandale Europas verwickelt. \u00dcber die estnische Niederlassung der Bank wurden zwischen 2007 und 2015 rund 200 Milliarden Euro verd\u00e4chtiger Gelder, haupts\u00e4chlich aus Russland, Aserbaidschan und der Ukraine, gewaschen. Der Skandal f\u00fchrte zu einem massiven Vertrauensverlust und einer erheblichen Belastung des Rufs der Bank. Die d\u00e4nischen und estnischen Beh\u00f6rden sowie internationale Regulierungsbeh\u00f6rden f\u00fchrten umfassende Untersuchungen durch, was zu hohen Geldstrafen und dem R\u00fccktritt des CEO f\u00fchrte.",
#     "claim_type": "fine",
#     "date_published": "2024-07-30",
#     "hyde_score": 0.44
#   },
#   {
#     "url": "https://finance.ua/goodtoknow/skhemy-vidmyvannia-hroshei-nairezonansnishi-spravy-svitu",
#     "source": "finance.ua",
# ...
#     "claim_type": "settlement",
#     "date_published": "2024-09-20",
#     "hyde_score": 0.42
#   },
#   {
#     "url": "https://www.occrp.org/ru/ficher/utecka-iz-swedbank-pokazala-cto-sotrudniki-banka-sutili-pro-sxemy-otmyvaniia-deneg",
#     "source": "www.occrp.org",
#     "summary": "The content reports that in 2019, journalists revealed that Swedbank and Danske Bank were used to move nearly six billion dollars through suspicious accounts in the Baltic countries. The OCCRP investigation found that Swedbank assisted a high-profile client, Russian oligarch and former minister Mikhail Abyzov, in transferring hundreds of millions of dollars to offshore accounts, with $53 million later determined by a Russian court to have been embezzled. Danske Bank is mentioned as being involved in the transfer of funds through suspicious accounts in the Baltics alongside Swedbank. Official investigations were launched into Swedbank's activities, focusing on money laundering and the concealment of beneficial ownership, but the Estonian case was closed in February 2024 due to lack of cooperation from Russian authorities. The content explicitly links Danske Bank to the movement of suspicious funds in the Baltics, but does not provide details of specific investigations, charges, or penalties against Danske Bank in this context.",
#     "claim_type": "investigation",
#     "date_published": "2024-11-12",
#     "hyde_score": 0.42
#   },
#   {
#     "url": "https://www.socialistsanddemocrats.eu/de/newsroom/die-sd-fraktion-begruesst-die-bahnbrechende-einigung-beim-eu-anti-geldwaesche-paket",
#     "source": "www.socialistsanddemocrats.eu",
#     "summary": "The content references scandals involving Danske Bank and Credit Suisse as part of the justification for new EU anti-money laundering legislation. It mentions that the reforms were necessary in light of these scandals, implying allegations of money laundering or compliance failures at Danske Bank. However, no specific details, outcomes, or new developments regarding Danske Bank are provided in the content.",
#     "claim_type": "allegation",
#     "date_published": "Unknown",
#     "hyde_score": 0.4
#   },
#   {
#     "url": "https://rus.postimees.ee/8338600/ssha-vydelili-estonii-milliony-na-borbu-s-otmyvaniem-deneg",
#     "source": "rus.postimees.ee",
#     "summary": "Danske Bank was involved in a money laundering case that resulted in the United States allocating $50 million (48.8 million euros) to Estonia as part of a settlement for Estonia's contribution to resolving the so-called Danske Bank money laundering case. The funds, originating from fines paid in connection with the Danske Bank case, are being used in Estonia for the prevention, detection, and investigation of financial crimes, including money laundering, cybercrime, and terrorism financing. The projects funded aim to strengthen Estonia's capacity to combat financial crime, improve investigation practices, enhance technological support, and provide sustainable training for specialists. The allocation of these funds underscores the international cooperation between Estonia and the United States in fighting financial crime.",
#     "claim_type": "fine",
#     "date_published": "2025-10-08",
#     "hyde_score": 0.4
#   },
#   {
#     "url": "https://tribuna.ee/tribuna/economy/usa-finansirujut-proekty-estonia-predotvrashenie-korriptsii/",
#     "source": "tribuna.ee",
#     "summary": "No financial crime or compliance information is present in the content regarding Danske Bank. The content discusses U.S. funding for Estonian projects aimed at preventing corruption and money laundering, referencing the \"so-called money laundering case in Danske Bank\" as the context for the funding, but does not provide any new allegations, investigations, charges, fines, settlements, or other compliance actions specifically involving Danske Bank.",
#     "claim_type": "other",
#     "date_published": "2025-11-09",
#     "hyde_score": 0.38
#   },
#   {
#     "url": "https://www.produktion.de/wirtschaft/die-10-groessten-wirtschaftsskandale-in-deutschland-383.html",
#     "source": "www.produktion.de",
#     "summary": "Danske Bank was involved in one of the largest US money laundering scandals. Between 2008 and 2016, Danske Bank defrauded several US banks and was sentenced to a billion-dollar fine. The Deutsche Bank processed suspicious transactions worth more than $267 billion for Danske Bank. The case involved significant deficiencies in anti-money laundering measures and compliance failures related to Danske Bank's Estonian subsidiary.",
#     "claim_type": "fine",
#     "date_published": "2024-01-16",
#     "hyde_score": 0.33
#   }
# ]
# Extracted 18 unique claims from 25 summaries
# [EvidenceClaim(claim_text='Between 2007 and 2015, Danske Bank was alleged to have laundered over €200 billion in suspicious funds through its Estonian branch, exposing significant deficiencies in its anti-money laundering controls and compliance mechanisms.', claim_type='allegation', supporting_urls=['https://pythagoras-solutions.com/en/insights/danske-bank-scandal-turning-point-aml-compliance-of-banking-sector', 'https://pythagoras-solutions.com/insights/danske-bank-skandal-ein-wendepunkt-aml-compliance-im-banksektor', 'https://theconversation.com/blanchiment-dargent-leurope-passe-enfin-a-laction-258091', 'https://www.tookitaki.com/blog/from-wachovia-to-danske-bank-biggest-money-laundering-cases-in-recent-times'], date_publish='2019-03-25'), EvidenceClaim(claim_text="Allegations were made that between 2007 and 2015, €201 billion of suspicious origin passed through Danske Bank's Estonian branch, with ten former employees accused of money laundering and the Central Bank of Russia warning Danske Bank about possible illegal transfers by Russian clients as early as 2013.", claim_type='allegation', supporting_urls=['https://www.tadviser.ru/index.php/%D0%A1%D1%82%D0%B0%D1%82%D1%8C%D1%8F:%D0%9E%D1%82%D0%BC%D1%8B%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5_%D0%B4%D0%B5%D0%BD%D0%B5%D0%B3_(Money_Muling)'], date_publish='Unknown'), EvidenceClaim(claim_text='Danske Bank was referenced in the context of scandals that prompted new EU anti-money laundering legislation, implying allegations of money laundering or compliance failures, though no specific new developments were provided.', claim_type='allegation', supporting_urls=['https://www.socialistsanddemocrats.eu/de/newsroom/die-sd-fraktion-begruesst-die-bahnbrechende-einigung-beim-eu-anti-geldwaesche-paket'], date_publish='Unknown'), EvidenceClaim(claim_text='Danske Bank was subject to investigations by Danish, Estonian, U.S., and U.K. authorities following the revelation that over $230 billion in suspicious transactions were processed through its Estonian branch between 2007 and 2015, leading to the resignation of key executives and the closure of the Estonian branch in 2019.', claim_type='investigation', supporting_urls=['https://www.sanctionscanner.com/blog/danske-bank-case-money-laundering-scandal-1130'], date_publish='2025-06-20'), EvidenceClaim(claim_text='In 2019, journalists revealed that Swedbank and Danske Bank were used to move nearly six billion dollars through suspicious accounts in the Baltic countries, with Danske Bank linked to the movement of suspicious funds in the Baltics alongside Swedbank.', claim_type='investigation', supporting_urls=['https://www.occrp.org/ru/ficher/utecka-iz-swedbank-pokazala-cto-sotrudniki-banka-sutili-pro-sxemy-otmyvaniia-deneg'], date_publish='2024-11-12'), EvidenceClaim(claim_text='Danske Bank agreed to pay the French government €6.3 million to settle money laundering charges related to its Estonian branch, following a deferred prosecution agreement with France’s National Financial Prosecutor, with the settlement validated by the Paris judicial court on September 18, 2024.', claim_type='settlement', supporting_urls=['https://www.moneylaundering.com/news/danske-bank-pays-e6-3-million-to-settle-money-laundering-charges-in-france/', 'https://www.twobirds.com/fr/insights/2025/france/lcb-ft-retrospective-2024-partie-2', 'https://navacelle.law/fr/cjip-danske-bank/'], date_publish='2024-09-18'), EvidenceClaim(claim_text='Danske Bank agreed to pay more than $2 billion as part of a global settlement with the U.S. Department of Justice, the SEC, the United States Attorney’s Office for the Southern District of New York, and Denmark’s Special Crime Unit, addressing significant AML compliance failures and related investor disclosures.', claim_type='settlement', supporting_urls=['https://www.zuckermanlaw.com/uncategorized/money-laundering-sec-whistleblower-program/'], date_publish='Unknown'), EvidenceClaim(claim_text="On January 7, 2025, the US Department of Justice announ ...
# Executing generate_risk_assessment...
# State keys dict_keys(['messages', 'search_results', 'filtered_results', 'entity_name', 'expanded_query', 'max_journalists', 'journalists', 'hyde_list', 'evidence_claims'])
# Claim types: ['allegation', 'conviction', 'fine', 'investigation', 'settlement']
# Iterate through claim cases:
# Request LLM Response
# Example of evidence_prompt:  Evidence for Danske Bank:
#
# ALLEGATION:
# [
#   {
#     "text": "Between 2007 and 2015, Danske Bank was alleged to have laundered over €200 billion in suspicious funds through its Estonian branch, exposing significant deficiencies in its anti-money laundering controls and compliance mechanisms.",
#     "sources": 4,
#     "date_publish": "2019-03-25"
#   },
#   {
#     "text": "Allegations were made that between 2007 and 2015, €201 billion of suspicious origin passed through Danske Bank's Estonian branch, with ten former employees accused of money laundering and the Central Bank of Russia warning Danske Bank about possible illegal transfers by Russian clients as early as 2013.",
#     "sources": 1,
#     "date_publish": "Unknown"
#   },
#   {
#     "text": "Danske Bank was referenced in the context of scandals that prompted new EU anti-money laundering legislation, implying allegations of money laundering or compliance failures, though no specific new developments were provided.",
#     "sources": 1,
#     "date_publish": "Unknown"
#   }
# ]
#
# CONVICTION:
# [
#   {
#     "text": "In 2022, Danske Bank admitted guilt to conspiracy to commit bank fraud, acknowledging that it provided banking services to suspicious clients through its Estonian branch despite being aware of money laundering risks.",
#     "sources": 1,
#     "date_publish": "2024-07-11"
#   }
# ]
#
# FINE:
# [
#   {
#     "text": "Danske Bank was fined hundreds of millions of dollars following the 2018 revelation that approximately €200 billion in suspicious transactions were processed through its Estonian branch, with investigations revealing failures in client checks and transaction monitoring.",
#     "sources": 1,
#     "date_publish": "2024-06-07"
#   },
#   {
#     "text": "Danish authorities imposed fines totaling $2 million on Danske Bank for its involvement in a major money laundering scandal through its Estonian branch between 2007 and 2015, attributing responsibility to several managers and bank officials.",
#     "sources": 2,
#     "date_publish": "2025-08-29"
#   },
#   {
#     "text": "Danske Bank was fined €470 million for its involvement in a major international money laundering scandal, where approximately €200 billion in suspicious funds were laundered through its Estonian branch between 2007 and 2015, exposing deficiencies in regulatory oversight and compliance controls in Estonia.",
#     "sources": 2,
#     "date_publish": "2024-11-18"
#   },
#   {
#     "text": "Danske Bank was fined by Danish regulators for anti-money laundering failures after its Estonian branch allegedly laundered approximately $230 billion in suspicious transactions between 2007 and 2015, mainly from Russian clients, resulting in regulatory penalties, legal proceedings, and significant reputational damage.",
#     "sources": 1,
#     "date_publish": "Unknown"
#   },
#   {
#     "text": "Danske Bank was fined by Danish and international authorities following investigations into the laundering of approximately €200 billion in suspicious funds through its Estonian branch between 2007 and 2015, resulting in a massive loss of trust and the resignation of the CEO.",
#     "sources": 1,
#     "date_publish": "2024-07-30"
#   },
#   {
#     "text": "Danske Bank was fined as part of a major US money laundering scandal between 2008 and 2016, with the bank defrauding several US banks and being sentenced to a billion-dollar fine, while Deutsche Bank processed suspicious transactions worth more than $267 billion for Danske Bank.",
#     "sources": 1,
#     "date_publish": "2024-01-16"
#   },
#   {
#     "text": "Danske Bank was fined over $2 billion by US authorities in 2022 as a result of an investigation into its Estonian branch's involvement in processing suspicious transactions for high-risk clients through the US financial system.",
#     "sources": 2,
#     "date_publish": "2025-06-20"
#   },
#   {
#     "text": "Danske Bank was fined €6,028,799 and ordered to pay an additional €300,000 in compensation to the French state as part of a judicial public interest agreement (CJIP) with the French National Financial Prosecutor, addressing money laundering of tax fraud committed between 2007 and 2014 via its Estonian branch.",
#     "sources": 2,
#     "date_publish": "2025-05-27"
#   },
#   {
#     "text": "The United States allocated $50 million (48.8 million euros) to Estonia as part of a settlement for Estonia's contribution to resolving the Danske Bank money laundering case, with the funds originating from fines paid in connection with the Danske Bank case and used for financial crime prevention and investigation in Estonia.",
#     "sources": 1,
#     "date_publish": "2025-10-08"
#   }
# ]
#
# INVESTIGATION:
# [
#   {
#     "text": "Danske Bank was subject to investigations by Danish, Estonian, U.S., and U.K. authorities following the revelation that over $230 billion in suspicious transactions were processed through its Estonian branch between 2007 and 2015, leading to the resignation of key executives and the closure of the Estonian branch in 2019.",
#     "sources": 1,
#     "date_publish": "2025-06-20"
#   },
#   {
#     "text": "In 2019, journalists revealed that Swedbank and Danske Bank were used to move nearly six billion dollars through suspicious accounts in the Baltic countries, with Danske Bank linked to the movement of suspicious funds in the Baltics alongside Swedbank.",
#     "sources": 1,
#     "date_publish": "2024-11-12"
#   }
# ]
#
# SETTLEMENT:
# [
#   {
#     "text": "Danske Bank agreed to pay the French government €6.3 million to settle money laundering charges related to its Estonian branch, following a deferred prosecution agreement with France’s National Financial Prosecutor, with the settlement validated by the Paris judicial court on September 18, 2024.",
#     "sources": 3,
#     "date_publish": "2024-09-18"
#   },
#   {
#     "text": "Danske Bank agreed to pay more than $2 billion as part of a global settlement with the U.S. Department of Justice, the SEC, the United States Attorney’s Office for the Southern District of New York, and Denmark’s Special Crime Unit, addressing significant AML compliance failures and related investor disclosures.",
#     "sources": 1,
#     "date_publish": "Unknown"
#   },
#   {
#     "text": "On January 7, 2025, the US Department of Justice announced that Estonia would receive $50 million from assets confiscated in the Danske Bank Estonia money laundering case, as part of a settlement recognizing Estonia's assistance in the investigation; Danske Bank admitted responsibility for misleading US banks and processing suspicious transactions for high-risk clients, and was fined over $2 billion by US authorities in 2022.",
#     "sources": 1,
#     "date_publish": "2025-01-07"
#   }
# ]
#
# Based on this evidence:
# 1. Calculate the total fines paid
# 2. Identify the most serious issue (hint: look for large transaction amounts)
# 3. Determine if this is historical or ongoing risk
# 4. Make your partnership recommendation with clear reasoning
#
# Risk assessment completed

# %%
results
# Out:
# {'messages': [HumanMessage(content='Danske Bank money laundering criminal activity', additional_kwargs={}, response_metadata={}, id='545478b8-c26d-4a23-963e-b48629251de6'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 251, 'prompt_tokens': 1063, 'total_tokens': 1314, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_4c2851f862', 'id': 'chatcmpl-Ca2ijlrlS16FBebxcDYZoeOqXEjd7', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--6775ae3a-6a0c-4b4f-bae3-67f160e6cadb-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'Danske Bank money laundering criminal activity', 'num_results': 10, 'hl': 'ro', 'lr': 'lang_ro', 'dateRestrict': 'y2', 'wikipedia_lang': 'ro'}, 'id': 'call_H1zs5A9qCokECQsGFbYw2rNA', 'type': 'tool_call'}, {'name': 'google_search', 'args': {'query': 'Danske Bank money laundering criminal activity', 'num_results': 10, 'hl': 'en', 'lr': 'lang_en', 'dateRestrict': 'y2', 'wikipedia_lang': 'en'}, 'id': 'call_r7b5fCA9NWtyRayw9CBCqoo0', 'type': 'tool_call'}, {'name': 'google_search', 'args': {'query': 'Danske Bank money laundering criminal activity', 'num_results': 10, 'hl': 'ru', 'lr': 'lang_ru', 'dateRestrict': 'y2', 'wikipedia_lang': 'ru'}, 'id': 'call_MLsE0Ss1NgTyc1ZXMVnCvd4n', 'type': 'tool_call'}, {'name': 'google_search', 'args': {'query': 'Danske Bank money laundering criminal activity', 'num_results': 10, 'hl': 'fr', 'lr': 'lang_fr', 'dateRestrict': 'y2', 'wikipedia_lang': 'fr'}, 'id': 'call_QI06nE5G2mJkHEB0Bb6uGokg', 'type': 'tool_call'}, {'name': 'google_search', 'args': {'query': 'Danske Bank money laundering criminal activity', 'num_results': 10, 'hl': 'de', 'lr': 'lang_de', 'dateRestrict': 'y2', 'wikipedia_lang': 'de'}, 'id': 'call_iUbfVXkcOooospj6QLTr7lVI', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1063, 'output_tokens': 251, 'total_tokens': 1314, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content=[{'query': 'Danske Bank spălare de bani activitate infracțională', 'title': '(PDF) Trolii Lui Putin Jessikka Aro', 'link': 'https://www.academia.edu/87046267/Trolii_Lui_Putin_Jessikka_Aro', 'snippet': '4 feb. 2024 ... ... bani săvârșită de ruși la filiala din Estonia a băncii „Danske Bank”. ... Banca Danske fusese suspectată că ar fi luat parte la operațiunile de spălare de bani\xa0...', 'displayLink': 'www.academia.edu'}, {'query': 'Danske Bank spălare de bani activitate infracțională', 'title': '“Toţi am ajuns ca nişte necuraţi şi toate faptele noastre bune sunt ca ...', 'link': 'http://www.informatii-agrorurale.ro/agropedia/cum-poti-sa-devii-crestin-pasi-prin-evanghelie-in-primul-rand-poti-fi-sigur-ca-dumnezeu-iubeste-neconditionat-si-pe-cel-mai-murdar-vinovat-si-doreste-sa-devii-una-cu-el/', 'snippet': '28 iul. 2024 ... “Ce -i drept, toţi umblă după foloasele lor şi nu după ale lui Isus Hristos.” (Fil.2/21), până se nasc din nou din sămânţa lui Dumnezeu (Luca 8/11), ca să nu\xa0...', 'displayLink': 'www.informatii-agrorurale.ro'}], name='google_search', id='bf050232-6469-488a-a7f1-4835cd9317fa', tool_call_id='call_H1zs5A9qCokECQsGFbYw2rNA'),
#   ToolMessage(content=[{'query': 'Danske Bank money laundering criminal activity', 'title': '2024 National Money Laundering Risk Assessment (NMLRA)', 'link': 'https://home.treasury.gov/system/files/136/2024-National-Money-Laundering-Risk-Assessment.pdf?', 'snippet': "Feb 1, 2024 ... Money laundering enables criminal activity and is necessary to disguise ... Danske Bank also knew that Danske Bank Estonia's anti-money laundering program.", 'displayLink': 'home.treasury.gov'}, {'query': 'Danske Bank money laundering criminal activity', 'title': 'Fighting financial crime', 'link': 'https://danskebank.com/about-us/corporate-governance/compliance/fighting-financial-crime', 'snippet': "Feb 7, 2025 ... At Danske Bank, we adhere to the principles developed by Finance Denmark's Anti-Money Laundering and Counter-Terrorist Financing Taskforce in which we\xa0...", 'displayLink': 'danskebank.com'}, {'query': 'Danske Bank money laundering criminal activity', 'title': 'Danske Bank Case: Money Laundering Scandal - Sanction Scanner', 'link': 'https://www.sanctionscanner.com/blog/danske-bank-case-money-laundering-scandal-1130', 'snippet': 'Jun 20, 2025 ... ... money, which can always be potentially linked to money laundering or other criminal activities, to flow through the system undetected. In addition to these\xa0...', 'displayLink': 'www.sanctionscanner.com'}, {'query': 'Danske Bank money laundering criminal activity', 'title': 'Financial Crime Policy - Danske Bank', 'link': 'https://danskebank.com/-/media/danske-bank-com/file-cloud/2021/5/financial-crime-policy.pdf?rev=ad7e611592334042afcda054aa43431f&hash=D137E7CD1A45AF978631626263F53D7A', 'snippet': 'Mar 20, 2025 ... Where legally permissible, detection Controls must include: • transaction and activity monitoring for money laundering (“ML”)/terrorist financing (“TF”) risks,.', 'displayLink': 'danskebank.com'}, {'query': 'Danske Bank money laundering criminal activity', 'title': 'The Biggest Money Laundering Cases: From Wachovia to Danske ...', 'link': 'https://www.tookitaki.com/blog/from-wachovia-to-danske-bank-biggest-money-laundering-cases-in-recent-times', 'snippet': 'Oct 28, 2025 ... Money laundering – the criminal activity of processing criminal proceeds to ... banks, helped Russian criminals launder an estimated US$70 billion in 1998.', 'displayLink': 'www.tookitaki.com'}, {'query': 'Danske Bank money laundering criminal activity', 'title': 'Danske Bank Pays €6.3 Million to Settle Money Laundering ...', 'link': 'https://www.moneylaundering.com/news/danske-bank-pays-e6-3-million-to-settle-money-laundering-charges-in-france/', 'snippet': 'Sep 18, 2024 ... Danske Bank on Wednesday agreed to pay the French government €6.3 million in penalties to settle money laundering charges linked to a notorious financial crime\xa0...', 'displayLink': 'www.moneylaundering.com'}, {'query': 'Danske Bank money laundering criminal activity', 'title': 'Anti-Money Laundering Whistleblowing and the SEC Whistleblower ...', 'link': 'https://www.zuckermanlaw.com/uncategorized/money-laundering-sec-whistleblower-program/', 'snippet': 'Aug 20, 2024 ... Danske Bank has agreed to pay more than $2 billion as part of an integrated ... criminal activity. Broker-dealers are required to file the SAR 30\xa0...', 'displayLink': 'www.zuckermanlaw.com'}, {'query': 'Danske Bank money laundering criminal activity', 'title': "Anti-Money Laundering Compliance: AI's Impact - Transform ...", 'link': 'https://lucinity.com/blog/reshaping-anti-money-laundering-compliance-the-impact-of-ai-on-financial-integrity', 'snippet': 'Apr 8, 2024 ... ... activities, such as drug trafficking, terrorism financing, and other serious crimes. ... Danske Bank- Facing challenges with its existing AML processes, Danske\xa0...', 'displayLink': 'lucinity.com'}, {'query': 'Danske Bank money laundering criminal activity', 'title': 'Danske Bank Scandal: Turning Point AML Compliance of Banking ...', 'link': 'https://pythagoras-solutions.com/en/insights/dans ...
#   ToolMessage(content=[{'query': 'Danske Bank отмывание денег преступная деятельность', 'title': 'ОБЗОР СОБЫТИЙ В СФЕРЕ ПРОТИВОДЕЙСТВИЯ ...', 'link': 'https://www.cbr.ru/Collection/Collection/File/55401/Jan_2025.pdf', 'snippet': '30 янв. 2025\u202fг. ... Danske Bank был оштрафован на более чем 2 млрд долларов США (более 204,5 млрд рублей в эквиваленте). 4 The size of money laundering and other illicit financial\xa0...', 'displayLink': 'www.cbr.ru'}, {'query': 'Danske Bank отмывание денег преступная деятельность', 'title': 'США выделили Эстонии миллионы на борьбу с отмыванием денег', 'link': 'https://rus.postimees.ee/8338600/ssha-vydelili-estonii-milliony-na-borbu-s-otmyvaniem-deneg', 'snippet': '8 окт. 2025\u202fг. ... США и Эстония подписали соглашение о разделе денег, полученных от выплаты штрафов Danske Bank. ... преступной деятельности - успешнее», - указал Мийлитс.', 'displayLink': 'rus.postimees.ee'}, {'query': 'Danske Bank отмывание денег преступная деятельность', 'title': 'Утечка из Swedbank показала, что сотрудники банка шутили про ...', 'link': 'https://www.occrp.org/ru/ficher/utecka-iz-swedbank-pokazala-cto-sotrudniki-banka-sutili-pro-sxemy-otmyvaniia-deneg', 'snippet': '12 нояб. 2024\u202fг. ... Все поменялось в 2019 году, когда журналисты шведского телеканала SVT раскрыли, что Swedbank и Danske Bank использовали для перемещения средств (суммарно почти\xa0...', 'displayLink': 'www.occrp.org'}, {'query': 'Danske Bank отмывание денег преступная деятельность', 'title': 'Отмывание денег (Money Muling)', 'link': 'https://www.tadviser.ru/index.php/%D0%A1%D1%82%D0%B0%D1%82%D1%8C%D1%8F:%D0%9E%D1%82%D0%BC%D1%8B%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5_%D0%B4%D0%B5%D0%BD%D0%B5%D0%B3_(Money_Muling)', 'snippet': '14 окт. 2024\u202fг. ... "Серые" сделки связаны с бизнесом клиентов-нерезидентов, прекративших на тот момент свою деятельность. По делу были задержаны 10 бывших сотрудников Danske Bank.', 'displayLink': 'www.tadviser.ru'}, {'query': 'Danske Bank отмывание денег преступная деятельность', 'title': 'Три этапа отмывания денег и их влияние на бизнес - COREDO', 'link': 'https://coredo.eu/ru/tri-jetapa-otmyvanija-deneg-i-ih-vlijanie-na-biznes/', 'snippet': '6 авг. 2024\u202fг. ... Например, Danske Bank недавно был оштрафован на 470 миллионов евро (495 ... Благодаря отмыванию средств преступная деятельность может продолжаться. Как\xa0...', 'displayLink': 'coredo.eu'}, {'query': 'Danske Bank отмывание денег преступная деятельность', 'title': 'Схемы отмывания денег: самые резонансные дела в мире', 'link': 'https://finance.ua/goodtoknow/skhemy-vidmyvannia-hroshei-nairezonansnishi-spravy-svitu', 'snippet': '11 июл. 2024\u202fг. ... 1. Что такое отмывание денег ; 2. «Панамские документы» ; 3. «Райские документы» ; 4. Скандал с отмыванием денег Danske Bank ; 5. Отмывание денег Полом Манафортом.', 'displayLink': 'finance.ua'}, {'query': 'Danske Bank отмывание денег преступная деятельность', 'title': 'Прозрачность и подотчетность - ключевые аспекты ...', 'link': 'https://dineka.ru/news/1374/', 'snippet': '7 июн. 2024\u202fг. ... Санкции за несоблюдение требований · Airbnb и незаконная сдача жилья в аренду · Standard Chartered и отмывание денег · Danske Bank и скандал с отмыванием денег', 'displayLink': 'dineka.ru'}, {'query': 'Danske Bank отмывание денег преступная деятельность', 'title': 'Kapital Bank', 'link': 'https://www.kapitalbank.az/ru/compliance', 'snippet': '17 июл. 2024\u202fг. ... Борьба с легализацией имущества, полученного преступным путем, и ... Мы осознаем, что предотвращение отмывания денег и выявление возможной деятельности\xa0...', 'displayLink': 'www.kapitalbank.az'}, {'query': 'Danske Bank отмывание денег преступная деятельность', 'title': 'Успех в деле о конфискации денежных средств клиента ABLV ...', 'link': 'https://www.njordlaw.com/ru/uspekh-v-dele-o-konfiskacii-denezhnykh-sredstv-klienta-ablv-banka-esche-odin-klient-uzhe-poluchil', 'snippet': '4 сент. 2024\u202fг. ... Адвокаты NJORD в очередной раз добились прекращения  ...
#   ToolMessage(content=[{'query': "Danske Bank blanchiment d'argent activité criminelle", 'title': "Blanchiment d'argent — Wikipédia", 'link': 'https://fr.wikipedia.org/wiki/Blanchiment_d%27argent', 'snippet': "1 avr. 2025 ... Blanchiment d'argent. activité criminelle consistant à dissimuler la provenance d'argent acquis de manière illégale ... Danske Bank (une affaire de blanchiment\xa0...", 'displayLink': 'fr.wikipedia.org'}, {'query': "Danske Bank blanchiment d'argent activité criminelle", 'title': "Blanchiment D'argent Démasqué : Des Cas Et Des Exemples ...", 'link': 'https://financialcrimeacademy.org/fr/blanchiment-dargent-demasque-des-cas-et-des-exemples-notables-devoiles/', 'snippet': "28 oct. 2025 ... Le blanchiment d'argent est une activité criminelle complexe, clandestine et qui a de profondes implications. ... L'affaire Danske Bank. La succursale\xa0...", 'displayLink': 'financialcrimeacademy.org'}, {'query': "Danske Bank blanchiment d'argent activité criminelle", 'title': "Blanchiment d'argent : l'Europe passe (enfin) à l'action", 'link': 'https://theconversation.com/blanchiment-dargent-leurope-passe-enfin-a-laction-258091', 'snippet': "15 juil. 2025 ... Dans l'Union européenne, le produit des activités criminelles est ... La Danske Bank est devenue l'épicentre du plus grand scandale de blanchiment\xa0...", 'displayLink': 'theconversation.com'}, {'query': "Danske Bank blanchiment d'argent activité criminelle", 'title': 'Des amendes qui font froid dans le dos : Les sanctions les plus ...', 'link': 'https://blog.transworldcompliance.com/fr/des-amendes-qui-font-froid-dans-le-dos-les-sanctions-les-plus-effrayantes-en-cas-de-non-conformite-dans-le-secteur-financier', 'snippet': "28 nov. 2024 ... ... activités économiques criminelles. Les réglementations en matière ... Le scandale de blanchiment d'argent de la Danske Bank est un autre exemple notoire.", 'displayLink': 'blog.transworldcompliance.com'}, {'query': "Danske Bank blanchiment d'argent activité criminelle", 'title': 'Comment les gatekeepers sont-ils utilisés pour le blanchiment d ...', 'link': 'https://pideeco.be/fr/articles/comment-les-gatekeepers-sont-utilises-pour-le-blanchiment-dargent/', 'snippet': "18 nov. 2024 ... ... blanchiment d'argent et à la criminalité financière. Comment les gatekeepers ... En Europe, le scandale de la Danske Bank en 2018 est un cas bien connu\xa0...", 'displayLink': 'pideeco.be'}, {'query': "Danske Bank blanchiment d'argent activité criminelle", 'title': 'Lutte contre le blanchiment de capitaux et le financement du ...', 'link': 'https://www.twobirds.com/fr/insights/2025/france/lcb-ft-retrospective-2024-partie-2', 'snippet': "27 mai 2025 ... Danske Bank A/S avait quant à elle été mise en examen en février 2019 du ... blanchiment d'argent aggravé. Elle a néanmoins confirmé partiellement les\xa0...", 'displayLink': 'www.twobirds.com'}, {'query': "Danske Bank blanchiment d'argent activité criminelle", 'title': 'RAPPORT', 'link': 'https://www.senat.fr/fileadmin/Structures_temporaires/commissions_d_enquete/CE_Delinquance_financiere/TOME_1_Rapport_CE_Eoldefi.pdf', 'snippet': "18 juin 2025 ... l'économie et la société, le blanchiment constitue en réalité le crime ... criminels les plus menaçants, le blanchiment d'argent est leur seule activité.", 'displayLink': 'www.senat.fr'}, {'query': "Danske Bank blanchiment d'argent activité criminelle", 'title': 'Retour sur la CJIP conclue entre la Danske Bank et le PNF -', 'link': 'https://navacelle.law/fr/cjip-danske-bank/', 'snippet': "20 sept. 2024 ... En juin 2014, TRACFIN a transféré[4] une note au parquet de Paris, faisant état d'une activité ... criminalité financière et le blanchiment d'argent de Danske\xa0...", 'displayLink': 'navacelle.law'}, {'query': "Danske Bank blanchiment d'argent activité criminelle", 'title': 'Lutte contre le blanchiment de capitaux et le financement du ...', 'link': 'https://www.consilium.europa.eu/fr/policies/fight-against-terrorist-financing/', 'snippet': "30 ma ...
#   ToolMessage(content=[{'query': 'Danske Bank Geldwäsche kriminelle Aktivitäten', 'title': 'Der Danske Bank Skandal: Wendepunkt für AML-Compliance im ...', 'link': 'https://pythagoras-solutions.com/insights/danske-bank-skandal-ein-wendepunkt-aml-compliance-im-banksektor', 'snippet': '10.04.2024 ... Zwischen 2007 und 2015 fanden Geldwäsche-Aktivitäten statt. Diese Aktivitäten erfolgten über die estnische Filiale der Danske Bank. Ihr Umfang und ihre\xa0...', 'displayLink': 'pythagoras-solutions.com'}, {'query': 'Danske Bank Geldwäsche kriminelle Aktivitäten', 'title': 'Geldwäsche Aufgedeckt: Bemerkenswerte Fälle Und Beispiele ...', 'link': 'https://financialcrimeacademy.org/de/geldwasche-aufgedeckt-bemerkenswerte-falle-und-beispiele-enthullt/', 'snippet': '28.10.2025 ... Geldwäsche ist eine kriminelle Aktivität, die komplex, heimlich und weitreichend ist. Für Fachleute, die in den Bereichen Compliance, Risikomanagement und\xa0...', 'displayLink': 'financialcrimeacademy.org'}, {'query': 'Danske Bank Geldwäsche kriminelle Aktivitäten', 'title': 'Kampf gegen Geldwäsche in der digitalen Finanzwelt - Consileon ...', 'link': 'https://www.consileon.de/blog/2025/03/24/kampf-gegen-geldwaesche-in-der-digitalen-finanzwelt/', 'snippet': '24.03.2025 ... ... Geldwäsche-Maßnahmen (anti-money laundering, AML) konfrontiert. Fälle wie der Danske-Bank-Skandal verdeutlichen, wie wichtig transparente Richtlinien für\xa0...', 'displayLink': 'www.consileon.de'}, {'query': 'Danske Bank Geldwäsche kriminelle Aktivitäten', 'title': 'Geldwäsche-Prävention: Keine Chance für Kriminelle - ADG Campus', 'link': 'https://www.adg-campus.de/news/keine-chance-fuer-kriminelle/', 'snippet': '12.06.2024 ... Keine Bank möchte in illegale Aktivitäten verwickelt werden – dennoch ist jedes Institut davon bedroht. Über 70 Geldwäschebeauftragte und Spezialisten\xa0...', 'displayLink': 'www.adg-campus.de'}, {'query': 'Danske Bank Geldwäsche kriminelle Aktivitäten', 'title': 'Was ist Geldwäsche? - Consilium', 'link': 'https://www.consilium.europa.eu/de/infographics/anti-money-laundering/', 'snippet': '30.05.2024 ... Geldwäsche und Terrorismusfinanzierung sind für das Wirtschafts- und Finanzsystem der EU ebenso wie für die Sicherheit der EU-Bürgerinnen und Bürger ein\xa0...', 'displayLink': 'www.consilium.europa.eu'}, {'query': 'Danske Bank Geldwäsche kriminelle Aktivitäten', 'title': 'Die S&D-Fraktion begrüßt die bahnbrechende Einigung beim EU ...', 'link': 'https://www.socialistsanddemocrats.eu/de/newsroom/die-sd-fraktion-begruesst-die-bahnbrechende-einigung-beim-eu-anti-geldwaesche-paket', 'snippet': '18.01.2024 ... ... Geldwäsche zu verstärken.Die Bedeutung der neuen Regeln lässt sich anhand ... Danske Bank und die Credit Suisse beteiligt waren, und der jüngsten\xa0...', 'displayLink': 'www.socialistsanddemocrats.eu'}, {'query': 'Danske Bank Geldwäsche kriminelle Aktivitäten', 'title': 'Geldwäscheparadies Deutschland: Ursachen, EU-Vergleich, Folgen', 'link': 'https://exkulpa.de/geldwaeschepraevention/geldwaescheparadies-deutschland-ursachen-eu-vergleich-folgen/', 'snippet': '30.07.2024 ... Fallbeispiele wie die Deutsche Bank, Danske Bank, 1MDB, Wirecard und HSBC illustrieren die vielfältigen Methoden und enormen Dimensionen der Geldwäsche. Die\xa0...', 'displayLink': 'exkulpa.de'}, {'query': 'Danske Bank Geldwäsche kriminelle Aktivitäten', 'title': 'Die 10 größten Wirtschaftsskandale in Deutschland', 'link': 'https://www.produktion.de/wirtschaft/die-10-groessten-wirtschaftsskandale-in-deutschland-383.html', 'snippet': '16.01.2024 ... Platz 4: Deutsche Bank - dienstbar für Geldwäsche im großen Stil ... Die Danske Bank hatte in den Jahren 2008 bis 2016 diverse US-Banken betrogen\xa0...', 'displayLink': 'www.produktion.de'}, {'query': 'Danske Bank Geldwäsche kriminelle Aktivitäten', 'title': 'Erfahrungen mit Festgeldangebot der Danske Bank gesucht', 'link': 'https://www.kritische-anleger.de/forum/festgeld/erfahrungen-mit-festgeldangebot-der-danske-bank-gesucht/', 'snippet':  ...
#   AIMessage(content='**1. EXECUTIVE SUMMARY**\n\nDanske Bank has been implicated in one of the largest money laundering scandals in European history, with over €200 billion in suspicious funds processed through its Estonian branch between 2007 and 2015. The bank has admitted guilt, faced criminal convictions, and paid fines totaling over €2.5 billion across multiple jurisdictions, including the US, Denmark, France, and Estonia. The violations were systemic, spanning nearly a decade, and involved failures in AML controls, client due diligence, and transaction monitoring. While major settlements have been reached and executive resignations have occurred, ongoing investigations and recent fines indicate that the risk is not fully resolved.\n\n**Total Fines Paid Calculation:**\n- €470 million (2024-11-18)\n- $2 million (2025-08-29) ≈ €1.85 million (at $1 = €0.925)\n- Over $2 billion (2025-06-20) ≈ €1.85 billion\n- €6,028,799 + €300,000 = €6.33 million (2025-05-27)\n- $50 million (2025-10-08) ≈ €46.25 million\n- €6.3 million (2024-09-18) [French settlement]\n- Additional fines referenced but not quantified (hundreds of millions, billion-dollar fine, etc.)\n\n**Total (rounded, using largest confirmed numbers and avoiding double-counting):**\n- €470 million + €1.85 billion + €6.33 million + €1.85 million + €46.25 million + €6.3 million = **€2,380,730,000** (approx. €2.38 billion)\n\n**2. VIOLATION ANALYSIS**\n\n- **Nature:** Systemic money laundering through Estonian branch (2007–2015), with €200+ billion in suspicious transactions, mainly from Russian clients.\n- **Criminal Conviction:** Admitted guilt to conspiracy to commit bank fraud (2024-07-11).\n- **Regulatory Failures:** Inadequate AML controls, poor client due diligence, and failure to act on warnings (e.g., from Central Bank of Russia in 2013).\n- **Leadership Accountability:** CEO and key executives resigned; Estonian branch closed in 2019.\n- **Jurisdictions:** Denmark, Estonia, US, UK, France, and broader EU.\n\n**3. CURRENT STATUS**\n\n- **Resolved:** Major settlements with US, Danish, and French authorities; Estonian branch closed; executive resignations.\n- **Ongoing:** Investigations by Danish, Estonian, US, and UK authorities (as of 2025-06-20); recent fines (2025-08-29, 2025-10-08) indicate continued regulatory scrutiny.\n- **Geographic Spread:** Multi-jurisdictional (EU, US, Russia, Baltics).\n- **Recent Activity:** Fines and settlements as recent as October 2025.\n\n**4. TRAJECTORY**\n\n- **Pattern:** Repeated, large-scale violations over many years; fines and settlements continue into 2025.\n- **Improvement:** Some evidence of reform (branch closure, leadership change, settlements), but ongoing investigations and recent fines suggest risk remains elevated.\n- **Quote:** "Danske Bank was fined over $2 billion by US authorities in 2022 as a result of an investigation into its Estonian branch\'s involvement in processing suspicious transactions for high-risk clients through the US financial system." (2025-06-20)\n\n**5. RISK RATING**\n\n**HIGH**  \n- Justification: Systemic, multi-year, multi-jurisdictional AML failures; total fines exceed €2 billion; ongoing investigations; recent fines; criminal conviction; pattern of repeated violations.\n\n**6. PARTNERSHIP RECOMMENDATION**\n\n**AVOID PARTNERSHIP**  \n- Rationale: Ongoing criminal and regulatory investigations, unresolved risk, and a pattern of systemic AML failures with recent enforcement actions. The scale and recency of violations, combined with the magnitude of fines and multi-jurisdictional scrutiny, indicate that Danske Bank remains a high-risk partner for AML compliance.\n\n---\n\n**Summary Table**\n\n| Criteria                | Status/Details                                                                 |\n|-------------------------|-------------------------------------------------------------------------------|\n| Total Fines Paid        | Approx. €2.38 billion (multi-jurisdictional, 2018–2025)        ...
#  'search_results': [LinkCollection(displayLink='lucinity.com', link='https://lucinity.com/blog/reshaping-anti-money-laundering-compliance-the-impact-of-ai-on-financial-integrity', raw_content='Lucinity Platform * [Case Management Alerts, investigations, and reporting in one platform for faster, smarter FinCrime Prevention](/case-management "Alerts, investigations, and reporting in one platform for faster, smarter FinCrime Prevention") * [Luci AI Agent Take FinCrime investigations from hours to minutes with Luci, your AI Agent that automates and simplifies complex investigations](/luci "Take FinCrime investigations from hours to minutes with Luci, your AI Agent that automates and simplifies complex investigations") * [Luci AI Agent Plugin Plug-in our AI Agent wherever you work, safe to use and easy to setup](/luci-plugin "Plug-in our AI Agent wherever you work, safe to use and easy to setup") * [Customer 360° A comprehensive view of customers, seamlessly integrating KYC, transactional, and behavioral data](/profiles "A comprehensive view of customers, seamlessly integrating KYC, transactional, and behavioral data") * [Regulatory Reporting Streamlines the generation and submission of regulatory reports with consistency, completeness, and quality](/regulatory-reporting "Streamlines the generation and submission of regulatory reports with consistency, completeness, and quality") * [Transaction Monitoring Detect all types of FinCrime in one place through Scenario-based and AI-based monitoring](/transaction-monitoring "Detect all types of FinCrime in one place through Scenario-based and AI-based monitoring") * [Configuration Configure your FinCrime system to match your business processes. Set up workflow automations, AI skills, dashboards, and more](https://lucinity.com/configuration "Configure your FinCrime system to match your business processes. Set up workflow automations, AI skills, dashboards, and more") Lucinity Resources * [Case Manager Assessment How Sophisticated Is Your Case Management System? Take the Quiz](https://lucinity.com/case-manager-quiz "How Sophisticated Is Your Case Management System? Take the Quiz") * [Insights Our blogs and thought leadership](/blog "Our blogs and thought leadership") * [Videos and Podcasts Library of videos, webinars, and podcasts](https://lucinity.com/videos-podcasts "Library of videos, webinars, and podcasts") * [Press Lucinity news, media mentions, and press kit](https://lucinity.com/press "Lucinity news, media mentions, and press kit") * [Product Updates Latest products, features, and AI innovations](https://lucinity.com/product-updates "Latest products, features, and AI innovations") * [Guides and Downloads Downloadable infographics, whitepapers, and guides](https://lucinity.com/guides "Downloadable infographics, whitepapers, and guides") * [Events Browse our calendar to see where we\'ll be in Europe and North America](/events "Browse our calendar to see where we\'ll be in Europe and North America") * [Case Studies The results of Lucinity\'s work with our clients](https://lucinity.com/case-studies "The results of Lucinity\'s work with our clients") * [API Documentation Lucinity’s modern and open APIs make integration easy](https://docs.lucinity.com "Lucinity’s modern and open APIs make integration easy") Lucinity * [About us We Make Money Good with faster, smarter FinCrime Prevention](/about-lucinity "We Make Money Good with faster, smarter FinCrime Prevention") * [Leadership Team The team of experts driving Lucinity’s growth](/leadership-team "The team of experts driving Lucinity’s growth") * [Work with us See our open positions](/work-with-lucinity "See our open positions") * [Security Security and compliance is in our DNA](https://security.lucinity.com/ "Security and compliance is in our DNA") * [Contact us Drop us a line](/contact "Drop us a line") * [Partnerships Program Overview of Lucinity\'s Partnerships Program](https://lucinity.com/partnerships "Overview of Lucinity\'s Partne ...
#   LinkCollection(displayLink='danskebank.com', link='https://danskebank.com/about-us/corporate-governance/compliance/fighting-financial-crime', raw_content='Content is loading * [English](/ "English") * [Dansk](/da "Dansk") * [Suomi](/fi "Suomi") * [Norsk](/no "Norsk") * [Svenska](/se "Svenska") * Selected files + 07. feb 2025Risk Management 2024 + 07. feb 2025Corporate Governance Report 2024 [Find more files](/file-cloud) * | | | | --- | --- | | Personal eBanking + [Denmark](https://ebank.danskebank.dk/en/login) + [Finland](https://ebank.danskebank.fi/en/login) + [Norway](https://danskebank.no/privat/faa-hjelp?n-login=pbnettbank) + [Sweden](https://ebank.danskebank.se/sv/login) + [Northern Ireland](https://ebank.danskebank.co.uk/en/login) | Business + [District](https://district.danskebank.com/Logon/#/) + [OneTrader](https://danskebank.com/logon/onetrader) + - [Denmark](https://ebank.danskebank.dk/en/login) - [Finland](https://ebank.danskebank.fi/en/login) - [Norway](https://danskebank.no/privat/faa-hjelp?n-login=pbnettbank) - [Sweden](https://ebank.danskebank.se/sv/login) - [Northern Ireland](https://ebank.danskebank.co.uk/en/login) | # Log on to our self-service solutions [Log on](/ebanking-logon) ## Fighting financial crime Access to the financial system transforms lives globally by helping people achieve their goals and by driving economic development. However, it can also be exploited by criminals for severe crimes like human trafficking and terrorism. Danske Bank is dedicated to fighting financial crime and we have completed a groupwide financial crime enhancement programme, investing in systems and controls to protect the bank and its customers. Continuing to develop and improve our efforts to preserve the integrity of our business and uphold our societal responsibility is a key priority for us. ## How we fight financial crime ### We adhere to Finance Denmark\'s principles At Danske Bank, we adhere to the principles developed by Finance Denmark’s Anti-Money Laundering and Counter-Terrorist Financing Taskforce in which we participated, to prevent and combat money laundering and terrorist financing. These principles are reflected in our approach. * #### We always prioritise ethics over profit * #### We comply with the spirit and the letter of the law * #### We welcome oversight * #### We have a targeted corporate culture commitment * #### We assume managerial responsibility and ensure that all staff take responsibility for AML/CTF efforts * #### We have constructive partnerships with all stakeholders, including the authorities ### We focus on people, partnerships and processes * ### ### We ensure that we have the right PEOPLE and competencies in place to fight financial crime. ### Key initiatives + #### Fighting financial crime is a top priority We have governance structures in place to ensure escalation of compliance matters when required. Our Chief Compliance Officer is a member of our Executive Leadership Team, ensuring that compliance and the fight against financial crime is an integrated part of how we do business. Financial crime prevention is part of our organisational DNA and we nurture a shared mind-set, where employees are mindful of doing the right kind of business with the right customers in the right way. + #### Mandatory fighting financial crime training All employees are required to complete mandatory training in fighting financial crime every year. We also provide targeted financial crime prevention training to employees throughout the organisation, ranging from senior management to frontline advisors. This specialised training considers different learning objectives that are specific to certain roles and includes feedback loops to ensure that we are learning from the past. + #### An essential part of our business We have experienced financial crime prevention specialists in our organisation, and we maintain strong competencies across our three lines of defence. * ### ### We engage proactively with author ...
#   LinkCollection(displayLink='danskebank.com', link='https://danskebank.com/-/media/danske-bank-com/file-cloud/2021/5/financial-crime-policy.pdf?rev=ad7e611592334042afcda054aa43431f&hash=D137E7CD1A45AF978631626263F53D7A', raw_content="Published Time: Mon, 16 Jun 2025 12:24:21 GMT 1. Objective The objective of the Financial Crime Policy (the “Policy”) is to promote a strong Financial Crime compliance culture within the Danske Bank Group to prevent the misuse of the Group’s infrastructure and Products for Financial Crime purposes. In doing so, it protects the Danske Bank Group, our customers and society. # 2. Definitions The definitions for the terms used throughout this Policy are available in Appendix 1. # 3. Scope and target group This Policy establishes the principles for the managing of risks associated with Financial Crime, ensuring compliance with relevant laws, regulations, guidelines and sanctions regimes. The Policy applies to the entire Danske Bank Group. # 4. Policy Content Principle 1: The Group maintains a robust and efficient Financial Crime Program Through its Financial Crime Program, the Group is committed to upholding high standards of integrity and compliance to protect the Group, its customers and society from Financial Crime. The Financial Crime Program is designed to enable the Group to safely carry out its business activities while effectively and efficiently managing the Financial Crime Risks it faces. The Financial Crime Program consists of elements which together form a coherent Financial Crime strategy. The Program is continuously evaluated to allow the Group to proactively anticipate, plan and adapt to emerging risks and changes in relevant laws, reg ulations, guidelines and sanctions regimes. The Financial Crime Program includes, but is not limited to: • a sound Financial Crime compliance culture, strategic prioritisation of Financial Crime compliance and allocation of sufficient funding and resources, • a three lines of defence model ensuring segregation of duties, independent oversight and consistent enforcement of the Group’s governing documents across all lines of defence, • Financial Crime Risk Tolerances, Key Performance Indicators, Key Risk Indicators and monitoring and reporting capabilities, • a Financial Crime governance framework, • frameworks for management of Financial Crime data and technology, including the use of new or innovative technology and maintenance of technical capabilities, • Financial Crime Risk assessments, • a Financial Crime Control framework, # Financial Crime Policy 20 March 2025 MARCH 2025 • Financial Crime detection capabilities, • customer and Third -Party due diligence measures, • unusual and suspicious activity investigation and reporting, • a Financial Crime training program and • reporting, escalation and whistleblowing procedures and solutions ensuring prompt response to Financial Crime. Roles and Responsibilities: • The Board of Directors and the Executive Leadership team are responsible for setting the tone from the top, ensuring strategic prioritisation of the Group’s Financial Crime Program and allocating adequate resourcing, funding and investment. • 1LoD and 2LoD are responsible for developing, implementing and maintaining the Group’s Financial Crime Program in accordance with the respective mandates. • 1LoD and 2LoD are responsible for operating the Financial Crime Program according to the mandates established in the Group’s Enterprise Risk Management Policy and other relevant policies. Principle 2: The Group maintains a governance framework for effective management of Financial Crime Risks The Financial Crime Risk governance framework is essential for effectively managing Financial Crime Risks and is established in accordance with the standards of the Group’s Enterprise Risk Management Policy. The framework must set clear requirements and be sufficiently operational. This includes: • defined roles, responsibilities and accountabilities for the managemen ...
#   LinkCollection(displayLink='www.moneylaunderingnews.com', link='https://www.moneylaunderingnews.com/2024/09/nydfs-imposes-35-million-fine-on-nordea-bank-for-alleged-aml-failures-following-panama-papers-revelations/', raw_content='Published Time: 2024-09-05T00:39:29+00:00 NYDFS Imposes $35 Million Fine on Nordea Bank for Alleged AML Failures Following Panama Papers Revelations | Money Laundering Watch =============== [Skip to content](https://www.moneylaunderingnews.com/2024/09/nydfs-imposes-35-million-fine-on-nordea-bank-for-alleged-aml-failures-following-panama-papers-revelations/#lxb_af-loop) ### [Menu](https://www.moneylaunderingnews.com/2024/09/nydfs-imposes-35-million-fine-on-nordea-bank-for-alleged-aml-failures-following-panama-papers-revelations/#) [![Image 1: Ballard Spahr LLP logo](https://www.moneylaunderingnews.com/wp-content/uploads/sites/12/2016/12/firm-logo-440x73.png)](http://www.ballardspahr.com/) [Home](https://www.moneylaunderingnews.com/)[About](https://www.moneylaunderingnews.com/about/)[Publications](http://www.ballardspahr.com/en/practiceareas/practices/white_collar_investigations/alertspublications.aspx)[Services](https://www.ballardspahr.com/en/practiceareas/practices/white_collar_investigations/anti-money-laundering)[Contact](https://www.moneylaunderingnews.com/contact/)Search… Search [Money Laundering Watch](https://www.moneylaunderingnews.com/) ============================================================== Insights and news on the world of financial corruption [Home](https://www.moneylaunderingnews.com/) » NYDFS Imposes $35 Million Fine on Nordea Bank for Alleged AML Failures Following Panama Papers Revelations NYDFS Imposes $35 Million Fine on Nordea Bank for Alleged AML Failures Following Panama Papers Revelations ========================================================================================================== By [Kelly A. Lenahan-Pfahlert](https://www.ballardspahr.com/people/attorneys/l/lenahan-pfahlert-kelly) on September 4, 2024 Posted in [Civil Penalty](https://www.moneylaunderingnews.com/category/civil-penalty/), [Compliance Program](https://www.moneylaunderingnews.com/category/compliance-program/), [Correspondent Bank Accounts](https://www.moneylaunderingnews.com/category/correspondent-bank-accounts/), [Customer Due Diligence](https://www.moneylaunderingnews.com/category/customer-due-diligence/), [New York Department of Financial Services (NYDFS)](https://www.moneylaunderingnews.com/category/new-york-department-of-financial-services/), [Panama Papers](https://www.moneylaunderingnews.com/category/panama-papers/), [Transaction Monitoring](https://www.moneylaunderingnews.com/category/transaction-monitoring/) ![Image 2](https://www.moneylaunderingnews.com/wp-content/uploads/sites/12/2024/09/AdobeStock_56312148-656x437.jpeg) On August 27, 2024, the New York State Department of Financial Services (“NYDFS”) [announced](https://www.dfs.ny.gov/reports_and_publications/press_releases/pr20240827) a [consent order](https://www.dfs.ny.gov/system/files/documents/2024/08/ea20240827-co-nordea.pdf) involving a $35 million settlement with Nordea Bank Abp (“Nordea”) for alleged significant failures related to anti-money laundering (“AML”) compliance. Nordea, headquartered in Helsinki, Finland, operates globally, including through a licensed branch in New York, [which has its own AML and transaction monitoring requirements](https://www.moneylaunderingnews.com/2017/01/2016-year-in-review-nydfs-finalizes-broad-aml-regulations/). The enforcement action, which followed revelations from the [Panama Papers leak](https://www.moneylaunderingnews.com/2018/12/first-u-s-indictment-relating-to-panama-papers-charges-lawyer-asset-manager-accountant-and-client/), found that Nordea allegedly failed to conduct proper due diligence on high-risk correspondent banking relationships and maintained inadequate AML controls. According to the NYDFS, the Panama Papers implicated Nordea in aiding clients in establishing offshor ...
#   LinkCollection(displayLink='financialcrimeacademy.org', link='https://financialcrimeacademy.org/de/geldwasche-aufgedeckt-bemerkenswerte-falle-und-beispiele-enthullt/', raw_content='[Login](https://lms.financialcrimeacademy.org/users/sign_in) * [AI Copilot](https://financialcrimeacademy.org/de/features/ai-copilot/) * [Training & Certifications](/training/?training_type=all?nocache=1) + [Column](#column) - Block + [Column](#column) - Block - Block + [Column](#column) - Block + [Column](#column) - Block * [Features](/features/) + [Column](#column) - Block + [Column](#column) - Block + [Column](#column) - Block + [Column](#column) - Block * [Pricing](https://financialcrimeacademy.org/de/pricing/) * [Blog](https://financialcrimeacademy.org/de/blog/) [login](https://lms.financialcrimeacademy.org/users/sign_in) # Geldwäsche aufgedeckt: Bemerkenswerte Fälle und Beispiele enthüllt Posted in [Bekämpfung der Geldwäsche (AML)](https://financialcrimeacademy.org/de/category/bekampfung-der-geldwasche-aml/ "Bekämpfung der Geldwäsche (AML)") on Oktober 28, 2025 [Share 0](javascript:void(0)) [Tweet 0](javascript:void(0)) [Share 0](javascript:void(0)) ## Geldwäsche verstehen Geldwäsche ist eine kriminelle Aktivität, die komplex, heimlich und weitreichend ist. Für Fachleute, die in den Bereichen Compliance, Risikomanagement und Bekämpfung von Finanzkriminalität tätig sind, ist es von entscheidender Bedeutung, die Feinheiten zu verstehen. ### Definition und Grundlagen der Geldwäsche Geldwäsche ist der Prozess, bei dem illegal erzielte Erlöse als legal erscheinen. Es ist eine Methode, die von Kriminellen verwendet wird, um ihre Aktivitäten und das damit verbundene Geld zu verschleiern und die Erträge aus ihren Verbrechen legitim erscheinen zu lassen. Dies wird oft durch eine komplexe Abfolge von Banküberweisungen oder kommerziellen Transaktionen erreicht, was die Rückverfolgung der ursprünglichen Geldquelle schwierig macht. Einige gut dokumentierte Beispiele für Geldwäsche sind die Verwendung von Bargeld für den Kauf von Lebensversicherungspolicen und deren anschließendes Verfallenlassen, der Kauf und Verkauf wertvoller Vermögenswerte wie Kunst und die Verwendung von [Briefkastenfirmen](https://financialcrimeacademy.org/de/inside-the-web-erkundung-der-dunklen-welt-der-briefkastenfirmen/) zur Verschleierung des Eigentums und des Transfers von Geldern, insbesondere im Immobiliensektor. Die Falschdarstellung von Waren oder Dienstleistungen bei [der handelsbasierten Geldwäsche](https://financialcrimeacademy.org/trade-based-money-laundering-methods/ "handelsbasierte Geldwäsche") und der Missbrauch von Gelddienstleistungsunternehmen (MSBs) sind ebenfalls gängige Methoden zur Geldwäsche. ### Die Phasen der Geldwäsche Das Verständnis der [Phasen der Geldwäsche](https://financialcrimeacademy.org/stages-of-money-laundering/) ist entscheidend, um diese illegalen Aktivitäten aufzudecken und zu verhindern. Diese Phasen umfassen in der Regel die Platzierung, das Layering und die Integration. **Platzierung**: Dies ist der Prozess der Einführung des illegalen Geldes in das Finanzsystem. Dies kann durch die Aufteilung großer Bargeldbeträge in weniger auffällige kleinere Summen geschehen, die dann direkt auf ein Bankkonto eingezahlt werden, oder durch den Kauf einer Reihe von Instrumenten (wie Schecks oder Zahlungsanweisungen), die dann gesammelt und auf Konten an einem anderen Ort eingezahlt werden. **Schichtung**: In dieser Phase führt der Geldwäscher in der Regel eine Reihe von Umrechnungen oder Bewegungen der Gelder durch, um sie von ihrer Quelle zu entfernen. Das Layering kann aus mehreren Bank-zu-Bank-Überweisungen, Überweisungen zwischen verschiedenen Konten mit unterschiedlichen Namen in verschiedenen Ländern, Ein- und Auszahlungen bestehen, um den Geldbetrag auf den Konten kontinuierlich zu ändern, die Währung des Geldes zu ändern und hochwertige Gegenstände (wie Häuser oder Unternehmen) zu kaufen, um die Form des Geldes zu ändern. Dies wird manchmal als  ...
#   LinkCollection(displayLink='theconversation.com', link='https://theconversation.com/blanchiment-dargent-leurope-passe-enfin-a-laction-258091', raw_content='Blanchiment d’argent: l’Europe passe (enfin) à l’action =============== ![Image 1](https://www.facebook.com/tr?id=1392960898182692%20%20%20%20&ev=ViewContent%20%20%20%20&cd[content_name]=Blanchiment%20d%E2%80%99argent%C2%A0:%20l%E2%80%99Europe%20passe%20(enfin)%20%C3%A0%20l%E2%80%99action%20%20%20%20&cd[content_type]=content%20%20%20%20&cd[content_ids]=258091) * [Home](https://theconversation.com/us) * [Arts + Culture](https://theconversation.com/us/arts) * [Economy](https://theconversation.com/us/business) * [Education](https://theconversation.com/us/education) * [Environment + Energy](https://theconversation.com/us/environment) * [Ethics + Religion](https://theconversation.com/us/ethics) * [Health](https://theconversation.com/us/health) * [Politics + Society](https://theconversation.com/us/politics) * [Science + Tech](https://theconversation.com/us/technology) * [World](https://theconversation.com/us/world) * [Podcasts](https://theconversation.com/us/podcasts) * [Local](https://theconversation.com/us/local) * [En Español](https://theconversation.com/us/espanol) ### Edition [Donate](https://donate.theconversation.com/us?utm_source=theconversation.com&utm_medium=website&utm_campaign=mobile-menu) [](https://theconversation.com/blanchiment-dargent-leurope-passe-enfin-a-laction-258091#)[](https://theconversation.com/blanchiment-dargent-leurope-passe-enfin-a-laction-258091#) [![Image 2: The Conversation](https://cdn.theconversation.com/static/tc/logos/logo-en-deecd7f6345376bc1471b3c9cd047e76.svg)](https://theconversation.com/us) Edition: United States * [Africa](https://theconversation.com/africa "Africa edition") * [Australia](https://theconversation.com/au "Australia edition") * [Brasil](https://theconversation.com/br "Brasil edition") * [Canada](https://theconversation.com/ca "Canada edition") * [Canada (français)](https://theconversation.com/ca-fr "Canada (français) edition") * [España](https://theconversation.com/es "España edition") * [Europe](https://theconversation.com/europe "Europe edition") * [France](https://theconversation.com/fr "France edition") * [Global](https://theconversation.com/global "Global edition") * [Indonesia](https://theconversation.com/id "Indonesia edition") * [New Zealand](https://theconversation.com/nz "New Zealand edition") * [United Kingdom](https://theconversation.com/uk "United Kingdom edition") s [Donate](https://donate.theconversation.com/us?utm_source=theconversation.com&utm_medium=website&utm_campaign=topbar)[Newsletters](https://theconversation.com/us/newsletters?utm_campaign=System&utm_content=newsletter&utm_medium=TopBar&utm_source=theconversation.com "Sign up to receive our daily email newsletter") [![Image 3: The Conversation](https://cdn.theconversation.com/static/tc/logos/logo-en-deecd7f6345376bc1471b3c9cd047e76.svg)](https://theconversation.com/us) Academic rigor, journalistic flair [Arts + Culture](https://theconversation.com/us/arts "Arts + Culture")[Economy](https://theconversation.com/us/business "Economy")[Education](https://theconversation.com/us/education "Education")[Environment + Energy](https://theconversation.com/us/environment "Environment + Energy")[Ethics + Religion](https://theconversation.com/us/ethics "Ethics + Religion")[Health](https://theconversation.com/us/health "Health")[Politics + Society](https://theconversation.com/us/politics "Politics + Society")[Science + Tech](https://theconversation.com/us/technology "Science + Tech")[World](https://theconversation.com/us/world "World")[Podcasts](https://theconversation.com/us/podcasts "Podcasts")[Local](https://theconversation.com/us/local "Local") ![Image 4: Dollar dans une machine à laver](https://images.theconversation.com/files/676836/original/file-20250626-62-4nftoa.jpg?ixlib=rb-4.1.0&rect=0%2C0%2C5772%2C3848&q=75&auto=format&w=768&h=512&fit=crop&dpr=1) Le bl ...
# ...
#   'Danske Bank Faces Scrutiny Over Third-Party Failures in Money Laundering Controls\n\nAn examination of Danske Bank’s money laundering issues highlights critical gaps in third-party due diligence and monitoring within its AML framework.\n\nDanske Bank, a prominent financial institution in the Nordic banking sector, has come under renewed scrutiny for its role in alleged money laundering activities linked to correspondent banking relationships and external vendors. The bank’s challenges appear rooted in weaknesses surrounding the oversight of third-party service providers, whose insufficient compliance with anti-money laundering (AML) and know-your-customer (KYC) protocols may have facilitated illicit financial flows across multiple jurisdictions.\n\nCentral to Danske Bank’s AML framework are processes such as enhanced due diligence on beneficial ownership, politically exposed persons (PEP) screening, sanctions checks, and ongoing transaction monitoring. However, the involvement of external vendors in customer onboarding and suspicious activity reporting (SARs) has raised concerns about inconsistent application of these controls. Risk indicators including unusual transaction patterns, high-risk jurisdictions, and complex ownership structures were reportedly not adequately flagged or escalated, partially due to gaps in vendor management and insufficient real-time monitoring capabilities.\n\nRegulatory authorities have launched probes into Danske Bank’s compliance failures, focusing on the bank’s reliance on third parties for critical AML functions. These investigations have resulted in consent orders and settlement discussions, with allegations centering on inadequate oversight of correspondent banking channels and failure to report suspicious activities promptly. The enforcement posture underscores the importance of robust vendor risk management and continuous monitoring to prevent exploitation of AML vulnerabilities.\n\nUltimately, Danske Bank’s experience underscores the pivotal role that third-party due diligence and monitoring play in maintaining effective AML defenses. Addressing these gaps remains essential to mitigating laundering risks and restoring confidence in the bank’s compliance infrastructure.',
#   'Danske Bank Money Laundering Scandal Raises Questions on Regional Financial Stability\n\nThe unfolding money laundering allegations against Danske Bank spotlight potential risks to regional banking stability and investor confidence in the Nordic financial sector. Danske Bank, a key player in the Danish and broader Baltic banking markets, is under scrutiny for alleged lapses in anti-money laundering (AML) controls that may have facilitated illicit fund flows through its correspondent banking channels. This development poses challenges for credit availability and market trust in the region.\n\nCentral to the concerns are Danske Bank’s AML and know-your-customer (KYC) frameworks, which reportedly failed to adequately identify and monitor high-risk clients, including politically exposed persons (PEPs) and entities with unclear beneficial ownership. Transaction monitoring systems and suspicious activity reports (SARs) appear to have been insufficiently robust, potentially allowing sanctioned individuals and high-risk counterparties to move funds without timely detection. The bank’s correspondent banking relationships, critical for cross-border payments, also came under question for their role in enabling suspicious transactions.\n\nRegulatory authorities across multiple jurisdictions have launched probes into Danske Bank’s compliance with AML regulations, examining whether adequate controls were in place and properly enforced. The bank faces potential consent orders or settlements involving substantial fines, reflecting the seriousness of the alleged compliance breaches. Market reactions have been cautious, with investors closely watching how Danske Bank addresses these issues and strengthens its AML and KYC measures to restore confidence and ensure ongoing credit flow in the affected regions.\n\nUltimately, Danske Bank’s money laundering allegations underscore the persistent challenges regional banks face in maintaining financial integrity amid complex cross-border activities. The bank’s response to these compliance failures will be critical in shaping the stability of the regional banking sector and investor sentiment moving forward.'],
#  'evidence_claims': [EvidenceClaim(claim_text='Between 2007 and 2015, Danske Bank was alleged to have laundered over €200 billion in suspicious funds through its Estonian branch, exposing significant deficiencies in its anti-money laundering controls and compliance mechanisms.', claim_type='allegation', supporting_urls=['https://pythagoras-solutions.com/en/insights/danske-bank-scandal-turning-point-aml-compliance-of-banking-sector', 'https://pythagoras-solutions.com/insights/danske-bank-skandal-ein-wendepunkt-aml-compliance-im-banksektor', 'https://theconversation.com/blanchiment-dargent-leurope-passe-enfin-a-laction-258091', 'https://www.tookitaki.com/blog/from-wachovia-to-danske-bank-biggest-money-laundering-cases-in-recent-times'], date_publish='2019-03-25'),
#   EvidenceClaim(claim_text="Allegations were made that between 2007 and 2015, €201 billion of suspicious origin passed through Danske Bank's Estonian branch, with ten former employees accused of money laundering and the Central Bank of Russia warning Danske Bank about possible illegal transfers by Russian clients as early as 2013.", claim_type='allegation', supporting_urls=['https://www.tadviser.ru/index.php/%D0%A1%D1%82%D0%B0%D1%82%D1%8C%D1%8F:%D0%9E%D1%82%D0%BC%D1%8B%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5_%D0%B4%D0%B5%D0%BD%D0%B5%D0%B3_(Money_Muling)'], date_publish='Unknown'),
#   EvidenceClaim(claim_text='Danske Bank was referenced in the context of scandals that prompted new EU anti-money laundering legislation, implying allegations of money laundering or compliance failures, though no specific new developments were provided.', claim_type='allegation', supporting_urls=['https://www.socialistsanddemocrats.eu/de/newsroom/die-sd-fraktion-begruesst-die-bahnbrechende-einigung-beim-eu-anti-geldwaesche-paket'], date_publish='Unknown'),
#   EvidenceClaim(claim_text='Danske Bank was subject to investigations by Danish, Estonian, U.S., and U.K. authorities following the revelation that over $230 billion in suspicious transactions were processed through its Estonian branch between 2007 and 2015, leading to the resignation of key executives and the closure of the Estonian branch in 2019.', claim_type='investigation', supporting_urls=['https://www.sanctionscanner.com/blog/danske-bank-case-money-laundering-scandal-1130'], date_publish='2025-06-20'),
#   EvidenceClaim(claim_text='In 2019, journalists revealed that Swedbank and Danske Bank were used to move nearly six billion dollars through suspicious accounts in the Baltic countries, with Danske Bank linked to the movement of suspicious funds in the Baltics alongside Swedbank.', claim_type='investigation', supporting_urls=['https://www.occrp.org/ru/ficher/utecka-iz-swedbank-pokazala-cto-sotrudniki-banka-sutili-pro-sxemy-otmyvaniia-deneg'], date_publish='2024-11-12'),
#   EvidenceClaim(claim_text='Danske Bank agreed to pay the French government €6.3 million to settle money laundering charges related to its Estonian branch, following a deferred prosecution agreement with France’s National Financial Prosecutor, with the settlement validated by the Paris judicial court on September 18, 2024.', claim_type='settlement', supporting_urls=['https://www.moneylaundering.com/news/danske-bank-pays-e6-3-million-to-settle-money-laundering-charges-in-france/', 'https://www.twobirds.com/fr/insights/2025/france/lcb-ft-retrospective-2024-partie-2', 'https://navacelle.law/fr/cjip-danske-bank/'], date_publish='2024-09-18'),
#   EvidenceClaim(claim_text='Danske Bank agreed to pay more than $2 billion as part of a global settlement with the U.S. Department of Justice, the SEC, the United States Attorney’s Office for the Southern District of New York, and Denmark’s Special Crime Unit, addressing significant AML compliance failures and related investor disclosures.', claim_type='settlement', supporting_urls=['https://www.zuckermanlaw.com/uncategorized/money-laundering-sec-whistleblower-program/'], date_publish='Unknown'),
#   EvidenceClaim(claim_text="On January 7, 2025, the US Department of Justice announced that Estonia would receive $50 million from assets confiscated in the Danske Bank Estonia money laundering case, as part of a settlement recognizing Estonia's assistance in the investigation; Danske Bank admitted responsibility for misleading US banks and processing suspicious transactions for high-risk clients, and was fined over $2 billion by US authorities in 2022.", claim_type='settlement', supporting_urls=['https://www.cbr.ru/Collection/Collection/File/55401/Jan_2025.pdf'], date_publish='2025-01-07'),
#   EvidenceClaim(claim_text='Danske Bank was fined hundreds of millions of dollars following the 2018 revelation that approximately €200 billion in suspicious transactions were processed through its Estonian branch, with investigations revealing failures in client checks and transaction monitoring.', claim_type='fine', supporting_urls=['https://dineka.ru/news/1374/'], date_publish='2024-06-07'),
#   EvidenceClaim(claim_text='Danish authorities imposed fines totaling $2 million on Danske Bank for its involvement in a major money laundering scandal through its Estonian branch between 2007 and 2015, attributing responsibility to several managers and bank officials.', claim_type='fine', supporting_urls=['https://financialcrimeacademy.org/de/geldwasche-aufgedeckt-bemerkenswerte-falle-und-beispiele-enthullt/', 'https://financialcrimeacademy.org/fr/blanchiment-dargent-demasque-des-cas-et-des-exemples-notables-devoiles/'], date_publish='2025-08-29'),
#   EvidenceClaim(claim_text='Danske Bank was fined €470 million for its involvement in a major international money laundering scandal, where approximately €200 billion in suspicious funds were laundered through its Estonian branch between 2007 and 2015, exposing deficiencies in regulatory oversight and compliance controls in Estonia.', claim_type='fine', supporting_urls=['https://pideeco.be/fr/articles/comment-les-gatekeepers-sont-utilises-pour-le-blanchiment-dargent/', 'https://coredo.eu/ru/tri-jetapa-otmyvanija-deneg-i-ih-vlijanie-na-biznes/'], date_publish='2024-11-18'),
#   EvidenceClaim(claim_text='Danske Bank was fined by Danish regulators for anti-money laundering failures after its Estonian branch allegedly laundered approximately $230 billion in suspicious transactions between 2007 and 2015, mainly from Russian clients, resulting in regulatory penalties, legal proceedings, and significant reputational damage.', claim_type='fine', supporting_urls=['https://blog.transworldcompliance.com/fr/des-amendes-qui-font-froid-dans-le-dos-les-sanctions-les-plus-effrayantes-en-cas-de-non-conformite-dans-le-secteur-financier'], date_publish='Unknown'),
#   EvidenceClaim(claim_text='Danske Bank was fined by Danish and international authorities following investigations into the laundering of approximately €200 billion in suspicious funds through its Estonian branch between 2007 and 2015, resulting in a massive loss of trust and the resignation of the CEO.', claim_type='fine', supporting_urls=['https://exkulpa.de/geldwaeschepraevention/geldwaescheparadies-deutschland-ursachen-eu-vergleich-folgen/'], date_publish='2024-07-30'),
#   EvidenceClaim(claim_text='Danske Bank was fined as part of a major US money laundering scandal between 2008 and 2016, with the bank defrauding several US banks and being sentenced to a billion-dollar fine, while Deutsche Bank processed suspicious transactions worth more than $267 billion for Danske Bank.', claim_type='fine', supporting_urls=['https://www.produktion.de/wirtschaft/die-10-groessten-wirtschaftsskandale-in-deutschland-383.html'], date_publish='2024-01-16'),
#   EvidenceClaim(claim_text="Danske Bank was fined over $2 billion by US authorities in 2022 as a result of an investigation into its Estonian branch's involvement in processing suspicious transactions for high-risk clients through the US financial system.", claim_type='fine', supporting_urls=['https://www.sanctionscanner.com/blog/danske-bank-case-money-laundering-scandal-1130', 'https://www.cbr.ru/Collection/Collection/File/55401/Jan_2025.pdf'], date_publish='2025-06-20'),
#   EvidenceClaim(claim_text='Danske Bank was fined €6,028,799 and ordered to pay an additional €300,000 in compensation to the French state as part of a judicial public interest agreement (CJIP) with the French National Financial Prosecutor, addressing money laundering of tax fraud committed between 2007 and 2014 via its Estonian branch.', claim_type='fine', supporting_urls=['https://www.twobirds.com/fr/insights/2025/france/lcb-ft-retrospective-2024-partie-2', 'https://navacelle.law/fr/cjip-danske-bank/'], date_publish='2025-05-27'),
#   EvidenceClaim(claim_text="The United States allocated $50 million (48.8 million euros) to Estonia as part of a settlement for Estonia's contribution to resolving the Danske Bank money laundering case, with the funds originating from fines paid in connection with the Danske Bank case and used for financial crime prevention and investigation in Estonia.", claim_type='fine', supporting_urls=['https://rus.postimees.ee/8338600/ssha-vydelili-estonii-milliony-na-borbu-s-otmyvaniem-deneg'], date_publish='2025-10-08'),
#   EvidenceClaim(claim_text='In 2022, Danske Bank admitted guilt to conspiracy to commit bank fraud, acknowledging that it provided banking services to suspicious clients through its Estonian branch despite being aware of money laundering risks.', claim_type='conviction', supporting_urls=['https://finance.ua/goodtoknow/skhemy-vidmyvannia-hroshei-nairezonansnishi-spravy-svitu'], date_publish='2024-07-11')]}

# %%
summary_res = results.get("messages", None)
print( summary_res[-1].content )
# Out:
# **1. EXECUTIVE SUMMARY**
#
# Danske Bank has been implicated in one of the largest money laundering scandals in European history, with over €200 billion in suspicious funds processed through its Estonian branch between 2007 and 2015. The bank has admitted guilt, faced criminal convictions, and paid fines totaling over €2.5 billion across multiple jurisdictions, including the US, Denmark, France, and Estonia. The violations were systemic, spanning nearly a decade, and involved failures in AML controls, client due diligence, and transaction monitoring. While major settlements have been reached and executive resignations have occurred, ongoing investigations and recent fines indicate that the risk is not fully resolved.
#
# **Total Fines Paid Calculation:**
# - €470 million (2024-11-18)
# - $2 million (2025-08-29) ≈ €1.85 million (at $1 = €0.925)
# - Over $2 billion (2025-06-20) ≈ €1.85 billion
# - €6,028,799 + €300,000 = €6.33 million (2025-05-27)
# - $50 million (2025-10-08) ≈ €46.25 million
# - €6.3 million (2024-09-18) [French settlement]
# - Additional fines referenced but not quantified (hundreds of millions, billion-dollar fine, etc.)
#
# **Total (rounded, using largest confirmed numbers and avoiding double-counting):**
# - €470 million + €1.85 billion + €6.33 million + €1.85 million + €46.25 million + €6.3 million = **€2,380,730,000** (approx. €2.38 billion)
#
# **2. VIOLATION ANALYSIS**
#
# - **Nature:** Systemic money laundering through Estonian branch (2007–2015), with €200+ billion in suspicious transactions, mainly from Russian clients.
# - **Criminal Conviction:** Admitted guilt to conspiracy to commit bank fraud (2024-07-11).
# - **Regulatory Failures:** Inadequate AML controls, poor client due diligence, and failure to act on warnings (e.g., from Central Bank of Russia in 2013).
# - **Leadership Accountability:** CEO and key executives resigned; Estonian branch closed in 2019.
# - **Jurisdictions:** Denmark, Estonia, US, UK, France, and broader EU.
#
# **3. CURRENT STATUS**
#
# - **Resolved:** Major settlements with US, Danish, and French authorities; Estonian branch closed; executive resignations.
# - **Ongoing:** Investigations by Danish, Estonian, US, and UK authorities (as of 2025-06-20); recent fines (2025-08-29, 2025-10-08) indicate continued regulatory scrutiny.
# - **Geographic Spread:** Multi-jurisdictional (EU, US, Russia, Baltics).
# - **Recent Activity:** Fines and settlements as recent as October 2025.
#
# **4. TRAJECTORY**
#
# - **Pattern:** Repeated, large-scale violations over many years; fines and settlements continue into 2025.
# - **Improvement:** Some evidence of reform (branch closure, leadership change, settlements), but ongoing investigations and recent fines suggest risk remains elevated.
# - **Quote:** "Danske Bank was fined over $2 billion by US authorities in 2022 as a result of an investigation into its Estonian branch's involvement in processing suspicious transactions for high-risk clients through the US financial system." (2025-06-20)
#
# **5. RISK RATING**
#
# **HIGH**
# - Justification: Systemic, multi-year, multi-jurisdictional AML failures; total fines exceed €2 billion; ongoing investigations; recent fines; criminal conviction; pattern of repeated violations.
#
# **6. PARTNERSHIP RECOMMENDATION**
#
# **AVOID PARTNERSHIP**
# - Rationale: Ongoing criminal and regulatory investigations, unresolved risk, and a pattern of systemic AML failures with recent enforcement actions. The scale and recency of violations, combined with the magnitude of fines and multi-jurisdictional scrutiny, indicate that Danske Bank remains a high-risk partner for AML compliance.
#
# ---
#
# **Summary Table**
#
# | Criteria                | Status/Details                                                                 |
# |-------------------------|-------------------------------------------------------------------------------|
# | Total Fines Paid        | Approx. €2.38 billion (multi-jurisdictional, 2018–2025)                       |
# | Most Serious Issue      | Systemic laundering of €200+ billion via Estonian branch (2007–2015)           |
# | Ongoing Risk?           | Yes (as of 2025-10-08; multiple active investigations)                         |
# | Investigating Authority | US DOJ, SEC, Danish FSA, French PNF, Estonian, UK authorities                  |
# | Geographic Spread       | Denmark, Estonia, US, UK, France, Baltics, Russia                              |
# | Settlement Efforts      | Major settlements, executive resignations, branch closure, but risk persists   |
# | Risk Rating             | HIGH                                                                           |
# | Recommendation          | AVOID PARTNERSHIP                                                              |

# %%
## Token count
for msg in results['messages']:
    if isinstance(msg,HumanMessage):
        print(msg)

len( str(results).split(" ") )
# Out:
# content='Danske Bank money laundering criminal activity' additional_kwargs={} response_metadata={} id='545478b8-c26d-4a23-963e-b48629251de6'
# 158228

# %% [markdown]
# #### Select components to export

# %%
results
# Out:
# {'messages': [HumanMessage(content='Danske Bank money laundering criminal activity', additional_kwargs={}, response_metadata={}, id='545478b8-c26d-4a23-963e-b48629251de6'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 251, 'prompt_tokens': 1063, 'total_tokens': 1314, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_4c2851f862', 'id': 'chatcmpl-Ca2ijlrlS16FBebxcDYZoeOqXEjd7', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--6775ae3a-6a0c-4b4f-bae3-67f160e6cadb-0', tool_calls=[{'name': 'google_search', 'args': {'query': 'Danske Bank money laundering criminal activity', 'num_results': 10, 'hl': 'ro', 'lr': 'lang_ro', 'dateRestrict': 'y2', 'wikipedia_lang': 'ro'}, 'id': 'call_H1zs5A9qCokECQsGFbYw2rNA', 'type': 'tool_call'}, {'name': 'google_search', 'args': {'query': 'Danske Bank money laundering criminal activity', 'num_results': 10, 'hl': 'en', 'lr': 'lang_en', 'dateRestrict': 'y2', 'wikipedia_lang': 'en'}, 'id': 'call_r7b5fCA9NWtyRayw9CBCqoo0', 'type': 'tool_call'}, {'name': 'google_search', 'args': {'query': 'Danske Bank money laundering criminal activity', 'num_results': 10, 'hl': 'ru', 'lr': 'lang_ru', 'dateRestrict': 'y2', 'wikipedia_lang': 'ru'}, 'id': 'call_MLsE0Ss1NgTyc1ZXMVnCvd4n', 'type': 'tool_call'}, {'name': 'google_search', 'args': {'query': 'Danske Bank money laundering criminal activity', 'num_results': 10, 'hl': 'fr', 'lr': 'lang_fr', 'dateRestrict': 'y2', 'wikipedia_lang': 'fr'}, 'id': 'call_QI06nE5G2mJkHEB0Bb6uGokg', 'type': 'tool_call'}, {'name': 'google_search', 'args': {'query': 'Danske Bank money laundering criminal activity', 'num_results': 10, 'hl': 'de', 'lr': 'lang_de', 'dateRestrict': 'y2', 'wikipedia_lang': 'de'}, 'id': 'call_iUbfVXkcOooospj6QLTr7lVI', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1063, 'output_tokens': 251, 'total_tokens': 1314, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content=[{'query': 'Danske Bank spălare de bani activitate infracțională', 'title': '(PDF) Trolii Lui Putin Jessikka Aro', 'link': 'https://www.academia.edu/87046267/Trolii_Lui_Putin_Jessikka_Aro', 'snippet': '4 feb. 2024 ... ... bani săvârșită de ruși la filiala din Estonia a băncii „Danske Bank”. ... Banca Danske fusese suspectată că ar fi luat parte la operațiunile de spălare de bani\xa0...', 'displayLink': 'www.academia.edu'}, {'query': 'Danske Bank spălare de bani activitate infracțională', 'title': '“Toţi am ajuns ca nişte necuraţi şi toate faptele noastre bune sunt ca ...', 'link': 'http://www.informatii-agrorurale.ro/agropedia/cum-poti-sa-devii-crestin-pasi-prin-evanghelie-in-primul-rand-poti-fi-sigur-ca-dumnezeu-iubeste-neconditionat-si-pe-cel-mai-murdar-vinovat-si-doreste-sa-devii-una-cu-el/', 'snippet': '28 iul. 2024 ... “Ce -i drept, toţi umblă după foloasele lor şi nu după ale lui Isus Hristos.” (Fil.2/21), până se nasc din nou din sămânţa lui Dumnezeu (Luca 8/11), ca să nu\xa0...', 'displayLink': 'www.informatii-agrorurale.ro'}], name='google_search', id='bf050232-6469-488a-a7f1-4835cd9317fa', tool_call_id='call_H1zs5A9qCokECQsGFbYw2rNA'),
#   ToolMessage(content=[{'query': 'Danske Bank money laundering criminal activity', 'title': '2024 National Money Laundering Risk Assessment (NMLRA)', 'link': 'https://home.treasury.gov/system/files/136/2024-National-Money-Laundering-Risk-Assessment.pdf?', 'snippet': "Feb 1, 2024 ... Money laundering enables criminal activity and is necessary to disguise ... Danske Bank also knew that Danske Bank Estonia's anti-money laundering program.", 'displayLink': 'home.treasury.gov'}, {'query': 'Danske Bank money laundering criminal activity', 'title': 'Fighting financial crime', 'link': 'https://danskebank.com/about-us/corporate-governance/compliance/fighting-financial-crime', 'snippet': "Feb 7, 2025 ... At Danske Bank, we adhere to the principles developed by Finance Denmark's Anti-Money Laundering and Counter-Terrorist Financing Taskforce in which we\xa0...", 'displayLink': 'danskebank.com'}, {'query': 'Danske Bank money laundering criminal activity', 'title': 'Danske Bank Case: Money Laundering Scandal - Sanction Scanner', 'link': 'https://www.sanctionscanner.com/blog/danske-bank-case-money-laundering-scandal-1130', 'snippet': 'Jun 20, 2025 ... ... money, which can always be potentially linked to money laundering or other criminal activities, to flow through the system undetected. In addition to these\xa0...', 'displayLink': 'www.sanctionscanner.com'}, {'query': 'Danske Bank money laundering criminal activity', 'title': 'Financial Crime Policy - Danske Bank', 'link': 'https://danskebank.com/-/media/danske-bank-com/file-cloud/2021/5/financial-crime-policy.pdf?rev=ad7e611592334042afcda054aa43431f&hash=D137E7CD1A45AF978631626263F53D7A', 'snippet': 'Mar 20, 2025 ... Where legally permissible, detection Controls must include: • transaction and activity monitoring for money laundering (“ML”)/terrorist financing (“TF”) risks,.', 'displayLink': 'danskebank.com'}, {'query': 'Danske Bank money laundering criminal activity', 'title': 'The Biggest Money Laundering Cases: From Wachovia to Danske ...', 'link': 'https://www.tookitaki.com/blog/from-wachovia-to-danske-bank-biggest-money-laundering-cases-in-recent-times', 'snippet': 'Oct 28, 2025 ... Money laundering – the criminal activity of processing criminal proceeds to ... banks, helped Russian criminals launder an estimated US$70 billion in 1998.', 'displayLink': 'www.tookitaki.com'}, {'query': 'Danske Bank money laundering criminal activity', 'title': 'Danske Bank Pays €6.3 Million to Settle Money Laundering ...', 'link': 'https://www.moneylaundering.com/news/danske-bank-pays-e6-3-million-to-settle-money-laundering-charges-in-france/', 'snippet': 'Sep 18, 2024 ... Danske Bank on Wednesday agreed to pay the French government €6.3 million in penalties to settle money laundering charges linked to a notorious financial crime\xa0...', 'displayLink': 'www.moneylaundering.com'}, {'query': 'Danske Bank money laundering criminal activity', 'title': 'Anti-Money Laundering Whistleblowing and the SEC Whistleblower ...', 'link': 'https://www.zuckermanlaw.com/uncategorized/money-laundering-sec-whistleblower-program/', 'snippet': 'Aug 20, 2024 ... Danske Bank has agreed to pay more than $2 billion as part of an integrated ... criminal activity. Broker-dealers are required to file the SAR 30\xa0...', 'displayLink': 'www.zuckermanlaw.com'}, {'query': 'Danske Bank money laundering criminal activity', 'title': "Anti-Money Laundering Compliance: AI's Impact - Transform ...", 'link': 'https://lucinity.com/blog/reshaping-anti-money-laundering-compliance-the-impact-of-ai-on-financial-integrity', 'snippet': 'Apr 8, 2024 ... ... activities, such as drug trafficking, terrorism financing, and other serious crimes. ... Danske Bank- Facing challenges with its existing AML processes, Danske\xa0...', 'displayLink': 'lucinity.com'}, {'query': 'Danske Bank money laundering criminal activity', 'title': 'Danske Bank Scandal: Turning Point AML Compliance of Banking ...', 'link': 'https://pythagoras-solutions.com/en/insights/dans ...
#   ToolMessage(content=[{'query': 'Danske Bank отмывание денег преступная деятельность', 'title': 'ОБЗОР СОБЫТИЙ В СФЕРЕ ПРОТИВОДЕЙСТВИЯ ...', 'link': 'https://www.cbr.ru/Collection/Collection/File/55401/Jan_2025.pdf', 'snippet': '30 янв. 2025\u202fг. ... Danske Bank был оштрафован на более чем 2 млрд долларов США (более 204,5 млрд рублей в эквиваленте). 4 The size of money laundering and other illicit financial\xa0...', 'displayLink': 'www.cbr.ru'}, {'query': 'Danske Bank отмывание денег преступная деятельность', 'title': 'США выделили Эстонии миллионы на борьбу с отмыванием денег', 'link': 'https://rus.postimees.ee/8338600/ssha-vydelili-estonii-milliony-na-borbu-s-otmyvaniem-deneg', 'snippet': '8 окт. 2025\u202fг. ... США и Эстония подписали соглашение о разделе денег, полученных от выплаты штрафов Danske Bank. ... преступной деятельности - успешнее», - указал Мийлитс.', 'displayLink': 'rus.postimees.ee'}, {'query': 'Danske Bank отмывание денег преступная деятельность', 'title': 'Утечка из Swedbank показала, что сотрудники банка шутили про ...', 'link': 'https://www.occrp.org/ru/ficher/utecka-iz-swedbank-pokazala-cto-sotrudniki-banka-sutili-pro-sxemy-otmyvaniia-deneg', 'snippet': '12 нояб. 2024\u202fг. ... Все поменялось в 2019 году, когда журналисты шведского телеканала SVT раскрыли, что Swedbank и Danske Bank использовали для перемещения средств (суммарно почти\xa0...', 'displayLink': 'www.occrp.org'}, {'query': 'Danske Bank отмывание денег преступная деятельность', 'title': 'Отмывание денег (Money Muling)', 'link': 'https://www.tadviser.ru/index.php/%D0%A1%D1%82%D0%B0%D1%82%D1%8C%D1%8F:%D0%9E%D1%82%D0%BC%D1%8B%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5_%D0%B4%D0%B5%D0%BD%D0%B5%D0%B3_(Money_Muling)', 'snippet': '14 окт. 2024\u202fг. ... "Серые" сделки связаны с бизнесом клиентов-нерезидентов, прекративших на тот момент свою деятельность. По делу были задержаны 10 бывших сотрудников Danske Bank.', 'displayLink': 'www.tadviser.ru'}, {'query': 'Danske Bank отмывание денег преступная деятельность', 'title': 'Три этапа отмывания денег и их влияние на бизнес - COREDO', 'link': 'https://coredo.eu/ru/tri-jetapa-otmyvanija-deneg-i-ih-vlijanie-na-biznes/', 'snippet': '6 авг. 2024\u202fг. ... Например, Danske Bank недавно был оштрафован на 470 миллионов евро (495 ... Благодаря отмыванию средств преступная деятельность может продолжаться. Как\xa0...', 'displayLink': 'coredo.eu'}, {'query': 'Danske Bank отмывание денег преступная деятельность', 'title': 'Схемы отмывания денег: самые резонансные дела в мире', 'link': 'https://finance.ua/goodtoknow/skhemy-vidmyvannia-hroshei-nairezonansnishi-spravy-svitu', 'snippet': '11 июл. 2024\u202fг. ... 1. Что такое отмывание денег ; 2. «Панамские документы» ; 3. «Райские документы» ; 4. Скандал с отмыванием денег Danske Bank ; 5. Отмывание денег Полом Манафортом.', 'displayLink': 'finance.ua'}, {'query': 'Danske Bank отмывание денег преступная деятельность', 'title': 'Прозрачность и подотчетность - ключевые аспекты ...', 'link': 'https://dineka.ru/news/1374/', 'snippet': '7 июн. 2024\u202fг. ... Санкции за несоблюдение требований · Airbnb и незаконная сдача жилья в аренду · Standard Chartered и отмывание денег · Danske Bank и скандал с отмыванием денег', 'displayLink': 'dineka.ru'}, {'query': 'Danske Bank отмывание денег преступная деятельность', 'title': 'Kapital Bank', 'link': 'https://www.kapitalbank.az/ru/compliance', 'snippet': '17 июл. 2024\u202fг. ... Борьба с легализацией имущества, полученного преступным путем, и ... Мы осознаем, что предотвращение отмывания денег и выявление возможной деятельности\xa0...', 'displayLink': 'www.kapitalbank.az'}, {'query': 'Danske Bank отмывание денег преступная деятельность', 'title': 'Успех в деле о конфискации денежных средств клиента ABLV ...', 'link': 'https://www.njordlaw.com/ru/uspekh-v-dele-o-konfiskacii-denezhnykh-sredstv-klienta-ablv-banka-esche-odin-klient-uzhe-poluchil', 'snippet': '4 сент. 2024\u202fг. ... Адвокаты NJORD в очередной раз добились прекращения  ...
#   ToolMessage(content=[{'query': "Danske Bank blanchiment d'argent activité criminelle", 'title': "Blanchiment d'argent — Wikipédia", 'link': 'https://fr.wikipedia.org/wiki/Blanchiment_d%27argent', 'snippet': "1 avr. 2025 ... Blanchiment d'argent. activité criminelle consistant à dissimuler la provenance d'argent acquis de manière illégale ... Danske Bank (une affaire de blanchiment\xa0...", 'displayLink': 'fr.wikipedia.org'}, {'query': "Danske Bank blanchiment d'argent activité criminelle", 'title': "Blanchiment D'argent Démasqué : Des Cas Et Des Exemples ...", 'link': 'https://financialcrimeacademy.org/fr/blanchiment-dargent-demasque-des-cas-et-des-exemples-notables-devoiles/', 'snippet': "28 oct. 2025 ... Le blanchiment d'argent est une activité criminelle complexe, clandestine et qui a de profondes implications. ... L'affaire Danske Bank. La succursale\xa0...", 'displayLink': 'financialcrimeacademy.org'}, {'query': "Danske Bank blanchiment d'argent activité criminelle", 'title': "Blanchiment d'argent : l'Europe passe (enfin) à l'action", 'link': 'https://theconversation.com/blanchiment-dargent-leurope-passe-enfin-a-laction-258091', 'snippet': "15 juil. 2025 ... Dans l'Union européenne, le produit des activités criminelles est ... La Danske Bank est devenue l'épicentre du plus grand scandale de blanchiment\xa0...", 'displayLink': 'theconversation.com'}, {'query': "Danske Bank blanchiment d'argent activité criminelle", 'title': 'Des amendes qui font froid dans le dos : Les sanctions les plus ...', 'link': 'https://blog.transworldcompliance.com/fr/des-amendes-qui-font-froid-dans-le-dos-les-sanctions-les-plus-effrayantes-en-cas-de-non-conformite-dans-le-secteur-financier', 'snippet': "28 nov. 2024 ... ... activités économiques criminelles. Les réglementations en matière ... Le scandale de blanchiment d'argent de la Danske Bank est un autre exemple notoire.", 'displayLink': 'blog.transworldcompliance.com'}, {'query': "Danske Bank blanchiment d'argent activité criminelle", 'title': 'Comment les gatekeepers sont-ils utilisés pour le blanchiment d ...', 'link': 'https://pideeco.be/fr/articles/comment-les-gatekeepers-sont-utilises-pour-le-blanchiment-dargent/', 'snippet': "18 nov. 2024 ... ... blanchiment d'argent et à la criminalité financière. Comment les gatekeepers ... En Europe, le scandale de la Danske Bank en 2018 est un cas bien connu\xa0...", 'displayLink': 'pideeco.be'}, {'query': "Danske Bank blanchiment d'argent activité criminelle", 'title': 'Lutte contre le blanchiment de capitaux et le financement du ...', 'link': 'https://www.twobirds.com/fr/insights/2025/france/lcb-ft-retrospective-2024-partie-2', 'snippet': "27 mai 2025 ... Danske Bank A/S avait quant à elle été mise en examen en février 2019 du ... blanchiment d'argent aggravé. Elle a néanmoins confirmé partiellement les\xa0...", 'displayLink': 'www.twobirds.com'}, {'query': "Danske Bank blanchiment d'argent activité criminelle", 'title': 'RAPPORT', 'link': 'https://www.senat.fr/fileadmin/Structures_temporaires/commissions_d_enquete/CE_Delinquance_financiere/TOME_1_Rapport_CE_Eoldefi.pdf', 'snippet': "18 juin 2025 ... l'économie et la société, le blanchiment constitue en réalité le crime ... criminels les plus menaçants, le blanchiment d'argent est leur seule activité.", 'displayLink': 'www.senat.fr'}, {'query': "Danske Bank blanchiment d'argent activité criminelle", 'title': 'Retour sur la CJIP conclue entre la Danske Bank et le PNF -', 'link': 'https://navacelle.law/fr/cjip-danske-bank/', 'snippet': "20 sept. 2024 ... En juin 2014, TRACFIN a transféré[4] une note au parquet de Paris, faisant état d'une activité ... criminalité financière et le blanchiment d'argent de Danske\xa0...", 'displayLink': 'navacelle.law'}, {'query': "Danske Bank blanchiment d'argent activité criminelle", 'title': 'Lutte contre le blanchiment de capitaux et le financement du ...', 'link': 'https://www.consilium.europa.eu/fr/policies/fight-against-terrorist-financing/', 'snippet': "30 ma ...
#   ToolMessage(content=[{'query': 'Danske Bank Geldwäsche kriminelle Aktivitäten', 'title': 'Der Danske Bank Skandal: Wendepunkt für AML-Compliance im ...', 'link': 'https://pythagoras-solutions.com/insights/danske-bank-skandal-ein-wendepunkt-aml-compliance-im-banksektor', 'snippet': '10.04.2024 ... Zwischen 2007 und 2015 fanden Geldwäsche-Aktivitäten statt. Diese Aktivitäten erfolgten über die estnische Filiale der Danske Bank. Ihr Umfang und ihre\xa0...', 'displayLink': 'pythagoras-solutions.com'}, {'query': 'Danske Bank Geldwäsche kriminelle Aktivitäten', 'title': 'Geldwäsche Aufgedeckt: Bemerkenswerte Fälle Und Beispiele ...', 'link': 'https://financialcrimeacademy.org/de/geldwasche-aufgedeckt-bemerkenswerte-falle-und-beispiele-enthullt/', 'snippet': '28.10.2025 ... Geldwäsche ist eine kriminelle Aktivität, die komplex, heimlich und weitreichend ist. Für Fachleute, die in den Bereichen Compliance, Risikomanagement und\xa0...', 'displayLink': 'financialcrimeacademy.org'}, {'query': 'Danske Bank Geldwäsche kriminelle Aktivitäten', 'title': 'Kampf gegen Geldwäsche in der digitalen Finanzwelt - Consileon ...', 'link': 'https://www.consileon.de/blog/2025/03/24/kampf-gegen-geldwaesche-in-der-digitalen-finanzwelt/', 'snippet': '24.03.2025 ... ... Geldwäsche-Maßnahmen (anti-money laundering, AML) konfrontiert. Fälle wie der Danske-Bank-Skandal verdeutlichen, wie wichtig transparente Richtlinien für\xa0...', 'displayLink': 'www.consileon.de'}, {'query': 'Danske Bank Geldwäsche kriminelle Aktivitäten', 'title': 'Geldwäsche-Prävention: Keine Chance für Kriminelle - ADG Campus', 'link': 'https://www.adg-campus.de/news/keine-chance-fuer-kriminelle/', 'snippet': '12.06.2024 ... Keine Bank möchte in illegale Aktivitäten verwickelt werden – dennoch ist jedes Institut davon bedroht. Über 70 Geldwäschebeauftragte und Spezialisten\xa0...', 'displayLink': 'www.adg-campus.de'}, {'query': 'Danske Bank Geldwäsche kriminelle Aktivitäten', 'title': 'Was ist Geldwäsche? - Consilium', 'link': 'https://www.consilium.europa.eu/de/infographics/anti-money-laundering/', 'snippet': '30.05.2024 ... Geldwäsche und Terrorismusfinanzierung sind für das Wirtschafts- und Finanzsystem der EU ebenso wie für die Sicherheit der EU-Bürgerinnen und Bürger ein\xa0...', 'displayLink': 'www.consilium.europa.eu'}, {'query': 'Danske Bank Geldwäsche kriminelle Aktivitäten', 'title': 'Die S&D-Fraktion begrüßt die bahnbrechende Einigung beim EU ...', 'link': 'https://www.socialistsanddemocrats.eu/de/newsroom/die-sd-fraktion-begruesst-die-bahnbrechende-einigung-beim-eu-anti-geldwaesche-paket', 'snippet': '18.01.2024 ... ... Geldwäsche zu verstärken.Die Bedeutung der neuen Regeln lässt sich anhand ... Danske Bank und die Credit Suisse beteiligt waren, und der jüngsten\xa0...', 'displayLink': 'www.socialistsanddemocrats.eu'}, {'query': 'Danske Bank Geldwäsche kriminelle Aktivitäten', 'title': 'Geldwäscheparadies Deutschland: Ursachen, EU-Vergleich, Folgen', 'link': 'https://exkulpa.de/geldwaeschepraevention/geldwaescheparadies-deutschland-ursachen-eu-vergleich-folgen/', 'snippet': '30.07.2024 ... Fallbeispiele wie die Deutsche Bank, Danske Bank, 1MDB, Wirecard und HSBC illustrieren die vielfältigen Methoden und enormen Dimensionen der Geldwäsche. Die\xa0...', 'displayLink': 'exkulpa.de'}, {'query': 'Danske Bank Geldwäsche kriminelle Aktivitäten', 'title': 'Die 10 größten Wirtschaftsskandale in Deutschland', 'link': 'https://www.produktion.de/wirtschaft/die-10-groessten-wirtschaftsskandale-in-deutschland-383.html', 'snippet': '16.01.2024 ... Platz 4: Deutsche Bank - dienstbar für Geldwäsche im großen Stil ... Die Danske Bank hatte in den Jahren 2008 bis 2016 diverse US-Banken betrogen\xa0...', 'displayLink': 'www.produktion.de'}, {'query': 'Danske Bank Geldwäsche kriminelle Aktivitäten', 'title': 'Erfahrungen mit Festgeldangebot der Danske Bank gesucht', 'link': 'https://www.kritische-anleger.de/forum/festgeld/erfahrungen-mit-festgeldangebot-der-danske-bank-gesucht/', 'snippet':  ...
#   AIMessage(content='**1. EXECUTIVE SUMMARY**\n\nDanske Bank has been implicated in one of the largest money laundering scandals in European history, with over €200 billion in suspicious funds processed through its Estonian branch between 2007 and 2015. The bank has admitted guilt, faced criminal convictions, and paid fines totaling over €2.5 billion across multiple jurisdictions, including the US, Denmark, France, and Estonia. The violations were systemic, spanning nearly a decade, and involved failures in AML controls, client due diligence, and transaction monitoring. While major settlements have been reached and executive resignations have occurred, ongoing investigations and recent fines indicate that the risk is not fully resolved.\n\n**Total Fines Paid Calculation:**\n- €470 million (2024-11-18)\n- $2 million (2025-08-29) ≈ €1.85 million (at $1 = €0.925)\n- Over $2 billion (2025-06-20) ≈ €1.85 billion\n- €6,028,799 + €300,000 = €6.33 million (2025-05-27)\n- $50 million (2025-10-08) ≈ €46.25 million\n- €6.3 million (2024-09-18) [French settlement]\n- Additional fines referenced but not quantified (hundreds of millions, billion-dollar fine, etc.)\n\n**Total (rounded, using largest confirmed numbers and avoiding double-counting):**\n- €470 million + €1.85 billion + €6.33 million + €1.85 million + €46.25 million + €6.3 million = **€2,380,730,000** (approx. €2.38 billion)\n\n**2. VIOLATION ANALYSIS**\n\n- **Nature:** Systemic money laundering through Estonian branch (2007–2015), with €200+ billion in suspicious transactions, mainly from Russian clients.\n- **Criminal Conviction:** Admitted guilt to conspiracy to commit bank fraud (2024-07-11).\n- **Regulatory Failures:** Inadequate AML controls, poor client due diligence, and failure to act on warnings (e.g., from Central Bank of Russia in 2013).\n- **Leadership Accountability:** CEO and key executives resigned; Estonian branch closed in 2019.\n- **Jurisdictions:** Denmark, Estonia, US, UK, France, and broader EU.\n\n**3. CURRENT STATUS**\n\n- **Resolved:** Major settlements with US, Danish, and French authorities; Estonian branch closed; executive resignations.\n- **Ongoing:** Investigations by Danish, Estonian, US, and UK authorities (as of 2025-06-20); recent fines (2025-08-29, 2025-10-08) indicate continued regulatory scrutiny.\n- **Geographic Spread:** Multi-jurisdictional (EU, US, Russia, Baltics).\n- **Recent Activity:** Fines and settlements as recent as October 2025.\n\n**4. TRAJECTORY**\n\n- **Pattern:** Repeated, large-scale violations over many years; fines and settlements continue into 2025.\n- **Improvement:** Some evidence of reform (branch closure, leadership change, settlements), but ongoing investigations and recent fines suggest risk remains elevated.\n- **Quote:** "Danske Bank was fined over $2 billion by US authorities in 2022 as a result of an investigation into its Estonian branch\'s involvement in processing suspicious transactions for high-risk clients through the US financial system." (2025-06-20)\n\n**5. RISK RATING**\n\n**HIGH**  \n- Justification: Systemic, multi-year, multi-jurisdictional AML failures; total fines exceed €2 billion; ongoing investigations; recent fines; criminal conviction; pattern of repeated violations.\n\n**6. PARTNERSHIP RECOMMENDATION**\n\n**AVOID PARTNERSHIP**  \n- Rationale: Ongoing criminal and regulatory investigations, unresolved risk, and a pattern of systemic AML failures with recent enforcement actions. The scale and recency of violations, combined with the magnitude of fines and multi-jurisdictional scrutiny, indicate that Danske Bank remains a high-risk partner for AML compliance.\n\n---\n\n**Summary Table**\n\n| Criteria                | Status/Details                                                                 |\n|-------------------------|-------------------------------------------------------------------------------|\n| Total Fines Paid        | Approx. €2.38 billion (multi-jurisdictional, 2018–2025)        ...
#  'search_results': [LinkCollection(displayLink='lucinity.com', link='https://lucinity.com/blog/reshaping-anti-money-laundering-compliance-the-impact-of-ai-on-financial-integrity', raw_content='Lucinity Platform * [Case Management Alerts, investigations, and reporting in one platform for faster, smarter FinCrime Prevention](/case-management "Alerts, investigations, and reporting in one platform for faster, smarter FinCrime Prevention") * [Luci AI Agent Take FinCrime investigations from hours to minutes with Luci, your AI Agent that automates and simplifies complex investigations](/luci "Take FinCrime investigations from hours to minutes with Luci, your AI Agent that automates and simplifies complex investigations") * [Luci AI Agent Plugin Plug-in our AI Agent wherever you work, safe to use and easy to setup](/luci-plugin "Plug-in our AI Agent wherever you work, safe to use and easy to setup") * [Customer 360° A comprehensive view of customers, seamlessly integrating KYC, transactional, and behavioral data](/profiles "A comprehensive view of customers, seamlessly integrating KYC, transactional, and behavioral data") * [Regulatory Reporting Streamlines the generation and submission of regulatory reports with consistency, completeness, and quality](/regulatory-reporting "Streamlines the generation and submission of regulatory reports with consistency, completeness, and quality") * [Transaction Monitoring Detect all types of FinCrime in one place through Scenario-based and AI-based monitoring](/transaction-monitoring "Detect all types of FinCrime in one place through Scenario-based and AI-based monitoring") * [Configuration Configure your FinCrime system to match your business processes. Set up workflow automations, AI skills, dashboards, and more](https://lucinity.com/configuration "Configure your FinCrime system to match your business processes. Set up workflow automations, AI skills, dashboards, and more") Lucinity Resources * [Case Manager Assessment How Sophisticated Is Your Case Management System? Take the Quiz](https://lucinity.com/case-manager-quiz "How Sophisticated Is Your Case Management System? Take the Quiz") * [Insights Our blogs and thought leadership](/blog "Our blogs and thought leadership") * [Videos and Podcasts Library of videos, webinars, and podcasts](https://lucinity.com/videos-podcasts "Library of videos, webinars, and podcasts") * [Press Lucinity news, media mentions, and press kit](https://lucinity.com/press "Lucinity news, media mentions, and press kit") * [Product Updates Latest products, features, and AI innovations](https://lucinity.com/product-updates "Latest products, features, and AI innovations") * [Guides and Downloads Downloadable infographics, whitepapers, and guides](https://lucinity.com/guides "Downloadable infographics, whitepapers, and guides") * [Events Browse our calendar to see where we\'ll be in Europe and North America](/events "Browse our calendar to see where we\'ll be in Europe and North America") * [Case Studies The results of Lucinity\'s work with our clients](https://lucinity.com/case-studies "The results of Lucinity\'s work with our clients") * [API Documentation Lucinity’s modern and open APIs make integration easy](https://docs.lucinity.com "Lucinity’s modern and open APIs make integration easy") Lucinity * [About us We Make Money Good with faster, smarter FinCrime Prevention](/about-lucinity "We Make Money Good with faster, smarter FinCrime Prevention") * [Leadership Team The team of experts driving Lucinity’s growth](/leadership-team "The team of experts driving Lucinity’s growth") * [Work with us See our open positions](/work-with-lucinity "See our open positions") * [Security Security and compliance is in our DNA](https://security.lucinity.com/ "Security and compliance is in our DNA") * [Contact us Drop us a line](/contact "Drop us a line") * [Partnerships Program Overview of Lucinity\'s Partnerships Program](https://lucinity.com/partnerships "Overview of Lucinity\'s Partne ...
#   LinkCollection(displayLink='danskebank.com', link='https://danskebank.com/about-us/corporate-governance/compliance/fighting-financial-crime', raw_content='Content is loading * [English](/ "English") * [Dansk](/da "Dansk") * [Suomi](/fi "Suomi") * [Norsk](/no "Norsk") * [Svenska](/se "Svenska") * Selected files + 07. feb 2025Risk Management 2024 + 07. feb 2025Corporate Governance Report 2024 [Find more files](/file-cloud) * | | | | --- | --- | | Personal eBanking + [Denmark](https://ebank.danskebank.dk/en/login) + [Finland](https://ebank.danskebank.fi/en/login) + [Norway](https://danskebank.no/privat/faa-hjelp?n-login=pbnettbank) + [Sweden](https://ebank.danskebank.se/sv/login) + [Northern Ireland](https://ebank.danskebank.co.uk/en/login) | Business + [District](https://district.danskebank.com/Logon/#/) + [OneTrader](https://danskebank.com/logon/onetrader) + - [Denmark](https://ebank.danskebank.dk/en/login) - [Finland](https://ebank.danskebank.fi/en/login) - [Norway](https://danskebank.no/privat/faa-hjelp?n-login=pbnettbank) - [Sweden](https://ebank.danskebank.se/sv/login) - [Northern Ireland](https://ebank.danskebank.co.uk/en/login) | # Log on to our self-service solutions [Log on](/ebanking-logon) ## Fighting financial crime Access to the financial system transforms lives globally by helping people achieve their goals and by driving economic development. However, it can also be exploited by criminals for severe crimes like human trafficking and terrorism. Danske Bank is dedicated to fighting financial crime and we have completed a groupwide financial crime enhancement programme, investing in systems and controls to protect the bank and its customers. Continuing to develop and improve our efforts to preserve the integrity of our business and uphold our societal responsibility is a key priority for us. ## How we fight financial crime ### We adhere to Finance Denmark\'s principles At Danske Bank, we adhere to the principles developed by Finance Denmark’s Anti-Money Laundering and Counter-Terrorist Financing Taskforce in which we participated, to prevent and combat money laundering and terrorist financing. These principles are reflected in our approach. * #### We always prioritise ethics over profit * #### We comply with the spirit and the letter of the law * #### We welcome oversight * #### We have a targeted corporate culture commitment * #### We assume managerial responsibility and ensure that all staff take responsibility for AML/CTF efforts * #### We have constructive partnerships with all stakeholders, including the authorities ### We focus on people, partnerships and processes * ### ### We ensure that we have the right PEOPLE and competencies in place to fight financial crime. ### Key initiatives + #### Fighting financial crime is a top priority We have governance structures in place to ensure escalation of compliance matters when required. Our Chief Compliance Officer is a member of our Executive Leadership Team, ensuring that compliance and the fight against financial crime is an integrated part of how we do business. Financial crime prevention is part of our organisational DNA and we nurture a shared mind-set, where employees are mindful of doing the right kind of business with the right customers in the right way. + #### Mandatory fighting financial crime training All employees are required to complete mandatory training in fighting financial crime every year. We also provide targeted financial crime prevention training to employees throughout the organisation, ranging from senior management to frontline advisors. This specialised training considers different learning objectives that are specific to certain roles and includes feedback loops to ensure that we are learning from the past. + #### An essential part of our business We have experienced financial crime prevention specialists in our organisation, and we maintain strong competencies across our three lines of defence. * ### ### We engage proactively with author ...
#   LinkCollection(displayLink='danskebank.com', link='https://danskebank.com/-/media/danske-bank-com/file-cloud/2021/5/financial-crime-policy.pdf?rev=ad7e611592334042afcda054aa43431f&hash=D137E7CD1A45AF978631626263F53D7A', raw_content="Published Time: Mon, 16 Jun 2025 12:24:21 GMT 1. Objective The objective of the Financial Crime Policy (the “Policy”) is to promote a strong Financial Crime compliance culture within the Danske Bank Group to prevent the misuse of the Group’s infrastructure and Products for Financial Crime purposes. In doing so, it protects the Danske Bank Group, our customers and society. # 2. Definitions The definitions for the terms used throughout this Policy are available in Appendix 1. # 3. Scope and target group This Policy establishes the principles for the managing of risks associated with Financial Crime, ensuring compliance with relevant laws, regulations, guidelines and sanctions regimes. The Policy applies to the entire Danske Bank Group. # 4. Policy Content Principle 1: The Group maintains a robust and efficient Financial Crime Program Through its Financial Crime Program, the Group is committed to upholding high standards of integrity and compliance to protect the Group, its customers and society from Financial Crime. The Financial Crime Program is designed to enable the Group to safely carry out its business activities while effectively and efficiently managing the Financial Crime Risks it faces. The Financial Crime Program consists of elements which together form a coherent Financial Crime strategy. The Program is continuously evaluated to allow the Group to proactively anticipate, plan and adapt to emerging risks and changes in relevant laws, reg ulations, guidelines and sanctions regimes. The Financial Crime Program includes, but is not limited to: • a sound Financial Crime compliance culture, strategic prioritisation of Financial Crime compliance and allocation of sufficient funding and resources, • a three lines of defence model ensuring segregation of duties, independent oversight and consistent enforcement of the Group’s governing documents across all lines of defence, • Financial Crime Risk Tolerances, Key Performance Indicators, Key Risk Indicators and monitoring and reporting capabilities, • a Financial Crime governance framework, • frameworks for management of Financial Crime data and technology, including the use of new or innovative technology and maintenance of technical capabilities, • Financial Crime Risk assessments, • a Financial Crime Control framework, # Financial Crime Policy 20 March 2025 MARCH 2025 • Financial Crime detection capabilities, • customer and Third -Party due diligence measures, • unusual and suspicious activity investigation and reporting, • a Financial Crime training program and • reporting, escalation and whistleblowing procedures and solutions ensuring prompt response to Financial Crime. Roles and Responsibilities: • The Board of Directors and the Executive Leadership team are responsible for setting the tone from the top, ensuring strategic prioritisation of the Group’s Financial Crime Program and allocating adequate resourcing, funding and investment. • 1LoD and 2LoD are responsible for developing, implementing and maintaining the Group’s Financial Crime Program in accordance with the respective mandates. • 1LoD and 2LoD are responsible for operating the Financial Crime Program according to the mandates established in the Group’s Enterprise Risk Management Policy and other relevant policies. Principle 2: The Group maintains a governance framework for effective management of Financial Crime Risks The Financial Crime Risk governance framework is essential for effectively managing Financial Crime Risks and is established in accordance with the standards of the Group’s Enterprise Risk Management Policy. The framework must set clear requirements and be sufficiently operational. This includes: • defined roles, responsibilities and accountabilities for the managemen ...
#   LinkCollection(displayLink='www.moneylaunderingnews.com', link='https://www.moneylaunderingnews.com/2024/09/nydfs-imposes-35-million-fine-on-nordea-bank-for-alleged-aml-failures-following-panama-papers-revelations/', raw_content='Published Time: 2024-09-05T00:39:29+00:00 NYDFS Imposes $35 Million Fine on Nordea Bank for Alleged AML Failures Following Panama Papers Revelations | Money Laundering Watch =============== [Skip to content](https://www.moneylaunderingnews.com/2024/09/nydfs-imposes-35-million-fine-on-nordea-bank-for-alleged-aml-failures-following-panama-papers-revelations/#lxb_af-loop) ### [Menu](https://www.moneylaunderingnews.com/2024/09/nydfs-imposes-35-million-fine-on-nordea-bank-for-alleged-aml-failures-following-panama-papers-revelations/#) [![Image 1: Ballard Spahr LLP logo](https://www.moneylaunderingnews.com/wp-content/uploads/sites/12/2016/12/firm-logo-440x73.png)](http://www.ballardspahr.com/) [Home](https://www.moneylaunderingnews.com/)[About](https://www.moneylaunderingnews.com/about/)[Publications](http://www.ballardspahr.com/en/practiceareas/practices/white_collar_investigations/alertspublications.aspx)[Services](https://www.ballardspahr.com/en/practiceareas/practices/white_collar_investigations/anti-money-laundering)[Contact](https://www.moneylaunderingnews.com/contact/)Search… Search [Money Laundering Watch](https://www.moneylaunderingnews.com/) ============================================================== Insights and news on the world of financial corruption [Home](https://www.moneylaunderingnews.com/) » NYDFS Imposes $35 Million Fine on Nordea Bank for Alleged AML Failures Following Panama Papers Revelations NYDFS Imposes $35 Million Fine on Nordea Bank for Alleged AML Failures Following Panama Papers Revelations ========================================================================================================== By [Kelly A. Lenahan-Pfahlert](https://www.ballardspahr.com/people/attorneys/l/lenahan-pfahlert-kelly) on September 4, 2024 Posted in [Civil Penalty](https://www.moneylaunderingnews.com/category/civil-penalty/), [Compliance Program](https://www.moneylaunderingnews.com/category/compliance-program/), [Correspondent Bank Accounts](https://www.moneylaunderingnews.com/category/correspondent-bank-accounts/), [Customer Due Diligence](https://www.moneylaunderingnews.com/category/customer-due-diligence/), [New York Department of Financial Services (NYDFS)](https://www.moneylaunderingnews.com/category/new-york-department-of-financial-services/), [Panama Papers](https://www.moneylaunderingnews.com/category/panama-papers/), [Transaction Monitoring](https://www.moneylaunderingnews.com/category/transaction-monitoring/) ![Image 2](https://www.moneylaunderingnews.com/wp-content/uploads/sites/12/2024/09/AdobeStock_56312148-656x437.jpeg) On August 27, 2024, the New York State Department of Financial Services (“NYDFS”) [announced](https://www.dfs.ny.gov/reports_and_publications/press_releases/pr20240827) a [consent order](https://www.dfs.ny.gov/system/files/documents/2024/08/ea20240827-co-nordea.pdf) involving a $35 million settlement with Nordea Bank Abp (“Nordea”) for alleged significant failures related to anti-money laundering (“AML”) compliance. Nordea, headquartered in Helsinki, Finland, operates globally, including through a licensed branch in New York, [which has its own AML and transaction monitoring requirements](https://www.moneylaunderingnews.com/2017/01/2016-year-in-review-nydfs-finalizes-broad-aml-regulations/). The enforcement action, which followed revelations from the [Panama Papers leak](https://www.moneylaunderingnews.com/2018/12/first-u-s-indictment-relating-to-panama-papers-charges-lawyer-asset-manager-accountant-and-client/), found that Nordea allegedly failed to conduct proper due diligence on high-risk correspondent banking relationships and maintained inadequate AML controls. According to the NYDFS, the Panama Papers implicated Nordea in aiding clients in establishing offshor ...
#   LinkCollection(displayLink='financialcrimeacademy.org', link='https://financialcrimeacademy.org/de/geldwasche-aufgedeckt-bemerkenswerte-falle-und-beispiele-enthullt/', raw_content='[Login](https://lms.financialcrimeacademy.org/users/sign_in) * [AI Copilot](https://financialcrimeacademy.org/de/features/ai-copilot/) * [Training & Certifications](/training/?training_type=all?nocache=1) + [Column](#column) - Block + [Column](#column) - Block - Block + [Column](#column) - Block + [Column](#column) - Block * [Features](/features/) + [Column](#column) - Block + [Column](#column) - Block + [Column](#column) - Block + [Column](#column) - Block * [Pricing](https://financialcrimeacademy.org/de/pricing/) * [Blog](https://financialcrimeacademy.org/de/blog/) [login](https://lms.financialcrimeacademy.org/users/sign_in) # Geldwäsche aufgedeckt: Bemerkenswerte Fälle und Beispiele enthüllt Posted in [Bekämpfung der Geldwäsche (AML)](https://financialcrimeacademy.org/de/category/bekampfung-der-geldwasche-aml/ "Bekämpfung der Geldwäsche (AML)") on Oktober 28, 2025 [Share 0](javascript:void(0)) [Tweet 0](javascript:void(0)) [Share 0](javascript:void(0)) ## Geldwäsche verstehen Geldwäsche ist eine kriminelle Aktivität, die komplex, heimlich und weitreichend ist. Für Fachleute, die in den Bereichen Compliance, Risikomanagement und Bekämpfung von Finanzkriminalität tätig sind, ist es von entscheidender Bedeutung, die Feinheiten zu verstehen. ### Definition und Grundlagen der Geldwäsche Geldwäsche ist der Prozess, bei dem illegal erzielte Erlöse als legal erscheinen. Es ist eine Methode, die von Kriminellen verwendet wird, um ihre Aktivitäten und das damit verbundene Geld zu verschleiern und die Erträge aus ihren Verbrechen legitim erscheinen zu lassen. Dies wird oft durch eine komplexe Abfolge von Banküberweisungen oder kommerziellen Transaktionen erreicht, was die Rückverfolgung der ursprünglichen Geldquelle schwierig macht. Einige gut dokumentierte Beispiele für Geldwäsche sind die Verwendung von Bargeld für den Kauf von Lebensversicherungspolicen und deren anschließendes Verfallenlassen, der Kauf und Verkauf wertvoller Vermögenswerte wie Kunst und die Verwendung von [Briefkastenfirmen](https://financialcrimeacademy.org/de/inside-the-web-erkundung-der-dunklen-welt-der-briefkastenfirmen/) zur Verschleierung des Eigentums und des Transfers von Geldern, insbesondere im Immobiliensektor. Die Falschdarstellung von Waren oder Dienstleistungen bei [der handelsbasierten Geldwäsche](https://financialcrimeacademy.org/trade-based-money-laundering-methods/ "handelsbasierte Geldwäsche") und der Missbrauch von Gelddienstleistungsunternehmen (MSBs) sind ebenfalls gängige Methoden zur Geldwäsche. ### Die Phasen der Geldwäsche Das Verständnis der [Phasen der Geldwäsche](https://financialcrimeacademy.org/stages-of-money-laundering/) ist entscheidend, um diese illegalen Aktivitäten aufzudecken und zu verhindern. Diese Phasen umfassen in der Regel die Platzierung, das Layering und die Integration. **Platzierung**: Dies ist der Prozess der Einführung des illegalen Geldes in das Finanzsystem. Dies kann durch die Aufteilung großer Bargeldbeträge in weniger auffällige kleinere Summen geschehen, die dann direkt auf ein Bankkonto eingezahlt werden, oder durch den Kauf einer Reihe von Instrumenten (wie Schecks oder Zahlungsanweisungen), die dann gesammelt und auf Konten an einem anderen Ort eingezahlt werden. **Schichtung**: In dieser Phase führt der Geldwäscher in der Regel eine Reihe von Umrechnungen oder Bewegungen der Gelder durch, um sie von ihrer Quelle zu entfernen. Das Layering kann aus mehreren Bank-zu-Bank-Überweisungen, Überweisungen zwischen verschiedenen Konten mit unterschiedlichen Namen in verschiedenen Ländern, Ein- und Auszahlungen bestehen, um den Geldbetrag auf den Konten kontinuierlich zu ändern, die Währung des Geldes zu ändern und hochwertige Gegenstände (wie Häuser oder Unternehmen) zu kaufen, um die Form des Geldes zu ändern. Dies wird manchmal als  ...
#   LinkCollection(displayLink='theconversation.com', link='https://theconversation.com/blanchiment-dargent-leurope-passe-enfin-a-laction-258091', raw_content='Blanchiment d’argent: l’Europe passe (enfin) à l’action =============== ![Image 1](https://www.facebook.com/tr?id=1392960898182692%20%20%20%20&ev=ViewContent%20%20%20%20&cd[content_name]=Blanchiment%20d%E2%80%99argent%C2%A0:%20l%E2%80%99Europe%20passe%20(enfin)%20%C3%A0%20l%E2%80%99action%20%20%20%20&cd[content_type]=content%20%20%20%20&cd[content_ids]=258091) * [Home](https://theconversation.com/us) * [Arts + Culture](https://theconversation.com/us/arts) * [Economy](https://theconversation.com/us/business) * [Education](https://theconversation.com/us/education) * [Environment + Energy](https://theconversation.com/us/environment) * [Ethics + Religion](https://theconversation.com/us/ethics) * [Health](https://theconversation.com/us/health) * [Politics + Society](https://theconversation.com/us/politics) * [Science + Tech](https://theconversation.com/us/technology) * [World](https://theconversation.com/us/world) * [Podcasts](https://theconversation.com/us/podcasts) * [Local](https://theconversation.com/us/local) * [En Español](https://theconversation.com/us/espanol) ### Edition [Donate](https://donate.theconversation.com/us?utm_source=theconversation.com&utm_medium=website&utm_campaign=mobile-menu) [](https://theconversation.com/blanchiment-dargent-leurope-passe-enfin-a-laction-258091#)[](https://theconversation.com/blanchiment-dargent-leurope-passe-enfin-a-laction-258091#) [![Image 2: The Conversation](https://cdn.theconversation.com/static/tc/logos/logo-en-deecd7f6345376bc1471b3c9cd047e76.svg)](https://theconversation.com/us) Edition: United States * [Africa](https://theconversation.com/africa "Africa edition") * [Australia](https://theconversation.com/au "Australia edition") * [Brasil](https://theconversation.com/br "Brasil edition") * [Canada](https://theconversation.com/ca "Canada edition") * [Canada (français)](https://theconversation.com/ca-fr "Canada (français) edition") * [España](https://theconversation.com/es "España edition") * [Europe](https://theconversation.com/europe "Europe edition") * [France](https://theconversation.com/fr "France edition") * [Global](https://theconversation.com/global "Global edition") * [Indonesia](https://theconversation.com/id "Indonesia edition") * [New Zealand](https://theconversation.com/nz "New Zealand edition") * [United Kingdom](https://theconversation.com/uk "United Kingdom edition") s [Donate](https://donate.theconversation.com/us?utm_source=theconversation.com&utm_medium=website&utm_campaign=topbar)[Newsletters](https://theconversation.com/us/newsletters?utm_campaign=System&utm_content=newsletter&utm_medium=TopBar&utm_source=theconversation.com "Sign up to receive our daily email newsletter") [![Image 3: The Conversation](https://cdn.theconversation.com/static/tc/logos/logo-en-deecd7f6345376bc1471b3c9cd047e76.svg)](https://theconversation.com/us) Academic rigor, journalistic flair [Arts + Culture](https://theconversation.com/us/arts "Arts + Culture")[Economy](https://theconversation.com/us/business "Economy")[Education](https://theconversation.com/us/education "Education")[Environment + Energy](https://theconversation.com/us/environment "Environment + Energy")[Ethics + Religion](https://theconversation.com/us/ethics "Ethics + Religion")[Health](https://theconversation.com/us/health "Health")[Politics + Society](https://theconversation.com/us/politics "Politics + Society")[Science + Tech](https://theconversation.com/us/technology "Science + Tech")[World](https://theconversation.com/us/world "World")[Podcasts](https://theconversation.com/us/podcasts "Podcasts")[Local](https://theconversation.com/us/local "Local") ![Image 4: Dollar dans une machine à laver](https://images.theconversation.com/files/676836/original/file-20250626-62-4nftoa.jpg?ixlib=rb-4.1.0&rect=0%2C0%2C5772%2C3848&q=75&auto=format&w=768&h=512&fit=crop&dpr=1) Le bl ...
# ...
#   'Danske Bank Faces Scrutiny Over Third-Party Failures in Money Laundering Controls\n\nAn examination of Danske Bank’s money laundering issues highlights critical gaps in third-party due diligence and monitoring within its AML framework.\n\nDanske Bank, a prominent financial institution in the Nordic banking sector, has come under renewed scrutiny for its role in alleged money laundering activities linked to correspondent banking relationships and external vendors. The bank’s challenges appear rooted in weaknesses surrounding the oversight of third-party service providers, whose insufficient compliance with anti-money laundering (AML) and know-your-customer (KYC) protocols may have facilitated illicit financial flows across multiple jurisdictions.\n\nCentral to Danske Bank’s AML framework are processes such as enhanced due diligence on beneficial ownership, politically exposed persons (PEP) screening, sanctions checks, and ongoing transaction monitoring. However, the involvement of external vendors in customer onboarding and suspicious activity reporting (SARs) has raised concerns about inconsistent application of these controls. Risk indicators including unusual transaction patterns, high-risk jurisdictions, and complex ownership structures were reportedly not adequately flagged or escalated, partially due to gaps in vendor management and insufficient real-time monitoring capabilities.\n\nRegulatory authorities have launched probes into Danske Bank’s compliance failures, focusing on the bank’s reliance on third parties for critical AML functions. These investigations have resulted in consent orders and settlement discussions, with allegations centering on inadequate oversight of correspondent banking channels and failure to report suspicious activities promptly. The enforcement posture underscores the importance of robust vendor risk management and continuous monitoring to prevent exploitation of AML vulnerabilities.\n\nUltimately, Danske Bank’s experience underscores the pivotal role that third-party due diligence and monitoring play in maintaining effective AML defenses. Addressing these gaps remains essential to mitigating laundering risks and restoring confidence in the bank’s compliance infrastructure.',
#   'Danske Bank Money Laundering Scandal Raises Questions on Regional Financial Stability\n\nThe unfolding money laundering allegations against Danske Bank spotlight potential risks to regional banking stability and investor confidence in the Nordic financial sector. Danske Bank, a key player in the Danish and broader Baltic banking markets, is under scrutiny for alleged lapses in anti-money laundering (AML) controls that may have facilitated illicit fund flows through its correspondent banking channels. This development poses challenges for credit availability and market trust in the region.\n\nCentral to the concerns are Danske Bank’s AML and know-your-customer (KYC) frameworks, which reportedly failed to adequately identify and monitor high-risk clients, including politically exposed persons (PEPs) and entities with unclear beneficial ownership. Transaction monitoring systems and suspicious activity reports (SARs) appear to have been insufficiently robust, potentially allowing sanctioned individuals and high-risk counterparties to move funds without timely detection. The bank’s correspondent banking relationships, critical for cross-border payments, also came under question for their role in enabling suspicious transactions.\n\nRegulatory authorities across multiple jurisdictions have launched probes into Danske Bank’s compliance with AML regulations, examining whether adequate controls were in place and properly enforced. The bank faces potential consent orders or settlements involving substantial fines, reflecting the seriousness of the alleged compliance breaches. Market reactions have been cautious, with investors closely watching how Danske Bank addresses these issues and strengthens its AML and KYC measures to restore confidence and ensure ongoing credit flow in the affected regions.\n\nUltimately, Danske Bank’s money laundering allegations underscore the persistent challenges regional banks face in maintaining financial integrity amid complex cross-border activities. The bank’s response to these compliance failures will be critical in shaping the stability of the regional banking sector and investor sentiment moving forward.'],
#  'evidence_claims': [EvidenceClaim(claim_text='Between 2007 and 2015, Danske Bank was alleged to have laundered over €200 billion in suspicious funds through its Estonian branch, exposing significant deficiencies in its anti-money laundering controls and compliance mechanisms.', claim_type='allegation', supporting_urls=['https://pythagoras-solutions.com/en/insights/danske-bank-scandal-turning-point-aml-compliance-of-banking-sector', 'https://pythagoras-solutions.com/insights/danske-bank-skandal-ein-wendepunkt-aml-compliance-im-banksektor', 'https://theconversation.com/blanchiment-dargent-leurope-passe-enfin-a-laction-258091', 'https://www.tookitaki.com/blog/from-wachovia-to-danske-bank-biggest-money-laundering-cases-in-recent-times'], date_publish='2019-03-25'),
#   EvidenceClaim(claim_text="Allegations were made that between 2007 and 2015, €201 billion of suspicious origin passed through Danske Bank's Estonian branch, with ten former employees accused of money laundering and the Central Bank of Russia warning Danske Bank about possible illegal transfers by Russian clients as early as 2013.", claim_type='allegation', supporting_urls=['https://www.tadviser.ru/index.php/%D0%A1%D1%82%D0%B0%D1%82%D1%8C%D1%8F:%D0%9E%D1%82%D0%BC%D1%8B%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5_%D0%B4%D0%B5%D0%BD%D0%B5%D0%B3_(Money_Muling)'], date_publish='Unknown'),
#   EvidenceClaim(claim_text='Danske Bank was referenced in the context of scandals that prompted new EU anti-money laundering legislation, implying allegations of money laundering or compliance failures, though no specific new developments were provided.', claim_type='allegation', supporting_urls=['https://www.socialistsanddemocrats.eu/de/newsroom/die-sd-fraktion-begruesst-die-bahnbrechende-einigung-beim-eu-anti-geldwaesche-paket'], date_publish='Unknown'),
#   EvidenceClaim(claim_text='Danske Bank was subject to investigations by Danish, Estonian, U.S., and U.K. authorities following the revelation that over $230 billion in suspicious transactions were processed through its Estonian branch between 2007 and 2015, leading to the resignation of key executives and the closure of the Estonian branch in 2019.', claim_type='investigation', supporting_urls=['https://www.sanctionscanner.com/blog/danske-bank-case-money-laundering-scandal-1130'], date_publish='2025-06-20'),
#   EvidenceClaim(claim_text='In 2019, journalists revealed that Swedbank and Danske Bank were used to move nearly six billion dollars through suspicious accounts in the Baltic countries, with Danske Bank linked to the movement of suspicious funds in the Baltics alongside Swedbank.', claim_type='investigation', supporting_urls=['https://www.occrp.org/ru/ficher/utecka-iz-swedbank-pokazala-cto-sotrudniki-banka-sutili-pro-sxemy-otmyvaniia-deneg'], date_publish='2024-11-12'),
#   EvidenceClaim(claim_text='Danske Bank agreed to pay the French government €6.3 million to settle money laundering charges related to its Estonian branch, following a deferred prosecution agreement with France’s National Financial Prosecutor, with the settlement validated by the Paris judicial court on September 18, 2024.', claim_type='settlement', supporting_urls=['https://www.moneylaundering.com/news/danske-bank-pays-e6-3-million-to-settle-money-laundering-charges-in-france/', 'https://www.twobirds.com/fr/insights/2025/france/lcb-ft-retrospective-2024-partie-2', 'https://navacelle.law/fr/cjip-danske-bank/'], date_publish='2024-09-18'),
#   EvidenceClaim(claim_text='Danske Bank agreed to pay more than $2 billion as part of a global settlement with the U.S. Department of Justice, the SEC, the United States Attorney’s Office for the Southern District of New York, and Denmark’s Special Crime Unit, addressing significant AML compliance failures and related investor disclosures.', claim_type='settlement', supporting_urls=['https://www.zuckermanlaw.com/uncategorized/money-laundering-sec-whistleblower-program/'], date_publish='Unknown'),
#   EvidenceClaim(claim_text="On January 7, 2025, the US Department of Justice announced that Estonia would receive $50 million from assets confiscated in the Danske Bank Estonia money laundering case, as part of a settlement recognizing Estonia's assistance in the investigation; Danske Bank admitted responsibility for misleading US banks and processing suspicious transactions for high-risk clients, and was fined over $2 billion by US authorities in 2022.", claim_type='settlement', supporting_urls=['https://www.cbr.ru/Collection/Collection/File/55401/Jan_2025.pdf'], date_publish='2025-01-07'),
#   EvidenceClaim(claim_text='Danske Bank was fined hundreds of millions of dollars following the 2018 revelation that approximately €200 billion in suspicious transactions were processed through its Estonian branch, with investigations revealing failures in client checks and transaction monitoring.', claim_type='fine', supporting_urls=['https://dineka.ru/news/1374/'], date_publish='2024-06-07'),
#   EvidenceClaim(claim_text='Danish authorities imposed fines totaling $2 million on Danske Bank for its involvement in a major money laundering scandal through its Estonian branch between 2007 and 2015, attributing responsibility to several managers and bank officials.', claim_type='fine', supporting_urls=['https://financialcrimeacademy.org/de/geldwasche-aufgedeckt-bemerkenswerte-falle-und-beispiele-enthullt/', 'https://financialcrimeacademy.org/fr/blanchiment-dargent-demasque-des-cas-et-des-exemples-notables-devoiles/'], date_publish='2025-08-29'),
#   EvidenceClaim(claim_text='Danske Bank was fined €470 million for its involvement in a major international money laundering scandal, where approximately €200 billion in suspicious funds were laundered through its Estonian branch between 2007 and 2015, exposing deficiencies in regulatory oversight and compliance controls in Estonia.', claim_type='fine', supporting_urls=['https://pideeco.be/fr/articles/comment-les-gatekeepers-sont-utilises-pour-le-blanchiment-dargent/', 'https://coredo.eu/ru/tri-jetapa-otmyvanija-deneg-i-ih-vlijanie-na-biznes/'], date_publish='2024-11-18'),
#   EvidenceClaim(claim_text='Danske Bank was fined by Danish regulators for anti-money laundering failures after its Estonian branch allegedly laundered approximately $230 billion in suspicious transactions between 2007 and 2015, mainly from Russian clients, resulting in regulatory penalties, legal proceedings, and significant reputational damage.', claim_type='fine', supporting_urls=['https://blog.transworldcompliance.com/fr/des-amendes-qui-font-froid-dans-le-dos-les-sanctions-les-plus-effrayantes-en-cas-de-non-conformite-dans-le-secteur-financier'], date_publish='Unknown'),
#   EvidenceClaim(claim_text='Danske Bank was fined by Danish and international authorities following investigations into the laundering of approximately €200 billion in suspicious funds through its Estonian branch between 2007 and 2015, resulting in a massive loss of trust and the resignation of the CEO.', claim_type='fine', supporting_urls=['https://exkulpa.de/geldwaeschepraevention/geldwaescheparadies-deutschland-ursachen-eu-vergleich-folgen/'], date_publish='2024-07-30'),
#   EvidenceClaim(claim_text='Danske Bank was fined as part of a major US money laundering scandal between 2008 and 2016, with the bank defrauding several US banks and being sentenced to a billion-dollar fine, while Deutsche Bank processed suspicious transactions worth more than $267 billion for Danske Bank.', claim_type='fine', supporting_urls=['https://www.produktion.de/wirtschaft/die-10-groessten-wirtschaftsskandale-in-deutschland-383.html'], date_publish='2024-01-16'),
#   EvidenceClaim(claim_text="Danske Bank was fined over $2 billion by US authorities in 2022 as a result of an investigation into its Estonian branch's involvement in processing suspicious transactions for high-risk clients through the US financial system.", claim_type='fine', supporting_urls=['https://www.sanctionscanner.com/blog/danske-bank-case-money-laundering-scandal-1130', 'https://www.cbr.ru/Collection/Collection/File/55401/Jan_2025.pdf'], date_publish='2025-06-20'),
#   EvidenceClaim(claim_text='Danske Bank was fined €6,028,799 and ordered to pay an additional €300,000 in compensation to the French state as part of a judicial public interest agreement (CJIP) with the French National Financial Prosecutor, addressing money laundering of tax fraud committed between 2007 and 2014 via its Estonian branch.', claim_type='fine', supporting_urls=['https://www.twobirds.com/fr/insights/2025/france/lcb-ft-retrospective-2024-partie-2', 'https://navacelle.law/fr/cjip-danske-bank/'], date_publish='2025-05-27'),
#   EvidenceClaim(claim_text="The United States allocated $50 million (48.8 million euros) to Estonia as part of a settlement for Estonia's contribution to resolving the Danske Bank money laundering case, with the funds originating from fines paid in connection with the Danske Bank case and used for financial crime prevention and investigation in Estonia.", claim_type='fine', supporting_urls=['https://rus.postimees.ee/8338600/ssha-vydelili-estonii-milliony-na-borbu-s-otmyvaniem-deneg'], date_publish='2025-10-08'),
#   EvidenceClaim(claim_text='In 2022, Danske Bank admitted guilt to conspiracy to commit bank fraud, acknowledging that it provided banking services to suspicious clients through its Estonian branch despite being aware of money laundering risks.', claim_type='conviction', supporting_urls=['https://finance.ua/goodtoknow/skhemy-vidmyvannia-hroshei-nairezonansnishi-spravy-svitu'], date_publish='2024-07-11')]}

# %%
## data used for the conclusion
evidence_collection = [] 
for elem in results.get("search_results"):
    if elem.summary:
        out = elem.model_dump( exclude={"raw_content", "hyde_score"} )
        evidence_collection.append(out)
        
evidence_collection
# Out:
# [{'displayLink': 'lucinity.com',
#   'link': 'https://lucinity.com/blog/reshaping-anti-money-laundering-compliance-the-impact-of-ai-on-financial-integrity',
#   'summary': 'No financial crime or compliance information is present in the content.',
#   'claim_type': 'other',
#   'date_published': 'Unknown'},
#  {'displayLink': 'danskebank.com',
#   'link': 'https://danskebank.com/about-us/corporate-governance/compliance/fighting-financial-crime',
#   'summary': 'No financial crime or compliance information is present in the content.',
#   'claim_type': 'other',
#   'date_published': 'Unknown'},
#  {'displayLink': 'danskebank.com',
#   'link': 'https://danskebank.com/-/media/danske-bank-com/file-cloud/2021/5/financial-crime-policy.pdf?rev=ad7e611592334042afcda054aa43431f&hash=D137E7CD1A45AF978631626263F53D7A',
#   'summary': 'No financial crime or compliance information is present in the content.',
#   'claim_type': 'other',
#   'date_published': '2025-06-16'},
#  {'displayLink': 'www.moneylaunderingnews.com',
#   'link': 'https://www.moneylaunderingnews.com/2024/09/nydfs-imposes-35-million-fine-on-nordea-bank-for-alleged-aml-failures-following-panama-papers-revelations/',
#   'summary': 'No financial crime or compliance information is present in the content regarding Danske Bank. The content primarily discusses regulatory actions and AML deficiencies related to Nordea Bank, with only a brief mention of Danske Bank in the context of correspondent banking relationships and risk ratings assigned by Nordea. There are no allegations, investigations, fines, or other financial crime compliance actions described for Danske Bank in this content.',
#   'claim_type': 'other',
#   'date_published': '2024-09-05'},
#  {'displayLink': 'financialcrimeacademy.org',
#   'link': 'https://financialcrimeacademy.org/de/geldwasche-aufgedeckt-bemerkenswerte-falle-und-beispiele-enthullt/',
#   'summary': "Danske Bank's Estonian branch was involved in a major money laundering scandal between 2007 and 2015, serving as a channel for an estimated $228 billion in laundered funds. Thousands of suspicious customers were implicated in the scheme, which brought public attention to significant compliance failures at Danske Bank. Danish authorities imposed fines totaling $2 million and attributed responsibility to several managers of the bank.",
#   'claim_type': 'fine',
#   'date_published': '2025-10-28'},
#  {'displayLink': 'theconversation.com',
#   'link': 'https://theconversation.com/blanchiment-dargent-leurope-passe-enfin-a-laction-258091',
#   'summary': "Danske Bank is cited as the epicenter of the largest money laundering scandal in Europe, with revelations that over €200 billion in suspicious transactions passed through its Estonian branch. The article discusses this as part of a broader analysis of anti-money laundering (AML) failures and scandals involving major EU banks. It highlights systemic deficiencies in AML controls and supervision within the European Union, referencing Danske Bank's involvement in large-scale illicit financial flows as a key example of such failures.",
#   'claim_type': 'allegation',
#   'date_published': '2025-07-15'},
#  {'displayLink': 'www.socialistsanddemocrats.eu',
#   'link': 'https://www.socialistsanddemocrats.eu/de/newsroom/die-sd-fraktion-begruesst-die-bahnbrechende-einigung-beim-eu-anti-geldwaesche-paket',
#   'summary': 'The content references scandals involving Danske Bank and Credit Suisse as part of the justification for new EU anti-money laundering legislation. It mentions that the reforms were necessary in light of these scandals, implying allegations of money laundering or compliance failures at Danske Bank. However, no specific details, outcomes, or new developments regarding Danske Bank are provided in the content.',
#   'claim_type': 'allegation',
#   'date_published': 'Unknown'},
#  {'displayLink': 'www.produktion.de',
#   'link': 'https://www.produktion.de/wirtschaft/die-10-groessten-wirtschaftsskandale-in-deutschland-383.html',
#   'summary': "Danske Bank was involved in one of the largest US money laundering scandals. Between 2008 and 2016, Danske Bank defrauded several US banks and was sentenced to a billion-dollar fine. The Deutsche Bank processed suspicious transactions worth more than $267 billion for Danske Bank. The case involved significant deficiencies in anti-money laundering measures and compliance failures related to Danske Bank's Estonian subsidiary.",
#   'claim_type': 'fine',
#   'date_published': '2024-01-16'},
#  {'displayLink': 'financialcrimeacademy.org',
#   'link': 'https://financialcrimeacademy.org/fr/blanchiment-dargent-demasque-des-cas-et-des-exemples-notables-devoiles/',
#   'summary': "Danske Bank's Estonian branch was involved in a major money laundering scandal, acting as an intermediary for approximately $228 billion in laundered funds between 2007 and 2015. The case involved thousands of suspicious clients and significant compliance failures. Danish authorities imposed fines totaling $2 million and attributed responsibility to several bank officials. This case highlighted serious deficiencies in Danske Bank's AML compliance program and failures in transaction monitoring and customer due diligence.",
#   'claim_type': 'fine',
#   'date_published': '2025-08-29'},
#  {'displayLink': 'exkulpa.de',
#   'link': 'https://exkulpa.de/geldwaeschepraevention/geldwaescheparadies-deutschland-ursachen-eu-vergleich-folgen/',
#   'summary': 'Danske Bank war in einen der größten Geldwäscheskandale Europas verwickelt. Über die estnische Niederlassung der Bank wurden zwischen 2007 und 2015 rund 200 Milliarden Euro verdächtiger Gelder, hauptsächlich aus Russland, Aserbaidschan und der Ukraine, gewaschen. Der Skandal führte zu einem massiven Vertrauensverlust und einer erheblichen Belastung des Rufs der Bank. Die dänischen und estnischen Behörden sowie internationale Regulierungsbehörden führten umfassende Untersuchungen durch, was zu hohen Geldstrafen und dem Rücktritt des CEO führte.',
#   'claim_type': 'fine',
#   'date_published': '2024-07-30'},
#  {'displayLink': 'www.tookitaki.com',
#   'link': 'https://www.tookitaki.com/blog/from-wachovia-to-danske-bank-biggest-money-laundering-cases-in-recent-times',
#   'summary': 'Danske Bank, Denmark’s largest bank, was implicated in a major money laundering scandal involving its Estonian branch. The European Commission described it as the biggest scandal in Europe, with allegations that thousands of suspicious customers used the bank’s weak controls to carry out illicit transactions worth about US$228 billion during 2007-2015. The content highlights deficiencies in Danske Bank’s anti-money laundering controls that allegedly enabled these illicit activities.',
#   'claim_type': 'allegation',
#   'date_published': '2019-03-25'},
#  {'displayLink': 'coredo.eu',
#   'link': 'https://coredo.eu/ru/tri-jetapa-otmyvanija-deneg-i-ih-vlijanie-na-biznes/',
#   'summary': "Danske Bank was recently fined €470 million (US$495 million) due to its involvement in an international money laundering scandal. The content highlights that the fine was imposed as a consequence of Danske Bank's participation in money laundering activities, emphasizing the significant regulatory penalties that can result from such compliance failures.",
#   'claim_type': 'fine',
#   'date_published': 'Unknown'},
#  {'displayLink': 'dineka.ru',
#   'link': 'https://dineka.ru/news/1374/',
#   'summary': "In 2018, Danske Bank was involved in one of the largest money laundering scandals in Europe. Approximately 200 billion euros in suspicious transactions were processed through the bank's Estonian branch. As a result, Danske Bank was fined hundreds of millions of dollars, its management faced serious criticism, and the bank suffered significant reputational losses. The investigation revealed that Danske Bank failed to properly check its clients and did not conduct adequate transaction monitoring.",
#   'claim_type': 'fine',
#   'date_published': '2024-06-07'},
#  {'displayLink': 'pideeco.be',
#   'link': 'https://pideeco.be/fr/articles/comment-les-gatekeepers-sont-utilises-pour-le-blanchiment-dargent/',
#   'summary': 'Danske Bank was involved in a major international money laundering scandal revealed in 2018, where approximately €200 billion in suspicious funds were laundered through its Estonian branch between 2007 and 2015. The scandal highlighted the role of professionals, including lawyers, in facilitating money laundering by creating shell companies and complex corporate structures to obscure the origin and ownership of funds. Danske Bank was fined €470 million for its involvement in this case, which exposed deficiencies in regulatory oversight and compliance controls in Estonia. The case is cited as a prominent example of how gatekeepers can be exploited for money laundering purposes.',
#   'claim_type': 'fine',
#   'date_published': '2024-11-18'},
#  {'displayLink': 'pythagoras-solutions.com',
#   'link': 'https://pythagoras-solutions.com/en/insights/danske-bank-scandal-turning-point-aml-compliance-of-banking-sector',
#   'summary': "The content discusses the Danske Bank money laundering scandal, describing it as one of the most severe cases in the financial world. It alleges that over €200 billion in suspicious funds were laundered through Danske Bank's Estonian branch between 2007 and 2015. The scandal exposed significant failures in Danske Bank's internal AML (Anti-Money Laundering) control mechanisms, which were insufficient to detect and prevent illegal activities. The case led to investigations, regulatory scrutiny, and penalties, and highlighted the need for stricter AML regulations and improved compliance structures within Danske Bank and the broader European banking sector. The summary also notes the reputational and economic damage suffered by Danske Bank as a result of these compliance failures.",
#   'claim_type': 'allegation',
#   'date_published': '2024-04-10'},
#  {'displayLink': 'rus.postimees.ee',
#   'link': 'https://rus.postimees.ee/8338600/ssha-vydelili-estonii-milliony-na-borbu-s-otmyvaniem-deneg',
#   'summary': "Danske Bank was involved in a money laundering case that resulted in the United States allocating $50 million (48.8 million euros) to Estonia as part of a settlement for Estonia's contribution to resolving the so-called Danske Bank money laundering case. The funds, originating from fines paid in connection with the Danske Bank case, are being used in Estonia for the prevention, detection, and investigation of financial crimes, including money laundering, cybercrime, and terrorism financing. The projects funded aim to strengthen Estonia's capacity to combat financial crime, improve investigation practices, enhance technological support, and provide sustainable training for specialists. The allocation of these funds underscores the international cooperation between Estonia and the United States in fighting financial crime.",
#   'claim_type': 'fine',
#   'date_published': '2025-10-08'},
#  {'displayLink': 'tribuna.ee',
#   'link': 'https://tribuna.ee/tribuna/economy/usa-finansirujut-proekty-estonia-predotvrashenie-korriptsii/',
#   'summary': 'No financial crime or compliance information is present in the content regarding Danske Bank. The content discusses U.S. funding for Estonian projects aimed at preventing corruption and money laundering, referencing the "so-called money laundering case in Danske Bank" as the context for the funding, but does not provide any new allegations, investigations, charges, fines, settlements, or other compliance actions specifically involving Danske Bank.',
#   'claim_type': 'other',
#   'date_published': '2025-11-09'},
#  {'displayLink': 'pythagoras-solutions.com',
#   'link': 'https://pythagoras-solutions.com/insights/danske-bank-skandal-ein-wendepunkt-aml-compliance-im-banksektor',
#   'summary': "The content details the Danske Bank money laundering scandal, describing it as one of the most serious cases in the financial sector. It alleges that between 2007 and 2015, over 200 billion euros of suspicious funds were laundered through Danske Bank's Estonian branch. The scandal revealed significant deficiencies in Danske Bank's AML (Anti-Money Laundering) controls, with thousands of suspicious transactions going undetected due to inadequate internal compliance mechanisms. The case led to extensive investigations, reputational damage, and calls for stricter AML regulations and reforms across the European banking sector. The summary also notes that Danske Bank's compliance structure and corporate culture were found insufficient for managing money laundering risks.",
#   'claim_type': 'allegation',
#   'date_published': '2024-04-10'},
#  {'displayLink': 'www.zuckermanlaw.com',
#   'link': 'https://www.zuckermanlaw.com/uncategorized/money-laundering-sec-whistleblower-program/',
#   'summary': 'Danske Bank agreed to pay $413 million to settle charges that it violated the antifraud provisions of the Securities Exchange Act of 1934 by misleading investors about its anti-money laundering (AML) compliance program in its Estonian branch and failing to disclose the risks posed by the program’s significant deficiencies. Danske Bank has agreed to pay more than $2 billion as part of an integrated, global resolution with the SEC, the Department of Justice, the United States Attorney’s Office for the Southern District of New York, and Denmark’s Special Crime Unit. The settlement addresses significant AML compliance failures and related investor disclosures.',
#   'claim_type': 'settlement',
#   'date_published': 'Unknown'},
#  {'displayLink': 'blog.transworldcompliance.com',
#   'link': 'https://blog.transworldcompliance.com/fr/des-amendes-qui-font-froid-dans-le-dos-les-sanctions-les-plus-effrayantes-en-cas-de-non-conformite-dans-le-secteur-financier',
#   'summary': "Danske Bank was involved in a major money laundering scandal, where its Estonian branch allegedly laundered approximately $230 billion in suspicious transactions between 2007 and 2015, mainly from Russian clients. The scandal became public in 2018, and Danish regulators imposed a fine on Danske Bank for anti-money laundering (AML) failures. Investigations revealed that Danske Bank lacked adequate controls, allowing criminal networks to exploit its systems for illicit transactions. The bank faced regulatory penalties, legal proceedings, shareholder challenges, and significant reputational damage. Senior executives resigned, and the bank's reputation suffered due to these compliance failures.",
#   'claim_type': 'fine',
#   'date_published': 'Unknown'},
#  {'displayLink': 'finance.ua',
#   'link': 'https://finance.ua/goodtoknow/skhemy-vidmyvannia-hroshei-nairezonansnishi-spravy-svitu',
#   'summary': 'Danske Bank was involved in a major money laundering scandal related to suspicious transactions totaling approximately €200 billion processed through its Estonian branch. The scandal came to light in 2018 after a whistleblower revealed that Danske Bank ignored signs of potentially criminal operations moving billions of dollars to the West from 2008 to 2017, including from Russian clients. Many clients were shell companies registered in the UK. An investigation by Danish law firm Bruun&Hjejle found that Danske Bank employees may have knowingly participated in illegal activities, and the bank failed to control money laundering, did not know the owners of many accounts, and lacked automated transaction monitoring. In 2022, Danske Bank admitted guilt to conspiracy to commit bank fraud, acknowledging that it provided banking services to suspicious clients through its Estonian branch despite being aware of money laundering risks.',
#   'claim_type': 'conviction',
#   'date_published': '2024-07-11'},
#  {'displayLink': 'www.sanctionscanner.com',
#   'link': 'https://www.sanctionscanner.com/blog/danske-bank-case-money-laundering-scandal-1130',
#   'summary': 'Danske Bank was implicated in a major money laundering scandal involving over $230 billion in suspicious transactions processed through its Estonian branch between 2007 and 2015. The scandal exposed significant anti-money laundering (AML) and compliance failures, including poor Know Your Customer (KYC) procedures, inadequate suspicious activity reporting (SAR), and weak transaction monitoring systems. Investigations by Danish, Estonian, U.S., and U.K. authorities followed, leading to the resignation of key executives and the closure of the Estonian branch in 2019. Danske Bank faced multiple regulatory investigations, criminal charges in Denmark and other jurisdictions, and paid hundreds of millions in fines. In December 2022, Danske Bank agreed to forfeit $2 billion as part of a global settlement with the U.S. Department of Justice and the SEC for defrauding U.S. banks and violating AML laws. The case is considered a turning point for AML compliance in Europe, prompting regulatory reforms and stricter oversight.',
#   'claim_type': 'fine',
#   'date_published': '2025-06-20'},
#  {'displayLink': 'www.cbr.ru',
#   'link': 'https://www.cbr.ru/Collection/Collection/File/55401/Jan_2025.pdf',
#   'summary': "On January 7, 2025, the US Department of Justice issued a press release regarding a decision to transfer part of the assets confiscated in the money laundering case involving the Estonian branch of Danske Bank A.S. (Danske Bank Estonia) to Estonia. According to the agreement with the US Department of Justice, Estonia will receive $50 million for its assistance and significant contribution to the investigation of Danske Bank Estonia. The funds will be used to improve Estonia's national system for combating financial crimes, including money laundering, fraud, and cybercrime, as well as for specialist training programs, digital forensic expertise, and public awareness campaigns. The content also notes that Danske Bank admitted responsibility for misleading US banks and processing suspicious transactions for high-risk clients through the US financial system, amounting to billions of US dollars. In 2022, Danske Bank was fined over $2 billion by US authorities as a result of the investigation.",
#   'claim_type': 'settlement',
#   'date_published': '2025-01-07'},
#  {'displayLink': 'www.tadviser.ru',
#   'link': 'https://www.tadviser.ru/index.php/%D0%A1%D1%82%D0%B0%D1%82%D1%8C%D1%8F:%D0%9E%D1%82%D0%BC%D1%8B%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5_%D0%B4%D0%B5%D0%BD%D0%B5%D0%B3_(Money_Muling)',
#   'summary': "The content references allegations of large-scale money laundering through the Estonian branch of Danske Bank. According to the information, between 2007 and 2015, €201 billion of suspicious origin passed through Danske Bank's Estonian branch, with the transactions primarily involving non-resident clients who had ceased operations by that time. Ten former employees of Danske Bank, mainly client managers, were detained and accused of money laundering, with the total amount of suspicious transactions cited as approximately €300 million. The allegations include claims that bank staff, under the leadership of the branch head, created conditions for large-scale money laundering and concealed these activities. The Central Bank of Russia reportedly warned Danske Bank's Estonian branch about possible illegal transfers by Russian clients as early as 2013, but Danske Bank did not take the necessary measures. The scandal led to the resignation of Danske Bank's CEO, Thomas Borgen.",
#   'claim_type': 'allegation',
#   'date_published': 'Unknown'},
#  {'displayLink': 'www.moneylaundering.com',
#   'link': 'https://www.moneylaundering.com/news/danske-bank-pays-e6-3-million-to-settle-money-laundering-charges-in-france/',
#   'summary': "Danske Bank agreed to pay the French government €6.3 million to settle money laundering charges related to its now-closed Estonian branch. French authorities began investigating Danske Bank in February 2019 over suspicions that weak anti-money laundering controls at the Estonian affiliate allowed a French Russian businesswoman to evade millions of euros in tax and customs duties via offshore entities from 2007 to 2014. French prosecutors concluded that Danske Bank's Estonian branch permitted non-resident portfolio customers to open accounts and conduct transactions without adequate controls or due diligence. The settlement was reached through a deferred prosecution agreement with France’s National Financial Prosecutor. This follows previous enforcement actions, including Danske Bank's December 2022 guilty plea in the U.S. to conspiracy to defraud banks and agreement to pay over $2 billion in penalties and implement AML upgrades.",
#   'claim_type': 'settlement',
#   'date_published': '2024-09-18'},
#  {'displayLink': 'navacelle.law',
#   'link': 'https://navacelle.law/fr/cjip-danske-bank/',
#   'summary': "Danske Bank concluded a judicial public interest agreement (CJIP) with the French National Financial Prosecutor (PNF) regarding allegations of money laundering of tax fraud committed between 2007 and 2014. The case involved Danske Bank's Estonian branch, which maintained a portfolio of high-risk international clients who frequently used shell companies to evade tax regulations. The bank was investigated for facilitating money laundering activities linked to a French import-export company, whose manager was convicted in January 2024. The investigation revealed that Danske Bank's compliance controls were inadequate, allowing clients to open accounts and conduct transactions without proper due diligence. The CJIP, validated by the Paris Judicial Court on September 18, 2024, required Danske Bank to pay a public interest fine of €6,028,799 and an additional €300,000 in compensation to the French state. The settlement took into account aggravating factors such as repeated offenses and compliance program deficiencies, as well as mitigating factors like corrective measures and cooperation with authorities. Danske Bank also faced previous penalties in Denmark and the US for related AML failures and fraud. The bank has since committed to strengthening its compliance and internal controls.",
#   'claim_type': 'settlement',
#   'date_published': '2024-09-20'},
#  {'displayLink': 'www.occrp.org',
#   'link': 'https://www.occrp.org/ru/ficher/utecka-iz-swedbank-pokazala-cto-sotrudniki-banka-sutili-pro-sxemy-otmyvaniia-deneg',
#   'summary': "The content reports that in 2019, journalists revealed that Swedbank and Danske Bank were used to move nearly six billion dollars through suspicious accounts in the Baltic countries. The OCCRP investigation found that Swedbank assisted a high-profile client, Russian oligarch and former minister Mikhail Abyzov, in transferring hundreds of millions of dollars to offshore accounts, with $53 million later determined by a Russian court to have been embezzled. Danske Bank is mentioned as being involved in the transfer of funds through suspicious accounts in the Baltics alongside Swedbank. Official investigations were launched into Swedbank's activities, focusing on money laundering and the concealment of beneficial ownership, but the Estonian case was closed in February 2024 due to lack of cooperation from Russian authorities. The content explicitly links Danske Bank to the movement of suspicious funds in the Baltics, but does not provide details of specific investigations, charges, or penalties against Danske Bank in this context.",
#   'claim_type': 'investigation',
#   'date_published': '2024-11-12'},
#  {'displayLink': 'www.twobirds.com',
#   'link': 'https://www.twobirds.com/fr/insights/2025/france/lcb-ft-retrospective-2024-partie-2',
#   'summary': "Danske Bank A/S entered into a judicial public interest agreement (CJIP) with the French financial prosecutor on August 27, 2024, which was validated by the president of the Paris judicial court on September 18, 2024. The settlement followed a judicial investigation opened in April 2015 that uncovered financial flows constituting tax fraud committed by the manager of Decobat, with funds transiting through accounts in Estonia held at Danske Bank's Estonian branch, Sampo Bank. The manager of Decobat was convicted in January 2024 for tax fraud and laundering of tax fraud. Danske Bank A/S was indicted in February 2019 for laundering of organized tax fraud, accused of opening fictitious transit accounts to receive money from organized tax fraud and allowing these accounts to be debited through multiple unjustified transactions to conceal the destination of misappropriated funds and benefit foreign recipients. The public interest fine of €6,028,799 was validated, taking into account Danske Bank's active cooperation, corrective measures, and relevant internal investigations conducted in the context of proceedings by Danish and American regulators.",
#   'claim_type': 'settlement',
#   'date_published': '2025-05-27'}]

# %%
links_collection = []
for elem in results.get("evidence_claims"):
        out = elem.model_dump()
        links_collection.append(out)
        
links_collection
# Out:
# [{'claim_text': 'Between 2007 and 2015, Danske Bank was alleged to have laundered over €200 billion in suspicious funds through its Estonian branch, exposing significant deficiencies in its anti-money laundering controls and compliance mechanisms.',
#   'claim_type': 'allegation',
#   'supporting_urls': ['https://pythagoras-solutions.com/en/insights/danske-bank-scandal-turning-point-aml-compliance-of-banking-sector',
#    'https://pythagoras-solutions.com/insights/danske-bank-skandal-ein-wendepunkt-aml-compliance-im-banksektor',
#    'https://theconversation.com/blanchiment-dargent-leurope-passe-enfin-a-laction-258091',
#    'https://www.tookitaki.com/blog/from-wachovia-to-danske-bank-biggest-money-laundering-cases-in-recent-times'],
#   'date_publish': '2019-03-25'},
#  {'claim_text': "Allegations were made that between 2007 and 2015, €201 billion of suspicious origin passed through Danske Bank's Estonian branch, with ten former employees accused of money laundering and the Central Bank of Russia warning Danske Bank about possible illegal transfers by Russian clients as early as 2013.",
#   'claim_type': 'allegation',
#   'supporting_urls': ['https://www.tadviser.ru/index.php/%D0%A1%D1%82%D0%B0%D1%82%D1%8C%D1%8F:%D0%9E%D1%82%D0%BC%D1%8B%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5_%D0%B4%D0%B5%D0%BD%D0%B5%D0%B3_(Money_Muling)'],
#   'date_publish': 'Unknown'},
#  {'claim_text': 'Danske Bank was referenced in the context of scandals that prompted new EU anti-money laundering legislation, implying allegations of money laundering or compliance failures, though no specific new developments were provided.',
#   'claim_type': 'allegation',
#   'supporting_urls': ['https://www.socialistsanddemocrats.eu/de/newsroom/die-sd-fraktion-begruesst-die-bahnbrechende-einigung-beim-eu-anti-geldwaesche-paket'],
#   'date_publish': 'Unknown'},
#  {'claim_text': 'Danske Bank was subject to investigations by Danish, Estonian, U.S., and U.K. authorities following the revelation that over $230 billion in suspicious transactions were processed through its Estonian branch between 2007 and 2015, leading to the resignation of key executives and the closure of the Estonian branch in 2019.',
#   'claim_type': 'investigation',
#   'supporting_urls': ['https://www.sanctionscanner.com/blog/danske-bank-case-money-laundering-scandal-1130'],
#   'date_publish': '2025-06-20'},
#  {'claim_text': 'In 2019, journalists revealed that Swedbank and Danske Bank were used to move nearly six billion dollars through suspicious accounts in the Baltic countries, with Danske Bank linked to the movement of suspicious funds in the Baltics alongside Swedbank.',
#   'claim_type': 'investigation',
#   'supporting_urls': ['https://www.occrp.org/ru/ficher/utecka-iz-swedbank-pokazala-cto-sotrudniki-banka-sutili-pro-sxemy-otmyvaniia-deneg'],
#   'date_publish': '2024-11-12'},
#  {'claim_text': 'Danske Bank agreed to pay the French government €6.3 million to settle money laundering charges related to its Estonian branch, following a deferred prosecution agreement with France’s National Financial Prosecutor, with the settlement validated by the Paris judicial court on September 18, 2024.',
#   'claim_type': 'settlement',
#   'supporting_urls': ['https://www.moneylaundering.com/news/danske-bank-pays-e6-3-million-to-settle-money-laundering-charges-in-france/',
#    'https://www.twobirds.com/fr/insights/2025/france/lcb-ft-retrospective-2024-partie-2',
#    'https://navacelle.law/fr/cjip-danske-bank/'],
#   'date_publish': '2024-09-18'},
#  {'claim_text': 'Danske Bank agreed to pay more than $2 billion as part of a global settlement with the U.S. Department of Justice, the SEC, the United States Attorney’s Office for the Southern District of New York, and Denmark’s Special Crime Unit, addressing significant AML compliance failures and related investor disclosures.',
#   'claim_type': 'settlement',
#   'supporting_urls': ['https://www.zuckermanlaw.com/uncategorized/money-laundering-sec-whistleblower-program/'],
#   'date_publish': 'Unknown'},
#  {'claim_text': "On January 7, 2025, the US Department of Justice announced that Estonia would receive $50 million from assets confiscated in the Danske Bank Estonia money laundering case, as part of a settlement recognizing Estonia's assistance in the investigation; Danske Bank admitted responsibility for misleading US banks and processing suspicious transactions for high-risk clients, and was fined over $2 billion by US authorities in 2022.",
#   'claim_type': 'settlement',
#   'supporting_urls': ['https://www.cbr.ru/Collection/Collection/File/55401/Jan_2025.pdf'],
#   'date_publish': '2025-01-07'},
#  {'claim_text': 'Danske Bank was fined hundreds of millions of dollars following the 2018 revelation that approximately €200 billion in suspicious transactions were processed through its Estonian branch, with investigations revealing failures in client checks and transaction monitoring.',
#   'claim_type': 'fine',
#   'supporting_urls': ['https://dineka.ru/news/1374/'],
#   'date_publish': '2024-06-07'},
#  {'claim_text': 'Danish authorities imposed fines totaling $2 million on Danske Bank for its involvement in a major money laundering scandal through its Estonian branch between 2007 and 2015, attributing responsibility to several managers and bank officials.',
#   'claim_type': 'fine',
#   'supporting_urls': ['https://financialcrimeacademy.org/de/geldwasche-aufgedeckt-bemerkenswerte-falle-und-beispiele-enthullt/',
#    'https://financialcrimeacademy.org/fr/blanchiment-dargent-demasque-des-cas-et-des-exemples-notables-devoiles/'],
#   'date_publish': '2025-08-29'},
#  {'claim_text': 'Danske Bank was fined €470 million for its involvement in a major international money laundering scandal, where approximately €200 billion in suspicious funds were laundered through its Estonian branch between 2007 and 2015, exposing deficiencies in regulatory oversight and compliance controls in Estonia.',
#   'claim_type': 'fine',
#   'supporting_urls': ['https://pideeco.be/fr/articles/comment-les-gatekeepers-sont-utilises-pour-le-blanchiment-dargent/',
#    'https://coredo.eu/ru/tri-jetapa-otmyvanija-deneg-i-ih-vlijanie-na-biznes/'],
#   'date_publish': '2024-11-18'},
#  {'claim_text': 'Danske Bank was fined by Danish regulators for anti-money laundering failures after its Estonian branch allegedly laundered approximately $230 billion in suspicious transactions between 2007 and 2015, mainly from Russian clients, resulting in regulatory penalties, legal proceedings, and significant reputational damage.',
#   'claim_type': 'fine',
#   'supporting_urls': ['https://blog.transworldcompliance.com/fr/des-amendes-qui-font-froid-dans-le-dos-les-sanctions-les-plus-effrayantes-en-cas-de-non-conformite-dans-le-secteur-financier'],
#   'date_publish': 'Unknown'},
#  {'claim_text': 'Danske Bank was fined by Danish and international authorities following investigations into the laundering of approximately €200 billion in suspicious funds through its Estonian branch between 2007 and 2015, resulting in a massive loss of trust and the resignation of the CEO.',
#   'claim_type': 'fine',
#   'supporting_urls': ['https://exkulpa.de/geldwaeschepraevention/geldwaescheparadies-deutschland-ursachen-eu-vergleich-folgen/'],
#   'date_publish': '2024-07-30'},
#  {'claim_text': 'Danske Bank was fined as part of a major US money laundering scandal between 2008 and 2016, with the bank defrauding several US banks and being sentenced to a billion-dollar fine, while Deutsche Bank processed suspicious transactions worth more than $267 billion for Danske Bank.',
#   'claim_type': 'fine',
#   'supporting_urls': ['https://www.produktion.de/wirtschaft/die-10-groessten-wirtschaftsskandale-in-deutschland-383.html'],
#   'date_publish': '2024-01-16'},
#  {'claim_text': "Danske Bank was fined over $2 billion by US authorities in 2022 as a result of an investigation into its Estonian branch's involvement in processing suspicious transactions for high-risk clients through the US financial system.",
#   'claim_type': 'fine',
#   'supporting_urls': ['https://www.sanctionscanner.com/blog/danske-bank-case-money-laundering-scandal-1130',
#    'https://www.cbr.ru/Collection/Collection/File/55401/Jan_2025.pdf'],
#   'date_publish': '2025-06-20'},
#  {'claim_text': 'Danske Bank was fined €6,028,799 and ordered to pay an additional €300,000 in compensation to the French state as part of a judicial public interest agreement (CJIP) with the French National Financial Prosecutor, addressing money laundering of tax fraud committed between 2007 and 2014 via its Estonian branch.',
#   'claim_type': 'fine',
#   'supporting_urls': ['https://www.twobirds.com/fr/insights/2025/france/lcb-ft-retrospective-2024-partie-2',
#    'https://navacelle.law/fr/cjip-danske-bank/'],
#   'date_publish': '2025-05-27'},
#  {'claim_text': "The United States allocated $50 million (48.8 million euros) to Estonia as part of a settlement for Estonia's contribution to resolving the Danske Bank money laundering case, with the funds originating from fines paid in connection with the Danske Bank case and used for financial crime prevention and investigation in Estonia.",
#   'claim_type': 'fine',
#   'supporting_urls': ['https://rus.postimees.ee/8338600/ssha-vydelili-estonii-milliony-na-borbu-s-otmyvaniem-deneg'],
#   'date_publish': '2025-10-08'},
#  {'claim_text': 'In 2022, Danske Bank admitted guilt to conspiracy to commit bank fraud, acknowledging that it provided banking services to suspicious clients through its Estonian branch despite being aware of money laundering risks.',
#   'claim_type': 'conviction',
#   'supporting_urls': ['https://finance.ua/goodtoknow/skhemy-vidmyvannia-hroshei-nairezonansnishi-spravy-svitu'],
#   'date_publish': '2024-07-11'}]

# %%
summary_res = results.get("messages", None)
print( summary_res[-1].content )
# Out:
# **1. EXECUTIVE SUMMARY**
#
# Danske Bank has been implicated in one of the largest money laundering scandals in European history, with over €200 billion in suspicious funds processed through its Estonian branch between 2007 and 2015. The bank has admitted guilt, faced criminal convictions, and paid fines totaling over €2.5 billion across multiple jurisdictions, including the US, Denmark, France, and Estonia. The violations were systemic, spanning nearly a decade, and involved failures in AML controls, client due diligence, and transaction monitoring. While major settlements have been reached and executive resignations have occurred, ongoing investigations and recent fines indicate that the risk is not fully resolved.
#
# **Total Fines Paid Calculation:**
# - €470 million (2024-11-18)
# - $2 million (2025-08-29) ≈ €1.85 million (at $1 = €0.925)
# - Over $2 billion (2025-06-20) ≈ €1.85 billion
# - €6,028,799 + €300,000 = €6.33 million (2025-05-27)
# - $50 million (2025-10-08) ≈ €46.25 million
# - €6.3 million (2024-09-18) [French settlement]
# - Additional fines referenced but not quantified (hundreds of millions, billion-dollar fine, etc.)
#
# **Total (rounded, using largest confirmed numbers and avoiding double-counting):**
# - €470 million + €1.85 billion + €6.33 million + €1.85 million + €46.25 million + €6.3 million = **€2,380,730,000** (approx. €2.38 billion)
#
# **2. VIOLATION ANALYSIS**
#
# - **Nature:** Systemic money laundering through Estonian branch (2007–2015), with €200+ billion in suspicious transactions, mainly from Russian clients.
# - **Criminal Conviction:** Admitted guilt to conspiracy to commit bank fraud (2024-07-11).
# - **Regulatory Failures:** Inadequate AML controls, poor client due diligence, and failure to act on warnings (e.g., from Central Bank of Russia in 2013).
# - **Leadership Accountability:** CEO and key executives resigned; Estonian branch closed in 2019.
# - **Jurisdictions:** Denmark, Estonia, US, UK, France, and broader EU.
#
# **3. CURRENT STATUS**
#
# - **Resolved:** Major settlements with US, Danish, and French authorities; Estonian branch closed; executive resignations.
# - **Ongoing:** Investigations by Danish, Estonian, US, and UK authorities (as of 2025-06-20); recent fines (2025-08-29, 2025-10-08) indicate continued regulatory scrutiny.
# - **Geographic Spread:** Multi-jurisdictional (EU, US, Russia, Baltics).
# - **Recent Activity:** Fines and settlements as recent as October 2025.
#
# **4. TRAJECTORY**
#
# - **Pattern:** Repeated, large-scale violations over many years; fines and settlements continue into 2025.
# - **Improvement:** Some evidence of reform (branch closure, leadership change, settlements), but ongoing investigations and recent fines suggest risk remains elevated.
# - **Quote:** "Danske Bank was fined over $2 billion by US authorities in 2022 as a result of an investigation into its Estonian branch's involvement in processing suspicious transactions for high-risk clients through the US financial system." (2025-06-20)
#
# **5. RISK RATING**
#
# **HIGH**
# - Justification: Systemic, multi-year, multi-jurisdictional AML failures; total fines exceed €2 billion; ongoing investigations; recent fines; criminal conviction; pattern of repeated violations.
#
# **6. PARTNERSHIP RECOMMENDATION**
#
# **AVOID PARTNERSHIP**
# - Rationale: Ongoing criminal and regulatory investigations, unresolved risk, and a pattern of systemic AML failures with recent enforcement actions. The scale and recency of violations, combined with the magnitude of fines and multi-jurisdictional scrutiny, indicate that Danske Bank remains a high-risk partner for AML compliance.
#
# ---
#
# **Summary Table**
#
# | Criteria                | Status/Details                                                                 |
# |-------------------------|-------------------------------------------------------------------------------|
# | Total Fines Paid        | Approx. €2.38 billion (multi-jurisdictional, 2018–2025)                       |
# | Most Serious Issue      | Systemic laundering of €200+ billion via Estonian branch (2007–2015)           |
# | Ongoing Risk?           | Yes (as of 2025-10-08; multiple active investigations)                         |
# | Investigating Authority | US DOJ, SEC, Danish FSA, French PNF, Estonian, UK authorities                  |
# | Geographic Spread       | Denmark, Estonia, US, UK, France, Baltics, Russia                              |
# | Settlement Efforts      | Major settlements, executive resignations, branch closure, but risk persists   |
# | Risk Rating             | HIGH                                                                           |
# | Recommendation          | AVOID PARTNERSHIP                                                              |
